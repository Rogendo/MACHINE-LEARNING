# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogendo/MACHINE-LEARNING/blob/main/Stock_time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fusion-Trade Phase 1B — Self-Contained Multi-Model Benchmark
#
# This notebook now includes a full Colab-ready pipeline:
#
# 1. Download Dukascopy historical market data.
# 2. Resample to 4H OHLCV.
# 3. Build baseline, FFT, and FFT+causal-STFT feature sets.
# 4. Create direction and tradeable-movement targets.
# 5. Benchmark tree models and sequence models.
#
# The goal is to evaluate whether FFT/STFT representations improve predictive performance across multiple model families, not only XGBoost/LightGBM.

# %% [markdown]
# ## 0. Colab setup and dependencies
#
# This notebook is self-contained for Colab:
#
# 1. Install dependencies.
# 2. Download Dukascopy historical OHLC data.
# 3. Resample to 4H candles.
# 4. Build baseline / FFT / FFT+STFT datasets.
# 5. Benchmark XGBoost, LightGBM, Random Forest, MLP, LSTM, GRU, TCN, and a **real PatchTST classifier**.
#
# No pre-uploaded CSV is required unless you choose to use your own data.

# %%
# Colab/Kaggle/local setup
# In Colab, run this cell. Locally, you can comment it out if packages are already installed.

# !pip install -q numpy pandas scipy scikit-learn pyarrow xgboost lightgbm torch matplotlib dukascopy-python wandb

# %% [markdown]
# ## 1. Imports and configuration

# %%
import os, json, math, warnings, random
from pathlib import Path
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import entropy as scipy_entropy
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier

warnings.filterwarnings('ignore')

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

try:
    import xgboost as xgb
    HAS_XGB = True
except Exception as e:
    HAS_XGB = False
    print('XGBoost unavailable:', e)

try:
    import lightgbm as lgb
    HAS_LGB = True
except Exception as e:
    HAS_LGB = False
    print('LightGBM unavailable:', e)

try:
    import torch
    import torch.nn as nn
    from torch.utils.data import Dataset, DataLoader
    HAS_TORCH = True
    DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
    torch.manual_seed(SEED)
    print('Torch device:', DEVICE)
except Exception as e:
    HAS_TORCH = False
    DEVICE = 'cpu'
    print('PyTorch unavailable:', e)

pd.set_option('display.max_columns', 120)
# Out:
# Torch device: cuda

# %% [markdown]
# ## 2. Data source: download Dukascopy data inside the notebook
#
# For experimentation in Colab, we should not rely on a manually uploaded CSV.
#
# This section downloads Dukascopy data directly, converts it into the standard Fusion-Trade format:
#
# ```text
# timestamp | open | high | low | close | volume
# ```
#
# Then it resamples the data to the timeframe we want, for example **4H**.
#
# ### Why Dukascopy?
#
# Dukascopy gives much deeper Forex/metal history than Yahoo Finance intraday data. We can download 1-minute data and resample it ourselves to 1H, 4H, daily, etc.

# %%
# ============================================================
# Dukascopy downloader + resampler
# ============================================================

from datetime import datetime
import os
import pandas as pd

# -----------------------------
# User configuration
# -----------------------------
USE_DUKASCOPY = False       # True = download data in notebook. False = use CSV_PATH below.
USE_SYNTHETIC = True      # True = use synthetic data instead of real data.

# Instrument options usually include: "XAUUSD", "EURUSD", "GBPUSD", "USDJPY", etc.
# For metals, use XAUUSD. For forex, use EURUSD, GBPUSD, etc.
DUKA_SYMBOL = "XAUUSD"

START_DATE = datetime(2018, 1, 1)
END_DATE   = datetime(2026, 6, 30)

# Dukascopy download granularity. For long ranges, 1H is much lighter.
# If you want maximum flexibility, use "1min" then resample, but it may take longer.
DUKA_INTERVAL = "1h"    # options depend on dukascopy-python: commonly "1min", "1h", "1d"
TARGET_TIMEFRAME = "4H"   # pandas resample rule: "1H", "4H", "1D", etc.

CSV_PATH = "real_data/XAUUSD_4H_dukascopy.csv"  # used if USE_DUKASCOPY=False
OUT_CSV_PATH = f"real_data/{DUKA_SYMBOL}_{TARGET_TIMEFRAME}_dukascopy.csv".replace("/", "_")


def make_synthetic(n: int = 3000, seed: int = 42) -> pd.DataFrame:
    """Fallback synthetic dataset with hidden weekly/monthly cycles."""
    rng = np.random.default_rng(seed)
    t = np.arange(n)
    trend = 1900 + 0.05 * t
    weekly = 12 * np.sin(2*np.pi*t/7)
    monthly = 20 * np.sin(2*np.pi*t/30)
    vol_cycle = 1 + 0.5*np.abs(np.sin(2*np.pi*t/50))
    noise = rng.normal(0, 5*vol_cycle, n)
    close = np.maximum(trend + weekly + monthly + noise, 1)
    spread = rng.uniform(2, 8, n)
    high = close + spread * rng.uniform(0.4, 1.0, n)
    low = close - spread * rng.uniform(0.4, 1.0, n)
    open_ = close + rng.normal(0, 2, n)
    volume = rng.integers(1000, 50000, n).astype(float)
    dates = pd.date_range("2020-01-01", periods=n, freq="4H", tz="UTC")
    return pd.DataFrame({"timestamp": dates, "open": open_, "high": high, "low": low, "close": close, "volume": volume})


def _standardize_ohlcv_columns(df: pd.DataFrame) -> pd.DataFrame:
    """Return timestamp/open/high/low/close/volume columns from common provider formats."""
    df = df.copy()
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    df = df.reset_index() if df.index.name is not None or not isinstance(df.index, pd.RangeIndex) else df
    df.columns = [str(c).lower().replace(" ", "_") for c in df.columns]

    # Normalize timestamp column name
    for candidate in ["timestamp", "datetime", "date", "time", "index", "gmt_time"]:
        if candidate in df.columns:
            df = df.rename(columns={candidate: "timestamp"})
            break

    # Some Dukascopy outputs may use ask/bid variants; pick close/open/high/low if already present.
    required = ["timestamp", "open", "high", "low", "close"]
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required OHLC columns after standardization: {missing}. Available: {list(df.columns)}")

    if "volume" not in df.columns:
        # Dukascopy may sometimes return tick_volume or no volume depending on instrument/гранулярность.
        vol_candidates = [c for c in df.columns if "volume" in c]
        if vol_candidates:
            df = df.rename(columns={vol_candidates[0]: "volume"})
        else:
            df["volume"] = 0.0

    out = df[["timestamp", "open", "high", "low", "close", "volume"]].copy()
    out["timestamp"] = pd.to_datetime(out["timestamp"], utc=True)
    for c in ["open", "high", "low", "close", "volume"]:
        out[c] = pd.to_numeric(out[c], errors="coerce")
    out = out.dropna().sort_values("timestamp").reset_index(drop=True)
    return out


def resample_ohlcv(df: pd.DataFrame, rule: str = "4H") -> pd.DataFrame:
    """Resample OHLCV to the requested timeframe."""
    df = _standardize_ohlcv_columns(df)
    out = (
        df.set_index("timestamp")
          .resample(rule)
          .agg({
              "open": "first",
              "high": "max",
              "low": "min",
              "close": "last",
              "volume": "sum",
          })
          .dropna()
          .reset_index()
    )
    return out


def download_dukascopy(symbol: str, start: datetime, end: datetime, interval: str = "1min") -> pd.DataFrame:
    """Download Dukascopy data using dukascopy-python, with a robust fallback for instrument names."""
    import dukascopy_python as dp

    # dukascopy-python can accept symbols in many builds, but some versions expose instrument constants.
    symbol_upper = symbol.upper().replace("/", "")

    # Try direct symbol first.
    try:
        df = dp.fetch(symbol_upper, interval=interval, start=start, end=end, offer_side='BID')
        return _standardize_ohlcv_columns(df)
    except Exception as e_direct:
        print(f"Direct symbol fetch failed for {symbol_upper}: {e_direct}")

    # Try common constants from dukascopy_python.instruments.
    try:
        import dukascopy_python.instruments as inst
        constant_names = [
            f"INSTRUMENT_FX_METALS_{symbol_upper[:3]}_{symbol_upper[3:]}",
            f"INSTRUMENT_FX_MAJORS_{symbol_upper[:3]}_{symbol_upper[3:]}",
            f"INSTRUMENT_FX_CROSSES_{symbol_upper[:3]}_{symbol_upper[3:]}",
        ]
        for name in constant_names:
            if hasattr(inst, name):
                instrument = getattr(inst, name)
                print(f"Using Dukascopy instrument constant: {name}")
                df = dp.fetch(instrument, interval=interval, start=start, end=end, offer_side='BID')
                return _standardize_ohlcv_columns(df)
    except Exception as e_const:
        print(f"Constant-based fetch also failed: {e_const}")

    raise RuntimeError(
        f"Could not download {symbol} from Dukascopy. Try a known symbol like XAUUSD, EURUSD, GBPUSD, or upload a CSV."
    )


# -----------------------------
# Build the raw dataframe
# -----------------------------
if USE_SYNTHETIC:
    df_raw = make_synthetic(n=3000)
    print("Using synthetic data")
elif USE_DUKASCOPY:
    print(f"Downloading Dukascopy {DUKA_SYMBOL} from {START_DATE.date()} to {END_DATE.date()} at {DUKA_INTERVAL}...")
    df_min = download_dukascopy(DUKA_SYMBOL, START_DATE, END_DATE, interval=DUKA_INTERVAL)
    print("Raw downloaded data:", df_min.shape)
    display(df_min.head())
    df_raw = resample_ohlcv(df_min, TARGET_TIMEFRAME)
    os.makedirs(os.path.dirname(OUT_CSV_PATH), exist_ok=True)
    df_raw.to_csv(OUT_CSV_PATH, index=False)
    print(f"Saved resampled data: {OUT_CSV_PATH} shape={df_raw.shape}")
else:
    print(f"Loading local CSV: {CSV_PATH}")
    df_raw = pd.read_csv(CSV_PATH)
    df_raw = _standardize_ohlcv_columns(df_raw)

print("Final OHLCV dataframe:")
display(df_raw.head())
print(df_raw.shape)
# Out:
# Using synthetic data
# Final OHLCV dataframe:
#                   timestamp         open         high          low  \
# 0 2020-01-01 00:00:00+00:00  1900.352765  1904.872356  1896.907525
# 1 2020-01-01 04:00:00+00:00  1904.658137  1910.875404  1902.559973
# 2 2020-01-01 08:00:00+00:00  1923.524783  1927.385479  1919.040775
# 3 2020-01-01 12:00:00+00:00  1921.715282  1929.076622  1916.585964
# 4 2020-01-01 16:00:00+00:00  1895.101099  1903.064678  1894.210059
#
#          close   volume
# 0  1901.523585  39896.0
# 1  1908.064430  40116.0
# 2  1924.152698   3944.0
# 3  1922.680746  16645.0
# 4  1897.751320  47064.0
# (3000, 6)

# %% [markdown]
# ### Optional: download the resampled Dukascopy CSV from Colab
#
# After the Dukascopy data is downloaded and resampled, this cell lets you download the generated CSV to your local machine for reuse.

# %%
# Optional Colab download of the generated CSV
try:
    from google.colab import files
    if os.path.exists(OUT_CSV_PATH):
        files.download(OUT_CSV_PATH)
except Exception as e:
    print("Not running in Colab, or download skipped:", e)

# %% [markdown]
# ## 3. Feature engineering: baseline + FFT + causal STFT
#
# This section keeps the Phase 1 fixes:
#
# - FFT uses only historical candles.
# - STFT is causal: row `t` only sees candles `<= t`.
# - Phase is encoded as `sin`/`cos`, not raw radians.
# - Datasets are aligned to the same valid rows.

# %%
# -----------------------------
# Baseline technical indicators
# -----------------------------

def add_baseline_features(df: pd.DataFrame, price_col: str = 'close') -> pd.DataFrame:
    df = df.copy()
    c = df[price_col]
    h = df['high']; l = df['low']; v = df['volume']
    df['log_return'] = np.log(c / c.shift(1))
    df['return_5'] = np.log(c / c.shift(5))
    df['range'] = h - l
    df['body'] = c - df['open']
    df['upper_wick'] = h - df[['open', price_col]].max(axis=1)
    df['lower_wick'] = df[['open', price_col]].min(axis=1) - l
    df['typical_price'] = (h + l + c) / 3
    for w in [10,20,50]:
        df[f'sma_{w}'] = c.rolling(w).mean()
        df[f'ema_{w}'] = c.ewm(span=w, adjust=False).mean()
    df['price_vs_sma20'] = c / (df['sma_20'] + 1e-9) - 1
    df['price_vs_ema20'] = c / (df['ema_20'] + 1e-9) - 1
    df['roc_5'] = c.pct_change(5)
    df['roc_20'] = c.pct_change(20)
    delta = c.diff()
    gain = delta.clip(lower=0).rolling(14).mean()
    loss = (-delta.clip(upper=0)).rolling(14).mean()
    df['rsi_14'] = 100 - (100 / (1 + gain/(loss + 1e-9)))
    ema12 = c.ewm(span=12, adjust=False).mean()
    ema26 = c.ewm(span=26, adjust=False).mean()
    df['macd'] = ema12 - ema26
    df['macd_signal'] = df['macd'].ewm(span=9, adjust=False).mean()
    df['macd_hist'] = df['macd'] - df['macd_signal']
    df['rolling_std_10'] = df['log_return'].rolling(10).std()
    df['rolling_std_20'] = df['log_return'].rolling(20).std()
    tr = pd.concat([(h-l), (h-c.shift(1)).abs(), (l-c.shift(1)).abs()], axis=1).max(axis=1)
    df['atr_14'] = tr.rolling(14).mean()
    bb_mid = c.rolling(20).mean()
    bb_std = c.rolling(20).std()
    df['bb_upper'] = bb_mid + 2*bb_std
    df['bb_lower'] = bb_mid - 2*bb_std
    df['bb_width'] = (df['bb_upper'] - df['bb_lower']) / (bb_mid + 1e-9)
    df['bb_pct'] = (c - df['bb_lower']) / (df['bb_upper'] - df['bb_lower'] + 1e-9)
    df['volume_ma20'] = v.rolling(20).mean()
    df['volume_ratio'] = v / (df['volume_ma20'] + 1e-9)
    ts = pd.to_datetime(df['timestamp'], utc=True)
    df['hour'] = ts.dt.hour
    df['day_of_week'] = ts.dt.dayofweek
    df['month'] = ts.dt.month
    df['is_london'] = ((df['hour'] >= 7) & (df['hour'] < 16)).astype(int)
    df['is_newyork'] = ((df['hour'] >= 13) & (df['hour'] < 22)).astype(int)
    df['is_overlap'] = ((df['hour'] >= 13) & (df['hour'] < 16)).astype(int)
    return df

# -----------------------------
# FFT / STFT helpers
# -----------------------------

def _log_returns(prices: np.ndarray) -> np.ndarray:
    r = np.zeros_like(prices, dtype=float)
    r[1:] = np.log(prices[1:] / prices[:-1])
    return r


def _hanning_fft(signal: np.ndarray):
    n = len(signal)
    w = signal * np.hanning(n)
    vals = np.fft.rfft(w)
    freqs = np.fft.rfftfreq(n)
    amps = np.abs(vals)
    phases = np.angle(vals)
    return amps, phases, freqs


def _add_sincos(features: dict, prefix: str, phase: float):
    features[f'sin_{prefix}'] = float(np.sin(phase))
    features[f'cos_{prefix}'] = float(np.cos(phase))


def compute_fft_row(window_prices: np.ndarray, n_components: int = 5) -> dict:
    signal = _log_returns(window_prices)
    amps, phases, freqs = _hanning_fft(signal)
    amps_nd, phases_nd, freqs_nd = amps[1:], phases[1:], freqs[1:]
    top_idx = np.argsort(amps_nd)[::-1][:n_components]
    top_amps, top_freqs, top_phases = amps_nd[top_idx], freqs_nd[top_idx], phases_nd[top_idx]
    features = {}
    for i in range(n_components):
        a = float(top_amps[i]) if i < len(top_amps) else 0.0
        f = float(top_freqs[i]) if i < len(top_freqs) else 0.0
        p = float(top_phases[i]) if i < len(top_phases) else 0.0
        features[f'fft_amp_{i+1}'] = a
        features[f'fft_freq_{i+1}'] = f
        _add_sincos(features, f'fft_phase_{i+1}', p)
    dom_freq = top_freqs[0] if len(top_freqs) and top_freqs[0] > 0 else 1e-6
    features['fft_dominant_period'] = float(1.0 / dom_freq)
    total_energy = float(np.sum(amps_nd**2)) + 1e-9
    band = max(len(amps_nd)//3, 1)
    features['fft_spectral_energy'] = total_energy
    features['fft_low_freq_energy'] = float(np.sum(amps_nd[:band]**2)) / total_energy
    features['fft_mid_freq_energy'] = float(np.sum(amps_nd[band:2*band]**2)) / total_energy
    features['fft_high_freq_energy'] = float(np.sum(amps_nd[2*band:]**2)) / total_energy
    norm = amps_nd / (amps_nd.sum() + 1e-9)
    features['fft_spectral_entropy'] = float(scipy_entropy(norm + 1e-12))
    features['fft_cycle_strength'] = float(top_amps[0]**2) / total_energy if len(top_amps) else 0.0
    dom_phase = float(top_phases[0]) if len(top_phases) else 0.0
    _add_sincos(features, 'fft_dominant_phase', dom_phase)
    return features


def compute_causal_stft_row(window_prices: np.ndarray, nperseg: int = 32) -> dict:
    seg = window_prices[-nperseg:] if len(window_prices) >= nperseg else window_prices
    signal = _log_returns(seg)
    amps, phases, freqs = _hanning_fft(signal)
    amps_nd, phases_nd, freqs_nd = amps[1:], phases[1:], freqs[1:]
    total = float(amps_nd.sum()) + 1e-9
    band = max(len(amps_nd)//3, 1)
    dom_idx = int(np.argmax(amps_nd)) if len(amps_nd) else 0
    dom_freq = float(freqs_nd[dom_idx]) if len(freqs_nd) else 0.0
    dom_phase = float(phases_nd[dom_idx]) if len(phases_nd) else 0.0
    features = {
        'stft_dom_freq': dom_freq,
        'stft_dom_period': float(1.0/dom_freq) if dom_freq > 0 else 0.0,
        'stft_low_energy': float(amps_nd[:band].sum()) / total,
        'stft_mid_energy': float(amps_nd[band:2*band].sum()) / total,
        'stft_high_energy': float(amps_nd[2*band:].sum()) / total,
        'stft_centroid': float(np.sum(freqs_nd * amps_nd)) / total,
        'stft_entropy': float(scipy_entropy(amps_nd/total + 1e-12)),
    }
    _add_sincos(features, 'stft_dom_phase', dom_phase)
    return features


def add_signal_features(df: pd.DataFrame, price_col='close', fft_window=64, fft_components=5, stft_nperseg=32):
    df = df.copy()
    prices = df[price_col].values
    fft_rows, stft_rows = [], []
    for i in range(len(prices)):
        if i < fft_window - 1:
            fft_rows.append({}); stft_rows.append({})
            continue
        start = i - fft_window + 1
        win = prices[start:i+1]
        fft_rows.append(compute_fft_row(win, fft_components))
        stft_rows.append(compute_causal_stft_row(win, stft_nperseg))
    # causal spectral flux from previous row only
    for i in range(len(stft_rows)):
        if not stft_rows[i]:
            continue
        if i == 0 or not stft_rows[i-1]:
            stft_rows[i]['stft_spectral_flux'] = 0.0
        else:
            keys = ['stft_low_energy','stft_mid_energy','stft_high_energy']
            stft_rows[i]['stft_spectral_flux'] = float(np.sqrt(sum((stft_rows[i].get(k,0)-stft_rows[i-1].get(k,0))**2 for k in keys)))
    return pd.concat([df, pd.DataFrame(fft_rows), pd.DataFrame(stft_rows)], axis=1)

# %% [markdown]
# ## 4. Targets
#
# We keep the old targets for comparability, but add the new **tradeable movement target**.
#
# ### Trade target
#
# Let:
#
# ```text
# future_return_5 = log(close[t+5] / close[t])
# atr_return = ATR_14[t] / close[t]
# threshold = 0.5 * atr_return
# ```
#
# Then:
#
# ```text
# BUY      = +1 if future_return_5 > threshold
# SELL     = -1 if future_return_5 < -threshold
# NO_TRADE =  0 otherwise
# ```
#
# For model training we encode:
#
# ```text
# SELL=0, NO_TRADE=1, BUY=2
# ```

# %%
def add_targets(df: pd.DataFrame, price_col='close', horizon=5, atr_mult=0.5) -> pd.DataFrame:
    df = df.copy()
    c = df[price_col]
    fwd1 = np.log(c.shift(-1) / c)
    fwd5 = np.log(c.shift(-horizon) / c)
    df['target_return_1'] = fwd1
    df['target_direction_1'] = (fwd1 > 0).astype(int)
    df['target_return_5'] = fwd5
    df['target_direction_5'] = (fwd5 > 0).astype(int)
    # realized volatility over next horizon
    log_ret = np.log(c / c.shift(1))
    rv = pd.Series(index=df.index, dtype=float)
    for i in range(len(df) - horizon):
        rv.iloc[i] = log_ret.iloc[i+1:i+horizon+1].std()
    df['target_volatility_5'] = rv
    # tradeable movement target
    atr_return = df['atr_14'] / (c + 1e-9)
    threshold = atr_mult * atr_return
    trade = np.ones(len(df), dtype=float)  # 1 = NO_TRADE
    trade[fwd5 > threshold] = 2            # BUY
    trade[fwd5 < -threshold] = 0           # SELL
    trade[pd.isna(fwd5) | pd.isna(threshold)] = np.nan
    df['target_trade_signal_5'] = trade
    return df

TARGET_COLS = ['target_return_1','target_direction_1','target_return_5','target_direction_5','target_volatility_5','target_trade_signal_5']

# %% [markdown]
# ## 5. Build aligned datasets
#
# This creates the three ablation datasets:
#
# - `baseline`
# - `fft`
# - `fft_stft`

# %%
def build_aligned_datasets(source_df: pd.DataFrame, fft_window=64, stft_nperseg=32, horizon=5, atr_mult=0.5):
    df = add_baseline_features(source_df)
    df = add_targets(df, horizon=horizon, atr_mult=atr_mult)
    df = add_signal_features(df, fft_window=fft_window, stft_nperseg=stft_nperseg)

    fft_cols = [c for c in df.columns if c.startswith('fft_') or c.startswith('sin_fft_') or c.startswith('cos_fft_')]
    stft_cols = [c for c in df.columns if c.startswith('stft_') or c.startswith('sin_stft_') or c.startswith('cos_stft_')]
    signal_cols = set(fft_cols + stft_cols)
    meta_cols = ['timestamp']
    baseline_cols = [c for c in df.columns if c not in set(TARGET_COLS) | set(meta_cols) | signal_cols]

    # valid rows: all signal cols, all targets, no NaN baseline cols
    all_needed = baseline_cols + fft_cols + stft_cols + TARGET_COLS
    valid_mask = df[all_needed].notna().all(axis=1)
    dfv = df.loc[valid_mask].reset_index(drop=True)

    print('Valid aligned rows:', len(dfv), 'from source rows:', len(source_df))
    print('Baseline features:', len(baseline_cols), 'FFT:', len(fft_cols), 'STFT:', len(stft_cols))
    datasets = {
        'baseline': dfv[meta_cols + baseline_cols + TARGET_COLS].copy(),
        'fft': dfv[meta_cols + baseline_cols + fft_cols + TARGET_COLS].copy(),
        'fft_stft': dfv[meta_cols + baseline_cols + fft_cols + stft_cols + TARGET_COLS].copy(),
    }
    for k,v in datasets.items():
        print(k, v.shape)
    return datasets, {'baseline_cols': baseline_cols, 'fft_cols': fft_cols, 'stft_cols': stft_cols}

datasets, colgroups = build_aligned_datasets(df_raw, fft_window=64, stft_nperseg=32, horizon=5, atr_mult=0.5)

display(datasets['fft_stft'].head())
print('Trade target distribution:')
print(datasets['fft_stft']['target_trade_signal_5'].value_counts(normalize=True).sort_index())
# Out:
# Valid aligned rows: 2932 from source rows: 3000
# Baseline features: 41 FFT: 29 STFT: 10
# baseline (2932, 48)
# fft (2932, 77)
# fft_stft (2932, 87)
#                   timestamp         open         high          low  \
# 0 2020-01-11 12:00:00+00:00  1919.766733  1923.080691  1916.669998
# 1 2020-01-11 16:00:00+00:00  1931.375485  1936.346774  1927.381312
# 2 2020-01-11 20:00:00+00:00  1938.139774  1944.998447  1933.198806
# 3 2020-01-12 00:00:00+00:00  1926.967249  1926.199226  1923.180715
# 4 2020-01-12 04:00:00+00:00  1914.980591  1918.142858  1910.819873
#
#          close   volume  log_return  return_5      range      body  \
# 0  1919.299481   2930.0    0.008491  0.009944   6.410693 -0.467253
# 1  1932.747579  47838.0    0.006982  0.011300   8.965462  1.372094
# 2  1938.122674  41151.0    0.002777  0.027592  11.799640 -0.017100
# 3  1924.995270  35275.0   -0.006796  0.016754   3.018510 -1.971979
# 4  1914.746133  11843.0   -0.005338  0.006115   7.322984 -0.234459
#
#    upper_wick  lower_wick  typical_price       sma_10       ema_10  \
# 0    3.313957    2.629483    1919.683390  1894.999673  1899.518678
# 1    3.599195    3.994173    1932.158555  1901.368294  1905.560296
# 2    6.858672    4.923868    1938.773309  1907.989130  1911.480729
# 3   -0.768023    1.814555    1924.791737  1911.879605  1913.937918
# 4    3.162266    3.926259    1914.569621  1912.271152  1914.084866
#
#         sma_20       ema_20       sma_50       ema_50  price_vs_sma20  \
# 0  1894.144483  1898.064766  1899.062226  1899.864134        0.013280
# 1  1894.839837  1901.367891  1899.550301  1901.153681        0.020006
# 2  1896.302401  1904.868346  1900.236906  1902.603445        0.022054
# 3  1897.635073  1906.785196  1900.516435  1903.481556        0.014418
# 4  1899.180385  1907.543381  1900.989289  1903.923304        0.008196
#
#    price_vs_ema20     roc_5    roc_20     rsi_14      macd  macd_signal  \
# 0        0.011188  0.009994 -0.001028  59.632606  0.312644    -2.611909
# 1        0.016504  0.011364  0.007248  60.926032  3.004204    -1.488686
# 2        0.017458  0.027976  0.015324  61.566071  5.507523    -0.089444
# 3        0.009550  0.016895  0.014040  63.701625  6.358849     1.200214
# 4        0.003776  0.006134  0.016406  61.402734  6.135781     2.187328
#
#    macd_hist  rolling_std_10  rolling_std_20     atr_14     bb_upper  \
# 0   2.924553        0.007817        0.006681  14.925703  1923.966090
# 1   4.492890        0.007651        0.006854  15.391091  1927.590716
# 2   5.596967        0.007628        0.006744  15.771862  1933.939679
# 3   5.158635        0.008111        0.006812  15.286535  1937.403570
# 4   3.948454        0.007394        0.006680  15.803177  1939.093462
#
#       bb_lower  bb_width    bb_pct  volume_ma20  volume_ratio  hour  \
# 0  1864.322876  0.031488  0.921758     23461.70      0.124884    12
# 1  1862.088959  0.034568  1.078729     24575.40      1.946581    16
# 2  1858.665123  0.039695  1.055570     26478.75      1.554114    20
# 3  1857.866575  0.041914  0.843993     27923.60      1.263268     0
# 4  1859.267308  0.042032  0.694996     27087.90      0.437206     4
#
#    day_of_week  month  is_london  is_newyork  is_overlap  fft_amp_1  \
# 0            5      1          1           0           0   0.083218
# 1            5      1          0           1           0   0.083332
# 2            5      1          0           1           0   0.083473
# 3            6      1          0           0           0   0.083664
# 4            6      1          0           0           0   0.083916
#
#    fft_freq_1  sin_fft_phase_1  cos_fft_phase_1  fft_amp_2  fft_freq_2  \
# 0    0.140625         0.107106         0.994248   0.056555     0.15625
# 1    0.140625         0.845057         0.534676   0.055214     0.15625
# 2    0.140625         0.944365        -0.328900   0.053773     0.15625
# 3    0.140625         0.330129        -0.943936   0.052252     0.15625
# 4    0.140625        -0.533638        -0.845713   0.050688     0.15625
#
#    sin_fft_phase_2  cos_fft_phase_2  fft_amp_3  fft_freq_3  sin_fft_phase_3  \
# 0        -0.273547        -0.961859   0.036706       0.125        -0.073157
# 1        -0.926995        -0.375074   0.036636       0.125        -0.815479
# 2        -0.867592         0.497277   0.036404       0.125        -0.965257
# 3        -0.149889         0.988703   0.036001       0.125        -0.410267
# 4         0.676765         0.736199   0.035433       0.125         0.447195
#
#    cos_fft_phase_3  fft_amp_4  fft_freq_4  sin_fft_phase_4  cos_fft_phase_4  \
# 0        -0.997320   0.036556    0.484375         0.823463        -0.567370
# 1        -0.578786   0.036011    0.484375        -0.867388         0.497633
# 2         0.261301   0.035531    0.484375         0.905005        -0.425402
# 3         0.911965   0.035120    0.484375        -0.936318         0.351153
# 4         0.894436   0.034804    0.484375         0.961058        -0.276347
#
#    fft_amp_5  fft_freq_5  sin_fft_phase_5  cos_fft_phase_5  \
# 0   0.034172     0.03125         0.301766         0.953382
# 1   0.034181     0.03125         0.492834         0.870123
# 2   0.034212     0.03125         0.662102         0.749414
# 3   0.034262     0.03125         0.802515         0.596633
# 4   0.034311     0.03125         0.908401         0.418100
#
#    fft_dominant_period  fft_spectral_energy  fft_low_freq_energy  \
# 0             7.111111             0.023423             0.568719
# 1             7.111111             0.022963             0.573258
# 2             7.111111             0.022500             0.577630
# 3             7.111111             0.022051             0.581683
# 4             7.111111             0.021634             0.585276
#
#    fft_mid_freq_energy  fft_high_freq_energy  fft_spectral_entropy  \
# 0             0.199401              0.231880              3.206927
# 1             0.203439              0.223303              3.201401
# 2             0.206607              0.215763              3.194354
# 3             0.208711              0.209606              3.186674
# 4             0.209552              0.205172              3.180855
#
#    fft_cycle_strength  sin_fft_dominant_phase  cos_fft_dominant_phase  \
# 0            0.295656                0.107106                0.994248
# 1            0.302407                0.845057                0.534676
# 2            0.309677                0.944365               -0.328900
# 3            0.317424                0.330129               -0.943936
# 4            0.325500               -0.533638               -0.845713
#
#    stft_dom_freq  stft_dom_period  stft_low_energy  stft_mid_energy  \
# 0        0.15625              6.4         0.457191         0.209205
# 1        0.15625              6.4         0.452674         0.193024
# 2        0.15625              6.4         0.446388         0.182334
# 3        0.15625              6.4         0.438792         0.174243
# 4        0.15625              6.4         0.429816         0.166593
#
#    stft_high_energy  stft_centroid  stft_entropy  sin_stft_dom_phase  \
# 0          0.333604       0.242585      2.559342            0.991842
# 1          0.354302       0.248315      2.570412            0.497353
# 2          0.371278       0.253540      2.584638           -0.396373
# 3          0.386965       0.258528      2.592497           -0.973122
# 4          0.403591       0.263624      2.593919           -0.765838
#
#    cos_stft_dom_phase  stft_spectral_flux  target_return_1  \
# 0           -0.127470            0.000000         0.006982
# 1           -0.867548            0.026658         0.002777
# 2           -0.918090            0.021023        -0.006796
# 3           -0.230289            0.019216        -0.005338
# 4            0.643034            0.020384         0.001455
#
#    target_direction_1  target_return_5  target_direction_5  \
# 0                   1        -0.000920                   0
# 1                   1        -0.010895                   0
# 2                   0        -0.013273                   0
# 3                   0        -0.002201                   0
# 4                   1         0.003579                   1
#
#    target_volatility_5  target_trade_signal_5
# 0             0.005768                    1.0
# 1             0.004175                    0.0
# 2             0.003560                    0.0
# 3             0.003776                    1.0
# 4             0.002605                    1.0
# Trade target distribution:
# target_trade_signal_5
# 0.0    0.377899
# 1.0    0.234652
# 2.0    0.387449
# Name: proportion, dtype: float64

# %% [markdown]
# ### Build the three aligned feature sets
#
# This cell converts the downloaded/resampled OHLCV data into three comparable datasets:
#
# - `baseline`: OHLCV + technical indicators
# - `fft`: baseline + rolling FFT features
# - `fft_stft`: baseline + rolling FFT + causal STFT features
#
# The rows are aligned so all feature sets use the same timestamps.

# %%
# Feature/target configuration
FFT_WINDOW = 64
STFT_NPERSEG = 32
TARGET_HORIZON = 5
ATR_MULT = 0.5

# Build aligned datasets from the dataframe downloaded/resampled above.
datasets, colgroups = build_aligned_datasets(
    df_raw,
    fft_window=FFT_WINDOW,
    stft_nperseg=STFT_NPERSEG,
    horizon=TARGET_HORIZON,
    atr_mult=ATR_MULT,
)

for name, d in datasets.items():
    print(name, d.shape)
    display(d.head(2))

# Save the generated datasets for reuse.
os.makedirs('benchmark_data', exist_ok=True)
for name, d in datasets.items():
    out_path = f'benchmark_data/features_{name}.parquet'
    d.to_parquet(out_path, index=False)
    print('Saved:', out_path)
# Out:
# Valid aligned rows: 2932 from source rows: 3000
# Baseline features: 41 FFT: 29 STFT: 10
# baseline (2932, 48)
# fft (2932, 77)
# fft_stft (2932, 87)
# baseline (2932, 48)
#                   timestamp         open         high          low  \
# 0 2020-01-11 12:00:00+00:00  1919.766733  1923.080691  1916.669998
# 1 2020-01-11 16:00:00+00:00  1931.375485  1936.346774  1927.381312
#
#          close   volume  log_return  return_5     range      body  upper_wick  \
# 0  1919.299481   2930.0    0.008491  0.009944  6.410693 -0.467253    3.313957
# 1  1932.747579  47838.0    0.006982  0.011300  8.965462  1.372094    3.599195
#
#    lower_wick  typical_price       sma_10       ema_10       sma_20  \
# 0    2.629483    1919.683390  1894.999673  1899.518678  1894.144483
# 1    3.994173    1932.158555  1901.368294  1905.560296  1894.839837
#
#         ema_20       sma_50       ema_50  price_vs_sma20  price_vs_ema20  \
# 0  1898.064766  1899.062226  1899.864134        0.013280        0.011188
# 1  1901.367891  1899.550301  1901.153681        0.020006        0.016504
#
#       roc_5    roc_20     rsi_14      macd  macd_signal  macd_hist  \
# 0  0.009994 -0.001028  59.632606  0.312644    -2.611909   2.924553
# 1  0.011364  0.007248  60.926032  3.004204    -1.488686   4.492890
#
#    rolling_std_10  rolling_std_20     atr_14     bb_upper     bb_lower  \
# 0        0.007817        0.006681  14.925703  1923.966090  1864.322876
# 1        0.007651        0.006854  15.391091  1927.590716  1862.088959
#
#    bb_width    bb_pct  volume_ma20  volume_ratio  hour  day_of_week  month  \
# 0  0.031488  0.921758      23461.7      0.124884    12            5      1
# 1  0.034568  1.078729      24575.4      1.946581    16            5      1
#
#    is_london  is_newyork  is_overlap  target_return_1  target_direction_1  \
# 0          1           0           0         0.006982                   1
# 1          0           1           0         0.002777                   1
#
#    target_return_5  target_direction_5  target_volatility_5  \
# 0        -0.000920                   0             0.005768
# 1        -0.010895                   0             0.004175
#
#    target_trade_signal_5
# 0                    1.0
# 1                    0.0
# fft (2932, 77)
#                   timestamp         open         high          low  \
# 0 2020-01-11 12:00:00+00:00  1919.766733  1923.080691  1916.669998
# 1 2020-01-11 16:00:00+00:00  1931.375485  1936.346774  1927.381312
#
#          close   volume  log_return  return_5     range      body  upper_wick  \
# 0  1919.299481   2930.0    0.008491  0.009944  6.410693 -0.467253    3.313957
# 1  1932.747579  47838.0    0.006982  0.011300  8.965462  1.372094    3.599195
#
#    lower_wick  typical_price       sma_10       ema_10       sma_20  \
# 0    2.629483    1919.683390  1894.999673  1899.518678  1894.144483
# 1    3.994173    1932.158555  1901.368294  1905.560296  1894.839837
#
#         ema_20       sma_50       ema_50  price_vs_sma20  price_vs_ema20  \
# 0  1898.064766  1899.062226  1899.864134        0.013280        0.011188
# 1  1901.367891  1899.550301  1901.153681        0.020006        0.016504
#
#       roc_5    roc_20     rsi_14      macd  macd_signal  macd_hist  \
# 0  0.009994 -0.001028  59.632606  0.312644    -2.611909   2.924553
# 1  0.011364  0.007248  60.926032  3.004204    -1.488686   4.492890
#
#    rolling_std_10  rolling_std_20     atr_14     bb_upper     bb_lower  \
# 0        0.007817        0.006681  14.925703  1923.966090  1864.322876
# 1        0.007651        0.006854  15.391091  1927.590716  1862.088959
#
#    bb_width    bb_pct  volume_ma20  volume_ratio  hour  day_of_week  month  \
# 0  0.031488  0.921758      23461.7      0.124884    12            5      1
# 1  0.034568  1.078729      24575.4      1.946581    16            5      1
#
#    is_london  is_newyork  is_overlap  fft_amp_1  fft_freq_1  sin_fft_phase_1  \
# 0          1           0           0   0.083218    0.140625         0.107106
# 1          0           1           0   0.083332    0.140625         0.845057
#
#    cos_fft_phase_1  fft_amp_2  fft_freq_2  sin_fft_phase_2  cos_fft_phase_2  \
# 0         0.994248   0.056555     0.15625        -0.273547        -0.961859
# 1         0.534676   0.055214     0.15625        -0.926995        -0.375074
#
#    fft_amp_3  fft_freq_3  sin_fft_phase_3  cos_fft_phase_3  fft_amp_4  \
# 0   0.036706       0.125        -0.073157        -0.997320   0.036556
# 1   0.036636       0.125        -0.815479        -0.578786   0.036011
#
#    fft_freq_4  sin_fft_phase_4  cos_fft_phase_4  fft_amp_5  fft_freq_5  \
# 0    0.484375         0.823463        -0.567370   0.034172     0.03125
# 1    0.484375        -0.867388         0.497633   0.034181     0.03125
#
#    sin_fft_phase_5  cos_fft_phase_5  fft_dominant_period  fft_spectral_energy  \
# 0         0.301766         0.953382             7.111111             0.023423
# 1         0.492834         0.870123             7.111111             0.022963
#
#    fft_low_freq_energy  fft_mid_freq_energy  fft_high_freq_energy  \
# 0             0.568719             0.199401              0.231880
# 1             0.573258             0.203439              0.223303
#
#    fft_spectral_entropy  fft_cycle_strength  sin_fft_dominant_phase  \
# 0              3.206927            0.295656                0.107106
# 1              3.201401            0.302407                0.845057
#
#    cos_fft_dominant_phase  target_return_1  target_direction_1  \
# 0                0.994248         0.006982                   1
# 1                0.534676         0.002777                   1
#
#    target_return_5  target_direction_5  target_volatility_5  \
# 0        -0.000920                   0             0.005768
# 1        -0.010895                   0             0.004175
#
#    target_trade_signal_5
# 0                    1.0
# 1                    0.0
# fft_stft (2932, 87)
#                   timestamp         open         high          low  \
# 0 2020-01-11 12:00:00+00:00  1919.766733  1923.080691  1916.669998
# 1 2020-01-11 16:00:00+00:00  1931.375485  1936.346774  1927.381312
#
#          close   volume  log_return  return_5     range      body  upper_wick  \
# 0  1919.299481   2930.0    0.008491  0.009944  6.410693 -0.467253    3.313957
# 1  1932.747579  47838.0    0.006982  0.011300  8.965462  1.372094    3.599195
#
#    lower_wick  typical_price       sma_10       ema_10       sma_20  \
# 0    2.629483    1919.683390  1894.999673  1899.518678  1894.144483
# 1    3.994173    1932.158555  1901.368294  1905.560296  1894.839837
#
#         ema_20       sma_50       ema_50  price_vs_sma20  price_vs_ema20  \
# 0  1898.064766  1899.062226  1899.864134        0.013280        0.011188
# 1  1901.367891  1899.550301  1901.153681        0.020006        0.016504
#
#       roc_5    roc_20     rsi_14      macd  macd_signal  macd_hist  \
# 0  0.009994 -0.001028  59.632606  0.312644    -2.611909   2.924553
# 1  0.011364  0.007248  60.926032  3.004204    -1.488686   4.492890
#
#    rolling_std_10  rolling_std_20     atr_14     bb_upper     bb_lower  \
# 0        0.007817        0.006681  14.925703  1923.966090  1864.322876
# 1        0.007651        0.006854  15.391091  1927.590716  1862.088959
#
#    bb_width    bb_pct  volume_ma20  volume_ratio  hour  day_of_week  month  \
# 0  0.031488  0.921758      23461.7      0.124884    12            5      1
# 1  0.034568  1.078729      24575.4      1.946581    16            5      1
#
#    is_london  is_newyork  is_overlap  fft_amp_1  fft_freq_1  sin_fft_phase_1  \
# 0          1           0           0   0.083218    0.140625         0.107106
# 1          0           1           0   0.083332    0.140625         0.845057
#
#    cos_fft_phase_1  fft_amp_2  fft_freq_2  sin_fft_phase_2  cos_fft_phase_2  \
# 0         0.994248   0.056555     0.15625        -0.273547        -0.961859
# 1         0.534676   0.055214     0.15625        -0.926995        -0.375074
#
#    fft_amp_3  fft_freq_3  sin_fft_phase_3  cos_fft_phase_3  fft_amp_4  \
# 0   0.036706       0.125        -0.073157        -0.997320   0.036556
# 1   0.036636       0.125        -0.815479        -0.578786   0.036011
#
#    fft_freq_4  sin_fft_phase_4  cos_fft_phase_4  fft_amp_5  fft_freq_5  \
# 0    0.484375         0.823463        -0.567370   0.034172     0.03125
# 1    0.484375        -0.867388         0.497633   0.034181     0.03125
#
#    sin_fft_phase_5  cos_fft_phase_5  fft_dominant_period  fft_spectral_energy  \
# 0         0.301766         0.953382             7.111111             0.023423
# 1         0.492834         0.870123             7.111111             0.022963
#
#    fft_low_freq_energy  fft_mid_freq_energy  fft_high_freq_energy  \
# 0             0.568719             0.199401              0.231880
# 1             0.573258             0.203439              0.223303
#
#    fft_spectral_entropy  fft_cycle_strength  sin_fft_dominant_phase  \
# 0              3.206927            0.295656                0.107106
# 1              3.201401            0.302407                0.845057
#
#    cos_fft_dominant_phase  stft_dom_freq  stft_dom_period  stft_low_energy  \
# 0                0.994248        0.15625              6.4         0.457191
# 1                0.534676        0.15625              6.4         0.452674
#
#    stft_mid_energy  stft_high_energy  stft_centroid  stft_entropy  \
# 0         0.209205          0.333604       0.242585      2.559342
# 1         0.193024          0.354302       0.248315      2.570412
#
#    sin_stft_dom_phase  cos_stft_dom_phase  stft_spectral_flux  \
# 0            0.991842           -0.127470            0.000000
# 1            0.497353           -0.867548            0.026658
#
#    target_return_1  target_direction_1  target_return_5  target_direction_5  \
# 0         0.006982                   1        -0.000920                   0
# 1         0.002777                   1        -0.010895                   0
#
#    target_volatility_5  target_trade_signal_5
# 0             0.005768                    1.0
# 1             0.004175                    0.0
# Saved: benchmark_data/features_baseline.parquet
# Saved: benchmark_data/features_fft.parquet
# Saved: benchmark_data/features_fft_stft.parquet

# %% [markdown]
# ## 6. Common utilities for model benchmarking
#
# We evaluate using a strict walk-forward split.
#
# For sequence models, each sample contains a lookback window:
#
# ```text
# X[i] = previous 64 rows × features
# Y[i] = target at current row
# ```
#
# For tree models, each sample is one row.

# %%
def get_feature_cols(df: pd.DataFrame):
    return [c for c in df.columns if c not in TARGET_COLS + ['timestamp']]


def make_splits(n_samples: int, n_splits=5, gap=5):
    return list(TimeSeriesSplit(n_splits=n_splits, gap=gap).split(np.arange(n_samples)))


def summarize_clf(y_true, y_pred, labels=None):
    return {
        'accuracy': float(accuracy_score(y_true, y_pred)),
        'macro_f1': float(f1_score(y_true, y_pred, average='macro', zero_division=0)),
        'weighted_f1': float(f1_score(y_true, y_pred, average='weighted', zero_division=0)),
    }


def safe_display_results(results):
    df = pd.DataFrame(results)
    cols = ['feature_set','target','model','accuracy','macro_f1','weighted_f1','n_features','n_train_avg','n_test_avg']
    cols = [c for c in cols if c in df.columns]
    return df[cols].sort_values(['target','feature_set','accuracy'], ascending=[True, True, False]).reset_index(drop=True)

# %% [markdown]
# ## 7. Tree model benchmark
#
# This is the same family as before, but now it includes the **tradeable movement target**.

# %%
def eval_tree_models(datasets: Dict[str, pd.DataFrame], targets=('target_direction_5','target_trade_signal_5'), n_splits=5, gap=5):
    results = []
    for feat_set, df in datasets.items():
        feat_cols = get_feature_cols(df)
        X_all = df[feat_cols].values.astype(np.float32)
        for target in targets:
            y_all = df[target].values.astype(int)
            splits = make_splits(len(df), n_splits=n_splits, gap=gap)
            model_specs = []
            if HAS_XGB:
                # binary or multiclass
                num_classes = len(np.unique(y_all))
                if num_classes > 2:
                    model_specs.append(('xgboost', lambda: xgb.XGBClassifier(n_estimators=250, max_depth=4, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8, objective='multi:softprob', num_class=num_classes, eval_metric='mlogloss', random_state=SEED, verbosity=0)))
                else:
                    model_specs.append(('xgboost', lambda: xgb.XGBClassifier(n_estimators=250, max_depth=4, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8, eval_metric='logloss', random_state=SEED, verbosity=0)))
            if HAS_LGB:
                model_specs.append(('lightgbm', lambda: lgb.LGBMClassifier(n_estimators=250, max_depth=4, learning_rate=0.05, subsample=0.8, colsample_bytree=0.8, random_state=SEED, verbose=-1)))
            model_specs.append(('random_forest', lambda: RandomForestClassifier(n_estimators=250, max_depth=8, min_samples_leaf=5, random_state=SEED, n_jobs=-1)))
            for model_name, factory in model_specs:
                fold_scores = []
                ntr, nte = [], []
                for tr, te in splits:
                    scaler = StandardScaler()
                    Xtr = scaler.fit_transform(X_all[tr]); Xte = scaler.transform(X_all[te])
                    ytr, yte = y_all[tr], y_all[te]
                    model = factory()
                    model.fit(Xtr, ytr)
                    pred = model.predict(Xte)
                    fold_scores.append(summarize_clf(yte, pred))
                    ntr.append(len(tr)); nte.append(len(te))
                out = {'feature_set': feat_set, 'target': target, 'model': model_name, 'n_features': len(feat_cols), 'n_train_avg': int(np.mean(ntr)), 'n_test_avg': int(np.mean(nte))}
                for metric in fold_scores[0]:
                    out[metric] = float(np.mean([s[metric] for s in fold_scores]))
                    out[metric+'_std'] = float(np.std([s[metric] for s in fold_scores]))
                print(f"{feat_set:9s} | {target:22s} | {model_name:13s} acc={out['accuracy']:.4f} macroF1={out['macro_f1']:.4f}")
                results.append(out)
    return pd.DataFrame(results)

tree_results = eval_tree_models(datasets, targets=('target_direction_5','target_trade_signal_5'), n_splits=5, gap=5)
display(safe_display_results(tree_results.to_dict('records')))
# Out:
# baseline  | target_direction_5     | xgboost       acc=0.8545 macroF1=0.8540
# baseline  | target_direction_5     | lightgbm      acc=0.8406 macroF1=0.8397
# baseline  | target_direction_5     | random_forest acc=0.7832 macroF1=0.7758
# baseline  | target_trade_signal_5  | xgboost       acc=0.7168 macroF1=0.6478
# baseline  | target_trade_signal_5  | lightgbm      acc=0.7102 macroF1=0.6459
# baseline  | target_trade_signal_5  | random_forest acc=0.6500 macroF1=0.5413
# fft       | target_direction_5     | xgboost       acc=0.8738 macroF1=0.8737
# fft       | target_direction_5     | lightgbm      acc=0.8730 macroF1=0.8728
# fft       | target_direction_5     | random_forest acc=0.8324 macroF1=0.8292
# fft       | target_trade_signal_5  | xgboost       acc=0.7377 macroF1=0.6709
# fft       | target_trade_signal_5  | lightgbm      acc=0.7320 macroF1=0.6668
# fft       | target_trade_signal_5  | random_forest acc=0.6926 macroF1=0.5971
# fft_stft  | target_direction_5     | xgboost       acc=0.8705 macroF1=0.8704
# fft_stft  | target_direction_5     | lightgbm      acc=0.8709 macroF1=0.8707
# fft_stft  | target_direction_5     | random_forest acc=0.8230 macroF1=0.8186
# fft_stft  | target_trade_signal_5  | xgboost       acc=0.7475 macroF1=0.6827
# fft_stft  | target_trade_signal_5  | lightgbm      acc=0.7344 macroF1=0.6703
# fft_stft  | target_trade_signal_5  | random_forest acc=0.6758 macroF1=0.5653
#    feature_set                 target          model  accuracy  macro_f1  \
# 0     baseline     target_direction_5        xgboost  0.854508  0.853957
# 1     baseline     target_direction_5       lightgbm  0.840574  0.839742
# 2     baseline     target_direction_5  random_forest  0.783197  0.775757
# 3          fft     target_direction_5        xgboost  0.873770  0.873678
# 4          fft     target_direction_5       lightgbm  0.872951  0.872757
# 5          fft     target_direction_5  random_forest  0.832377  0.829192
# 6     fft_stft     target_direction_5       lightgbm  0.870902  0.870696
# 7     fft_stft     target_direction_5        xgboost  0.870492  0.870383
# 8     fft_stft     target_direction_5  random_forest  0.822951  0.818638
# 9     baseline  target_trade_signal_5        xgboost  0.716803  0.647766
# 10    baseline  target_trade_signal_5       lightgbm  0.710246  0.645907
# 11    baseline  target_trade_signal_5  random_forest  0.650000  0.541298
# 12         fft  target_trade_signal_5        xgboost  0.737705  0.670859
# 13         fft  target_trade_signal_5       lightgbm  0.731967  0.666806
# 14         fft  target_trade_signal_5  random_forest  0.692623  0.597062
# 15    fft_stft  target_trade_signal_5        xgboost  0.747541  0.682650
# 16    fft_stft  target_trade_signal_5       lightgbm  0.734426  0.670286
# 17    fft_stft  target_trade_signal_5  random_forest  0.675820  0.565266
#
#     weighted_f1  n_features  n_train_avg  n_test_avg
# 0      0.853978          41         1463         488
# 1      0.839747          41         1463         488
# 2      0.775632          41         1463         488
# 3      0.873723          70         1463         488
# 4      0.872821          70         1463         488
# 5      0.829103          70         1463         488
# 6      0.870744          80         1463         488
# 7      0.870416          80         1463         488
# 8      0.818461          80         1463         488
# 9      0.691399          41         1463         488
# 10     0.688694          41         1463         488
# 11     0.595482          41         1463         488
# 12     0.714948          70         1463         488
# 13     0.709770          70         1463         488
# 14     0.651573          70         1463         488
# 15     0.725244          80         1463         488
# 16     0.713064          80         1463         488
# 17     0.623908          80         1463         488

# %% [markdown]
# ## 8. Deep sequence model utilities
#
# We now test whether sequence models can exploit the same features better than row-level tree models.
#
# Models included:
#
# - **MLP**: neural tabular baseline using the last row only
# - **LSTM**: sequence memory model
# - **GRU**: lighter recurrent model
# - **TCN**: temporal convolutional network
# - **Real PatchTST classifier**: channel-independent patching, shared patch embedding, Transformer encoder over patches, and classification head
#
# Important: the sequence benchmark uses an **effective gap of `lookback + horizon_gap`** so train and test windows do not share overlapping input history near fold boundaries.

# %%
if HAS_TORCH:
    class SeqDataset(Dataset):
        def __init__(self, X, y):
            self.X = torch.tensor(X, dtype=torch.float32)
            self.y = torch.tensor(y, dtype=torch.long)
        def __len__(self): return len(self.y)
        def __getitem__(self, idx): return self.X[idx], self.y[idx]

    def make_sequence_arrays(df, feat_cols, target_col, lookback=64):
        """
        Build causal supervised sequences.

        For row i, the input contains rows [i-lookback+1, ..., i].
        The target is target_col at row i. The target_col itself must already
        have been shifted forward during target engineering.
        """
        Xraw = df[feat_cols].values.astype(np.float32)
        yraw = df[target_col].values.astype(int)
        Xseq, yseq, idxs = [], [], []
        for i in range(lookback-1, len(df)):
            Xseq.append(Xraw[i-lookback+1:i+1])
            yseq.append(yraw[i])
            idxs.append(i)
        return np.asarray(Xseq, dtype=np.float32), np.asarray(yseq, dtype=np.int64), np.asarray(idxs)

    def train_val_predict_torch(model, Xtr, ytr, Xte, yte, epochs=15, batch_size=128, lr=1e-3, patience=4, verbose=False):
        """Train a PyTorch classifier with time-ordered validation split."""
        n = len(Xtr)
        cut = max(int(n*0.85), 1)
        X_train, y_train = Xtr[:cut], ytr[:cut]
        X_val, y_val = Xtr[cut:], ytr[cut:]
        if len(X_val) < 20:
            X_train, y_train, X_val, y_val = Xtr, ytr, Xtr, ytr

        train_loader = DataLoader(SeqDataset(X_train, y_train), batch_size=batch_size, shuffle=False)
        val_loader = DataLoader(SeqDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

        model = model.to(DEVICE)
        opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        loss_fn = nn.CrossEntropyLoss()
        best_state, best_val = None, 1e9
        bad = 0

        for ep in range(epochs):
            model.train()
            for xb, yb in train_loader:
                xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                opt.zero_grad()
                loss = loss_fn(model(xb), yb)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                opt.step()

            model.eval(); vloss = 0.0
            with torch.no_grad():
                for xb, yb in val_loader:
                    xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                    vloss += loss_fn(model(xb), yb).item() * len(yb)
            vloss /= max(len(X_val), 1)

            if vloss < best_val:
                best_val = vloss
                best_state = {k:v.detach().cpu().clone() for k,v in model.state_dict().items()}
                bad = 0
            else:
                bad += 1
                if bad >= patience:
                    break

        if best_state is not None:
            model.load_state_dict(best_state)

        test_loader = DataLoader(SeqDataset(Xte, yte), batch_size=batch_size, shuffle=False)
        preds=[]
        model.eval()
        with torch.no_grad():
            for xb, yb in test_loader:
                logits = model(xb.to(DEVICE))
                preds.extend(torch.argmax(logits, dim=1).cpu().numpy().tolist())
        return np.array(preds)

    class MLPClassifierNN(nn.Module):
        def __init__(self, n_features, n_classes, hidden=128):
            super().__init__()
            self.net = nn.Sequential(
                nn.Linear(n_features, hidden), nn.ReLU(), nn.Dropout(0.2),
                nn.Linear(hidden, hidden//2), nn.ReLU(), nn.Dropout(0.1),
                nn.Linear(hidden//2, n_classes)
            )
        def forward(self, x):
            if x.ndim == 3:
                x = x[:, -1, :]
            return self.net(x)

    class LSTMClassifier(nn.Module):
        def __init__(self, n_features, n_classes, hidden=96, layers=1):
            super().__init__()
            self.lstm = nn.LSTM(n_features, hidden, num_layers=layers, batch_first=True, dropout=0 if layers==1 else 0.1)
            self.head = nn.Sequential(nn.LayerNorm(hidden), nn.Dropout(0.2), nn.Linear(hidden, n_classes))
        def forward(self, x):
            out, _ = self.lstm(x)
            return self.head(out[:, -1, :])

    class GRUClassifier(nn.Module):
        def __init__(self, n_features, n_classes, hidden=96, layers=1):
            super().__init__()
            self.gru = nn.GRU(n_features, hidden, num_layers=layers, batch_first=True, dropout=0 if layers==1 else 0.1)
            self.head = nn.Sequential(nn.LayerNorm(hidden), nn.Dropout(0.2), nn.Linear(hidden, n_classes))
        def forward(self, x):
            out, _ = self.gru(x)
            return self.head(out[:, -1, :])

    class Chomp1d(nn.Module):
        def __init__(self, chomp_size):
            super().__init__(); self.chomp_size = chomp_size
        def forward(self, x):
            return x[:, :, :-self.chomp_size] if self.chomp_size > 0 else x

    class TCNBlock(nn.Module):
        def __init__(self, in_ch, out_ch, kernel=3, dilation=1):
            super().__init__()
            pad = (kernel-1)*dilation
            self.conv = nn.Sequential(
                nn.Conv1d(in_ch, out_ch, kernel, padding=pad, dilation=dilation), Chomp1d(pad), nn.ReLU(), nn.Dropout(0.15),
                nn.Conv1d(out_ch, out_ch, kernel, padding=pad, dilation=dilation), Chomp1d(pad), nn.ReLU(), nn.Dropout(0.15),
            )
            self.down = nn.Conv1d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()
        def forward(self, x):
            return self.conv(x) + self.down(x)

    class TCNClassifier(nn.Module):
        def __init__(self, n_features, n_classes, hidden=64):
            super().__init__()
            self.net = nn.Sequential(
                TCNBlock(n_features, hidden, dilation=1),
                TCNBlock(hidden, hidden, dilation=2),
                TCNBlock(hidden, hidden, dilation=4),
            )
            self.head = nn.Sequential(nn.AdaptiveAvgPool1d(1), nn.Flatten(), nn.LayerNorm(hidden), nn.Linear(hidden, n_classes))
        def forward(self, x):
            x = x.transpose(1,2)
            z = self.net(x)
            return self.head(z)

    class RevIN(nn.Module):
        """
        Reversible instance normalization, commonly used with PatchTST-style models.
        Here we only use normalization for classification; denormalization is unnecessary.
        """
        def __init__(self, n_features, eps=1e-5, affine=True):
            super().__init__()
            self.eps = eps
            self.affine = affine
            if affine:
                self.weight = nn.Parameter(torch.ones(1, 1, n_features))
                self.bias = nn.Parameter(torch.zeros(1, 1, n_features))
        def forward(self, x):
            # x: [B, T, C]
            mean = x.mean(dim=1, keepdim=True)
            std = x.std(dim=1, keepdim=True).clamp_min(self.eps)
            x = (x - mean) / std
            if self.affine:
                x = x * self.weight + self.bias
            return x

    class PatchTSTClassifier(nn.Module):
        """
        Real PatchTST-style classifier.

        Key PatchTST ideas implemented:
        1. Channel independence: each feature/channel is patched separately.
        2. Shared patch embedding: the same Linear(patch_len -> d_model) is shared across channels.
        3. Transformer encoder operates over patch tokens for each channel.
        4. Classification head aggregates channel embeddings.

        Input:  x [B, T, C]
        Output: logits [B, n_classes]
        """
        def __init__(
            self,
            n_features,
            n_classes,
            lookback=64,
            patch_len=16,
            stride=8,
            d_model=64,
            nhead=4,
            layers=3,
            dropout=0.15,
            use_revin=True,
        ):
            super().__init__()
            assert lookback >= patch_len, "lookback must be >= patch_len"
            self.n_features = n_features
            self.lookback = lookback
            self.patch_len = patch_len
            self.stride = stride
            self.n_patches = 1 + (lookback - patch_len) // stride
            self.use_revin = use_revin
            self.revin = RevIN(n_features) if use_revin else nn.Identity()

            # Shared patch embedding across all channels.
            self.patch_embed = nn.Linear(patch_len, d_model)
            self.pos_embed = nn.Parameter(torch.zeros(1, self.n_patches, d_model))
            self.dropout = nn.Dropout(dropout)

            enc_layer = nn.TransformerEncoderLayer(
                d_model=d_model,
                nhead=nhead,
                dim_feedforward=d_model * 4,
                dropout=dropout,
                batch_first=True,
                activation='gelu',
                norm_first=True,
            )
            self.encoder = nn.TransformerEncoder(enc_layer, num_layers=layers)

            # Each channel becomes one representation after patch pooling.
            # Then all channel embeddings are flattened for classification.
            self.head = nn.Sequential(
                nn.LayerNorm(n_features * d_model),
                nn.Linear(n_features * d_model, 256),
                nn.GELU(),
                nn.Dropout(dropout),
                nn.Linear(256, n_classes),
            )

            nn.init.trunc_normal_(self.pos_embed, std=0.02)

        def forward(self, x):
            # x: [B, T, C]
            B, T, C = x.shape
            x = self.revin(x)

            # Channel independent view: [B, C, T]
            x = x.transpose(1, 2)

            # Patches per channel: [B, C, N, P]
            patches = x.unfold(dimension=2, size=self.patch_len, step=self.stride)
            N = patches.size(2)

            # Shared projection: [B, C, N, D]
            z = self.patch_embed(patches)
            z = z + self.pos_embed[:, :N, :].unsqueeze(1)
            z = self.dropout(z)

            # Transformer over patches, separately per channel: [B*C, N, D]
            z = z.reshape(B * C, N, -1)
            z = self.encoder(z)

            # Pool patches within each channel: [B, C, D]
            z = z.mean(dim=1).reshape(B, C, -1)

            # Flatten channels: [B, C*D]
            z = z.reshape(B, -1)
            return self.head(z)

# %% [markdown]
# ## 9. Run deep sequence benchmark
#
# This section now uses a real PatchTST classifier rather than the previous placeholder Transformer.
#
# PatchTST-specific details:
#
# - Each feature/channel is patched independently.
# - A shared patch embedding maps each patch into the Transformer dimension.
# - The Transformer learns relationships across patches for each channel.
# - Channel embeddings are pooled and sent to the classification head.
# - The split uses a sequence embargo of `lookback + gap` to reduce overlap leakage.

# %%
def eval_deep_models(datasets: Dict[str, pd.DataFrame], targets=('target_direction_5','target_trade_signal_5'), lookback=64, n_splits=5, gap=5, epochs=12):
    if not HAS_TORCH:
        print('PyTorch unavailable; skipping deep benchmark.')
        return pd.DataFrame()
    results=[]
    for feat_set, df in datasets.items():
        feat_cols = get_feature_cols(df)
        for target in targets:
            Xseq, yseq, row_idxs = make_sequence_arrays(df, feat_cols, target, lookback=lookback)
            n_classes = len(np.unique(yseq))

            # Important leakage guard:
            # Since adjacent sequences share input history, use lookback + target gap as the embargo.
            effective_gap = max(gap, lookback + gap)
            splits = make_splits(len(yseq), n_splits=n_splits, gap=effective_gap)

            model_factories = {
                'mlp_last_row': lambda: MLPClassifierNN(len(feat_cols), n_classes),
                'lstm': lambda: LSTMClassifier(len(feat_cols), n_classes),
                'gru': lambda: GRUClassifier(len(feat_cols), n_classes),
                'tcn': lambda: TCNClassifier(len(feat_cols), n_classes),
                'patchtst': lambda: PatchTSTClassifier(
                    len(feat_cols), n_classes,
                    lookback=lookback,
                    patch_len=16,
                    stride=8,
                    d_model=64,
                    nhead=4,
                    layers=3,
                    dropout=0.15,
                    use_revin=True,
                ),
            }
            for model_name, factory in model_factories.items():
                fold_scores=[]; ntr=[]; nte=[]
                for tr, te in splits:
                    # Scale using training fold only, across all timesteps/features.
                    scaler = StandardScaler()
                    B,T,F = Xseq[tr].shape
                    Xtr = scaler.fit_transform(Xseq[tr].reshape(-1,F)).reshape(-1,T,F)
                    Xte = scaler.transform(Xseq[te].reshape(-1,F)).reshape(-1,T,F)
                    ytr, yte = yseq[tr], yseq[te]
                    model = factory()
                    pred = train_val_predict_torch(model, Xtr, ytr, Xte, yte, epochs=epochs, batch_size=128, lr=1e-3, patience=4)
                    fold_scores.append(summarize_clf(yte, pred))
                    ntr.append(len(tr)); nte.append(len(te))
                out = {
                    'feature_set': feat_set,
                    'target': target,
                    'model': model_name,
                    'n_features': len(feat_cols),
                    'lookback': lookback,
                    'sequence_gap': effective_gap,
                    'n_train_avg': int(np.mean(ntr)),
                    'n_test_avg': int(np.mean(nte)),
                }
                for metric in fold_scores[0]:
                    out[metric] = float(np.mean([s[metric] for s in fold_scores]))
                    out[metric+'_std'] = float(np.std([s[metric] for s in fold_scores]))
                print(f"{feat_set:9s} | {target:22s} | {model_name:12s} acc={out['accuracy']:.4f} macroF1={out['macro_f1']:.4f}")
                results.append(out)
    return pd.DataFrame(results)

# This can take several minutes depending on CPU/GPU.
deep_results = eval_deep_models(
    datasets,
    targets=('target_direction_5','target_trade_signal_5'),
    lookback=64,
    n_splits=5,
    gap=5,
    epochs=12,
)

display(safe_display_results(deep_results.to_dict('records')) if len(deep_results) else deep_results)
# Out:
# baseline  | target_direction_5     | mlp_last_row acc=0.7582 macroF1=0.7320
# baseline  | target_direction_5     | lstm         acc=0.8377 macroF1=0.8353
# baseline  | target_direction_5     | gru          acc=0.8598 macroF1=0.8586
# baseline  | target_direction_5     | tcn          acc=0.6561 macroF1=0.6091
# baseline  | target_direction_5     | patchtst     acc=0.7950 macroF1=0.7948
# baseline  | target_trade_signal_5  | mlp_last_row acc=0.6046 macroF1=0.5322
# baseline  | target_trade_signal_5  | lstm         acc=0.6682 macroF1=0.6159
# baseline  | target_trade_signal_5  | gru          acc=0.6854 macroF1=0.6254
# baseline  | target_trade_signal_5  | tcn          acc=0.4582 macroF1=0.3056
# baseline  | target_trade_signal_5  | patchtst     acc=0.6657 macroF1=0.6054
# fft       | target_direction_5     | mlp_last_row acc=0.7540 macroF1=0.7224
# fft       | target_direction_5     | lstm         acc=0.8092 macroF1=0.8032
# fft       | target_direction_5     | gru          acc=0.8192 macroF1=0.8151
# fft       | target_direction_5     | tcn          acc=0.6741 macroF1=0.6505
# fft       | target_direction_5     | patchtst     acc=0.7916 macroF1=0.7902
# fft       | target_trade_signal_5  | mlp_last_row acc=0.6155 macroF1=0.5541
# fft       | target_trade_signal_5  | lstm         acc=0.6556 macroF1=0.5961
# fft       | target_trade_signal_5  | gru          acc=0.6753 macroF1=0.6077
# fft       | target_trade_signal_5  | tcn          acc=0.5000 macroF1=0.3955
# fft       | target_trade_signal_5  | patchtst     acc=0.6611 macroF1=0.6036
# fft_stft  | target_direction_5     | mlp_last_row acc=0.7464 macroF1=0.7155
# fft_stft  | target_direction_5     | lstm         acc=0.8042 macroF1=0.7952
# fft_stft  | target_direction_5     | gru          acc=0.8146 macroF1=0.8094
# fft_stft  | target_direction_5     | tcn          acc=0.6941 macroF1=0.6618
# fft_stft  | target_direction_5     | patchtst     acc=0.7874 macroF1=0.7871
# fft_stft  | target_trade_signal_5  | mlp_last_row acc=0.6117 macroF1=0.5581
# fft_stft  | target_trade_signal_5  | lstm         acc=0.6519 macroF1=0.6031
# fft_stft  | target_trade_signal_5  | gru          acc=0.6883 macroF1=0.6252
# fft_stft  | target_trade_signal_5  | tcn          acc=0.4954 macroF1=0.3785
# fft_stft  | target_trade_signal_5  | patchtst     acc=0.6858 macroF1=0.6108
#    feature_set                 target         model  accuracy  macro_f1  \
# 0     baseline     target_direction_5           gru  0.859833  0.858600
# 1     baseline     target_direction_5          lstm  0.837657  0.835323
# 2     baseline     target_direction_5      patchtst  0.794979  0.794795
# 3     baseline     target_direction_5  mlp_last_row  0.758159  0.731955
# 4     baseline     target_direction_5           tcn  0.656067  0.609137
# 5          fft     target_direction_5           gru  0.819247  0.815072
# 6          fft     target_direction_5          lstm  0.809205  0.803186
# 7          fft     target_direction_5      patchtst  0.791632  0.790192
# 8          fft     target_direction_5  mlp_last_row  0.753975  0.722377
# 9          fft     target_direction_5           tcn  0.674059  0.650461
# 10    fft_stft     target_direction_5           gru  0.814644  0.809364
# 11    fft_stft     target_direction_5          lstm  0.804184  0.795228
# 12    fft_stft     target_direction_5      patchtst  0.787448  0.787073
# 13    fft_stft     target_direction_5  mlp_last_row  0.746444  0.715519
# 14    fft_stft     target_direction_5           tcn  0.694142  0.661760
# 15    baseline  target_trade_signal_5           gru  0.685356  0.625403
# 16    baseline  target_trade_signal_5          lstm  0.668201  0.615866
# 17    baseline  target_trade_signal_5      patchtst  0.665690  0.605370
# 18    baseline  target_trade_signal_5  mlp_last_row  0.604603  0.532160
# 19    baseline  target_trade_signal_5           tcn  0.458159  0.305564
# 20         fft  target_trade_signal_5           gru  0.675314  0.607680
# 21         fft  target_trade_signal_5      patchtst  0.661088  0.603617
# 22         fft  target_trade_signal_5          lstm  0.655649  0.596144
# 23         fft  target_trade_signal_5  mlp_last_row  0.615481  0.554114
# 24         fft  target_trade_signal_5           tcn  0.500000  0.395508
# 25    fft_stft  target_trade_signal_5           gru  0.688285  0.625166
# 26    fft_stft  target_trade_signal_5      patchtst  0.685774  0.610846
# 27    fft_stft  target_trade_signal_5          lstm  0.651883  0.603088
# 28    fft_stft  target_trade_signal_5  mlp_last_row  0.611715  0.558093
# 29    fft_stft  target_trade_signal_5           tcn  0.495397  0.378512
#
#     weighted_f1  n_features  n_train_avg  n_test_avg
# 0      0.858664          41         1366         478
# 1      0.835264          41         1366         478
# 2      0.794784          41         1366         478
# 3      0.732674          41         1366         478
# 4      0.609132          41         1366         478
# 5      0.815307          70         1366         478
# 6      0.803132          70         1366         478
# 7      0.790430          70         1366         478
# 8      0.723018          70         1366         478
# 9      0.650855          70         1366         478
# 10     0.809633          80         1366         478
# 11     0.795100          80         1366         478
# 12     0.787033          80         1366         478
# 13     0.715792          80         1366         478
# 14     0.660678          80         1366         478
# 15     0.663484          41         1366         478
# 16     0.649766          41         1366         478
# 17     0.647399          41         1366         478
# 18     0.565149          41         1366         478
# 19     0.344838          41         1366         478
# 20     0.650485          70         1366         478
# 21     0.644380          70         1366         478
# 22     0.635956          70         1366         478
# 23     0.585835          70         1366         478
# 24     0.433647          70         1366         478
# 25     0.666118          80         1366         478
# 26     0.657296          80         1366         478
# 27     0.640736          80         1366         478
# 28     0.589212          80         1366         478
# 29     0.411066          80         1366         478

# %% [markdown]
# ## 10. Combined benchmark table
#
# This table answers the main question:
#
# > Which model architecture extracts the most useful information from baseline, FFT, and FFT+STFT features?

# %%
all_results = pd.concat([tree_results, deep_results], ignore_index=True) if len(deep_results) else tree_results.copy()

# Save results
os.makedirs('benchmark_results', exist_ok=True)
all_results.to_csv('benchmark_results/model_benchmark_results.csv', index=False)
print('Saved benchmark_results/model_benchmark_results.csv')

display(safe_display_results(all_results.to_dict('records')))

# Pivot: accuracy by model and feature set for each target
for target in all_results['target'].unique():
    print('\nTarget:', target)
    piv = all_results[all_results['target']==target].pivot_table(index='model', columns='feature_set', values='accuracy')
    if {'baseline','fft','fft_stft'}.issubset(set(piv.columns)):
        piv['best'] = piv[['baseline','fft','fft_stft']].max(axis=1)
        piv['uplift_vs_baseline'] = piv['best'] - piv['baseline']
    display(piv.sort_values('best' if 'best' in piv.columns else piv.columns[0], ascending=False))
# Out:
# Saved benchmark_results/model_benchmark_results.csv
#    feature_set                 target          model  accuracy  macro_f1  \
# 0     baseline     target_direction_5            gru  0.859833  0.858600
# 1     baseline     target_direction_5        xgboost  0.854508  0.853957
# 2     baseline     target_direction_5       lightgbm  0.840574  0.839742
# 3     baseline     target_direction_5           lstm  0.837657  0.835323
# 4     baseline     target_direction_5       patchtst  0.794979  0.794795
# 5     baseline     target_direction_5  random_forest  0.783197  0.775757
# 6     baseline     target_direction_5   mlp_last_row  0.758159  0.731955
# 7     baseline     target_direction_5            tcn  0.656067  0.609137
# 8          fft     target_direction_5        xgboost  0.873770  0.873678
# 9          fft     target_direction_5       lightgbm  0.872951  0.872757
# 10         fft     target_direction_5  random_forest  0.832377  0.829192
# 11         fft     target_direction_5            gru  0.819247  0.815072
# 12         fft     target_direction_5           lstm  0.809205  0.803186
# 13         fft     target_direction_5       patchtst  0.791632  0.790192
# 14         fft     target_direction_5   mlp_last_row  0.753975  0.722377
# 15         fft     target_direction_5            tcn  0.674059  0.650461
# 16    fft_stft     target_direction_5       lightgbm  0.870902  0.870696
# 17    fft_stft     target_direction_5        xgboost  0.870492  0.870383
# 18    fft_stft     target_direction_5  random_forest  0.822951  0.818638
# 19    fft_stft     target_direction_5            gru  0.814644  0.809364
# 20    fft_stft     target_direction_5           lstm  0.804184  0.795228
# 21    fft_stft     target_direction_5       patchtst  0.787448  0.787073
# 22    fft_stft     target_direction_5   mlp_last_row  0.746444  0.715519
# 23    fft_stft     target_direction_5            tcn  0.694142  0.661760
# 24    baseline  target_trade_signal_5        xgboost  0.716803  0.647766
# 25    baseline  target_trade_signal_5       lightgbm  0.710246  0.645907
# 26    baseline  target_trade_signal_5            gru  0.685356  0.625403
# 27    baseline  target_trade_signal_5           lstm  0.668201  0.615866
# 28    baseline  target_trade_signal_5       patchtst  0.665690  0.605370
# 29    baseline  target_trade_signal_5  random_forest  0.650000  0.541298
# 30    baseline  target_trade_signal_5   mlp_last_row  0.604603  0.532160
# 31    baseline  target_trade_signal_5            tcn  0.458159  0.305564
# 32         fft  target_trade_signal_5        xgboost  0.737705  0.670859
# 33         fft  target_trade_signal_5       lightgbm  0.731967  0.666806
# 34         fft  target_trade_signal_5  random_forest  0.692623  0.597062
# 35         fft  target_trade_signal_5            gru  0.675314  0.607680
# 36         fft  target_trade_signal_5       patchtst  0.661088  0.603617
# 37         fft  target_trade_signal_5           lstm  0.655649  0.596144
# 38         fft  target_trade_signal_5   mlp_last_row  0.615481  0.554114
# 39         fft  target_trade_signal_5            tcn  0.500000  0.395508
# 40    fft_stft  target_trade_signal_5        xgboost  0.747541  0.682650
# 41    fft_stft  target_trade_signal_5       lightgbm  0.734426  0.670286
# 42    fft_stft  target_trade_signal_5            gru  0.688285  0.625166
# 43    fft_stft  target_trade_signal_5       patchtst  0.685774  0.610846
# 44    fft_stft  target_trade_signal_5  random_forest  0.675820  0.565266
# 45    fft_stft  target_trade_signal_5           lstm  0.651883  0.603088
# 46    fft_stft  target_trade_signal_5   mlp_last_row  0.611715  0.558093
# 47    fft_stft  target_trade_signal_5            tcn  0.495397  0.378512
#
#     weighted_f1  n_features  n_train_avg  n_test_avg
# 0      0.858664          41         1366         478
# 1      0.853978          41         1463         488
# 2      0.839747          41         1463         488
# 3      0.835264          41         1366         478
# 4      0.794784          41         1366         478
# 5      0.775632          41         1463         488
# 6      0.732674          41         1366         478
# 7      0.609132          41         1366         478
# 8      0.873723          70         1463         488
# 9      0.872821          70         1463         488
# 10     0.829103          70         1463         488
# 11     0.815307          70         1366         478
# 12     0.803132          70         1366         478
# 13     0.790430          70         1366         478
# 14     0.723018          70         1366         478
# 15     0.650855          70         1366         478
# 16     0.870744          80         1463         488
# 17     0.870416          80         1463         488
# 18     0.818461          80         1463         488
# 19     0.809633          80         1366         478
# 20     0.795100          80         1366         478
# 21     0.787033          80         1366         478
# 22     0.715792          80         1366         478
# 23     0.660678          80         1366         478
# 24     0.691399          41         1463         488
# 25     0.688694          41         1463         488
# 26     0.663484          41         1366         478
# 27     0.649766          41         1366         478
# 28     0.647399          41         1366         478
# 29     0.595482          41         1463         488
# 30     0.565149          41         1366         478
# 31     0.344838          41         1366         478
# 32     0.714948          70         1463         488
# 33     0.709770          70         1463         488
# 34     0.651573          70         1463         488
# 35     0.650485          70         1366         478
# 36     0.644380          70         1366         478
# 37     0.635956          70         1366         478
# 38     0.585835          70         1366         478
# 39     0.433647          70         1366         478
# 40     0.725244          80         1463         488
# 41     0.713064          80         1463         488
# 42     0.666118          80         1366         478
# 43     0.657296          80         1366         478
# 44     0.623908          80         1463         488
# 45     0.640736          80         1366         478
# 46     0.589212          80         1366         478
# 47     0.411066          80         1366         478
# Target: target_direction_5
# feature_set    baseline       fft  fft_stft      best  uplift_vs_baseline
# model
# xgboost        0.854508  0.873770  0.870492  0.873770            0.019262
# lightgbm       0.840574  0.872951  0.870902  0.872951            0.032377
# gru            0.859833  0.819247  0.814644  0.859833            0.000000
# lstm           0.837657  0.809205  0.804184  0.837657            0.000000
# random_forest  0.783197  0.832377  0.822951  0.832377            0.049180
# patchtst       0.794979  0.791632  0.787448  0.794979            0.000000
# mlp_last_row   0.758159  0.753975  0.746444  0.758159            0.000000
# tcn            0.656067  0.674059  0.694142  0.694142            0.038075
# Target: target_trade_signal_5
# feature_set    baseline       fft  fft_stft      best  uplift_vs_baseline
# model
# xgboost        0.716803  0.737705  0.747541  0.747541            0.030738
# lightgbm       0.710246  0.731967  0.734426  0.734426            0.024180
# random_forest  0.650000  0.692623  0.675820  0.692623            0.042623
# gru            0.685356  0.675314  0.688285  0.688285            0.002929
# patchtst       0.665690  0.661088  0.685774  0.685774            0.020084
# lstm           0.668201  0.655649  0.651883  0.668201            0.000000
# mlp_last_row   0.604603  0.615481  0.611715  0.615481            0.010879
# tcn            0.458159  0.500000  0.495397  0.500000            0.041841

# %% [markdown]
# ## 11. Visualize benchmark results

# %%
if len(all_results):
    for target in all_results['target'].unique():
        sub = all_results[all_results['target']==target].copy()
        plt.figure(figsize=(12,5))
        labels = sub['model'] + ' | ' + sub['feature_set']
        order = np.argsort(sub['accuracy'].values)[::-1]
        plt.bar(np.arange(len(sub)), sub['accuracy'].values[order])
        plt.xticks(np.arange(len(sub)), labels.values[order], rotation=80, ha='right')
        plt.title(f'Accuracy benchmark — {target}')
        plt.ylabel('Accuracy')
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## 12. Interpretation guide
#
# Use this logic:
#
# ### Case A — Deep sequence models beat tree models
#
# Then the issue was probably architecture. FFT/STFT may need sequential learning.
#
# ### Case B — FFT/STFT improves trees and sequence models
#
# Then frequency-domain features carry robust predictive information.
#
# ### Case C — FFT/STFT improves only tree models
#
# Then FFT/STFT may be acting as handcrafted temporal memory. Sequence models may already learn similar temporal structure from the raw sequence.
#
# ### Case D — Real PatchTST improves strongly
#
# Then patch-based temporal modeling is a promising path, and the previous placeholder result should be ignored.
#
# ### Case E — No architecture improves beyond baseline
#
# Then the problem is likely target definition, missing external variables such as DXY/yields/news, or genuine market noise.

# %% [markdown]
# ## 13. Bridge to Phase 2 — Market regime discovery
#
# After this benchmark, Phase 2 should only begin once we know whether architecture was the bottleneck.
#
# If FFT/STFT still mainly helps volatility/tradeable movement, Phase 2 becomes:
#
# ```text
# FFT + STFT + indicators
# ↓
# market regime discovery
# ↓
# predict regime
# ↓
# condition directional models on regime
# ```

# %%
# Optional starter for Phase 2 regime discovery
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

regime_df = datasets['fft_stft'].copy()
feature_cols = get_feature_cols(regime_df)
X = regime_df[feature_cols].values.astype(np.float32)
X = StandardScaler().fit_transform(X)

pca = PCA(n_components=8, random_state=SEED)
Z = pca.fit_transform(X)
print('PCA explained variance:', pca.explained_variance_ratio_.round(3), 'total=', pca.explained_variance_ratio_.sum().round(3))

scores=[]
for k in range(3,9):
    km = KMeans(n_clusters=k, random_state=SEED, n_init='auto')
    lab = km.fit_predict(Z)
    scores.append((k, silhouette_score(Z, lab)))
print('Silhouette scores:', scores)

best_k = max(scores, key=lambda x: x[1])[0]
km = KMeans(n_clusters=best_k, random_state=SEED, n_init='auto')
regime_df['discovered_regime'] = km.fit_predict(Z)
print('Best k:', best_k)
display(regime_df['discovered_regime'].value_counts().sort_index())

plt.figure(figsize=(8,6))
plt.scatter(Z[:,0], Z[:,1], c=regime_df['discovered_regime'], s=5, alpha=0.6)
plt.title('Discovered market regimes — PCA view')
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.tight_layout(); plt.show()
# Out:
# PCA explained variance: [0.167 0.094 0.076 0.047 0.043 0.04  0.036 0.033] total= 0.536
# Silhouette scores: [(3, np.float32(0.15758008)), (4, np.float32(0.15855375)), (5, np.float32(0.14745523)), (6, np.float32(0.13633637)), (7, np.float32(0.121904425)), (8, np.float32(0.12459173))]
# Best k: 4
# discovered_regime
# 0     711
# 1     511
# 2     637
# 3    1073
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# # Phase 1C — Audited Advanced Transformer Benchmark
#
# This section upgrades the benchmark in four ways:
#
# 1. **Faithful PatchTST core**: channel independence, shared patch embedding, configurable `patch_len` / `stride`, learnable positional embedding over patches, and long contexts such as 256 and 512 candles.
# 2. **Long-context testing**: PatchTST is tested at longer lookbacks because the original PatchTST idea is especially useful when attention can see a longer history.
# 3. **Modern time-series Transformer baselines**: compact classifier adaptations of iTransformer, TimesNet, and FEDformer are added.
# 4. **Final leakage audit**: sequence splitting, scaling, and target alignment are checked again before results are trusted.
#
# The implementation is **classifier-adapted** because our targets are `target_direction_5` and `target_trade_signal_5`, not future-value forecasting. The backbone ideas follow the papers:
#
# - PatchTST: patching + channel independence + shared weights across channels. Source: https://arxiv.org/abs/2211.14730
# - iTransformer: invert the usual Transformer dimensions so variables become tokens and each token embeds the full lookback. Source: https://arxiv.org/abs/2310.06625
# - TimesNet: discover dominant periods and reshape 1D time series into 2D period tensors. Source: https://arxiv.org/abs/2210.02186
# - FEDformer: use seasonal/trend decomposition and frequency-domain filtering. Source: https://proceedings.mlr.press/v162/zhou22g.html
#
# Important naming: these are **classification adaptations** of the backbones, not drop-in official forecasting scripts.

# %%
import os, json, math, warnings, random
from pathlib import Path
from dataclasses import dataclass
from typing import Dict, List, Tuple, Optional

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import entropy as scipy_entropy
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings('ignore')

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

try:
    import xgboost as xgb
    HAS_XGB = True
except Exception as e:
    HAS_XGB = False
    print('XGBoost unavailable:', e)

try:
    import lightgbm as lgb
    HAS_LGB = True
except Exception as e:
    HAS_LGB = False
    print('LightGBM unavailable:', e)

try:
    import torch
    import torch.nn as nn
    from torch.utils.data import Dataset, DataLoader
    HAS_TORCH = True
    DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
    torch.manual_seed(SEED)
    print('Torch device:', DEVICE)
except Exception as e:
    HAS_TORCH = False
    DEVICE = 'cpu'
    print('PyTorch unavailable:', e)

pd.set_option('display.max_columns', 120)

# ============================================================
# Phase 1C — Evaluation audit utilities
# ============================================================

ADVANCED_TARGETS = ['target_direction_5', 'target_trade_signal_5']
DEFAULT_HORIZON = 5


def class_distribution_report(datasets, targets=ADVANCED_TARGETS):
    print('=== Class distribution by feature set and target ===')
    for fs, df in datasets.items():
        print(f'\n[{fs}] rows={len(df):,}')
        for target in targets:
            if target not in df.columns:
                print(f'  {target}: missing')
                continue
            counts = df[target].value_counts(dropna=False).sort_index()
            pct = (counts / len(df) * 100).round(2)
            print(f'  {target}:')
            for k in counts.index:
                print(f'    class {k}: {counts.loc[k]:>6}  ({pct.loc[k]:>5.2f}%)')


def audit_feature_safety(datasets):
    print('=== Feature safety audit ===')
    lengths = {k: len(v) for k, v in datasets.items()}
    print('Row counts:', lengths)
    assert len(set(lengths.values())) == 1, 'Dataset row counts differ. Ablation is not aligned.'
    for fs, df in datasets.items():
        feat_cols = get_feature_cols(df)
        bad = [c for c in feat_cols if c.startswith('target_') or c == 'timestamp']
        assert not bad, f'{fs}: target/meta columns leaked into features: {bad}'
        nan_count = df[feat_cols + [c for c in ADVANCED_TARGETS if c in df.columns]].isna().sum().sum()
        print(f'{fs:10s} features={len(feat_cols):3d}  NaNs in features/targets={nan_count}')
    print('✓ Feature sets are aligned and target columns are excluded from inputs.')


def make_sequence_arrays_with_index(df, feat_cols, target_col, lookback=256):
    """
    Create causal sequence samples.

    For sample ending at row i:
      input rows = [i-lookback+1, ..., i]
      target     = target_col[i]

    target_col must already be a forward-looking label created during target engineering.
    """
    valid = df[feat_cols + [target_col]].dropna().copy()
    Xraw = valid[feat_cols].values.astype(np.float32)
    yraw = valid[target_col].values.astype(int)
    # valid.index keeps original aligned row indices after dropna
    original_idx = valid.index.to_numpy()

    Xseq, yseq, end_idxs = [], [], []
    for j in range(lookback - 1, len(valid)):
        Xseq.append(Xraw[j - lookback + 1:j + 1])
        yseq.append(yraw[j])
        end_idxs.append(original_idx[j])
    return np.asarray(Xseq, dtype=np.float32), np.asarray(yseq, dtype=np.int64), np.asarray(end_idxs, dtype=np.int64)


def make_audited_sequence_splits(n_rows, end_idxs, lookback, horizon=5, n_splits=5):
    """
    Leakage-safe row-based split for sequence models.

    We split on original row positions, not on already-built sequences.
    The embargo is lookback + horizon so the test input window cannot overlap
    with training input/target regions near the fold boundary.
    Dynamically reduces n_splits if the requested number of splits cannot be formed
    due to insufficient data or large embargo.
    """
    embargo = lookback + horizon
    current_n_splits = n_splits
    final_splits = []

    while current_n_splits >= 1: # Try to find a valid number of splits down to 1
        try:
            # TimeSeriesSplit's n_samples refers to the input to .split(), which is np.arange(n_rows).
            # The gap parameter here is the embargo between train and test sets.
            tss = TimeSeriesSplit(n_splits=current_n_splits, gap=embargo)
            row_splits_generator = tss.split(np.arange(n_rows))

            # Convert generator to list to trigger any ValueError from TimeSeriesSplit
            # if the number of splits is too high for the given n_rows and gap.
            row_splits = list(row_splits_generator)

            # Process valid splits
            temp_splits = [] # Use a temporary list for splits in this iteration
            for fold, (train_rows, test_rows) in enumerate(row_splits):
                train_start, train_end = train_rows[0], train_rows[-1]
                test_start, test_end = test_rows[0], test_rows[-1]

                train_mask = (end_idxs >= train_start + lookback - 1) & (end_idxs <= train_end)
                test_mask  = (end_idxs >= test_start + lookback - 1) & (end_idxs <= test_end)

                tr = np.where(train_mask)[0]
                te = np.where(test_mask)[0]
                if len(tr) == 0 or len(te) == 0:
                    # If a fold results in empty train/test sequences after masking, skip it.
                    # This can happen if the embargo is very large and leaves no space for sequences.
                    continue

                # Safety check: max train target reach must be before min test input start.
                # This ensures no leakage where future information influences training.
                max_train_target_row = end_idxs[tr].max() + horizon
                min_test_input_row   = end_idxs[te].min() - lookback + 1
                assert max_train_target_row < min_test_input_row, (
                    f'Leakage risk fold {fold}: train target reaches {max_train_target_row}, '
                    f'test input starts {min_test_input_row}'
                )
                temp_splits.append((tr, te))

            if temp_splits: # If we successfully created at least one non-empty split in this attempt
                final_splits = temp_splits
                return final_splits
            else: # All splits were empty, try reducing current_n_splits
                print(f"Warning: All splits for n_splits={current_n_splits} and lookback={lookback}, embargo={embargo} resulted in empty train/test sets. Reducing splits...")
                current_n_splits -= 1

        except ValueError as e:
            if "Too many splits" in str(e):
                print(f"Warning: Failed to create {current_n_splits} splits with lookback={lookback}, embargo={embargo}. Error: '{e}'. Reducing splits...")
                current_n_splits -= 1
            else:
                # Re-raise other ValueErrors that are not related to "Too many splits"
                raise e

    print(f"Error: Could not create any valid sequence splits for lookback={lookback}, horizon={horizon} with initial n_splits={n_splits}.")
    return [] # Return empty list if no valid splits could be formed


def audit_sequence_splitting(datasets, lookbacks=(64, 256, 512), target='target_trade_signal_5', horizon=5, n_splits=5):
    print('=== Sequence splitting audit ===')
    fs = next(iter(datasets.keys()))
    df = datasets[fs]
    feat_cols = get_feature_cols(df)
    for lookback in lookbacks:
        Xseq, yseq, end_idxs = make_sequence_arrays_with_index(df, feat_cols, target, lookback=lookback)
        splits = make_audited_sequence_splits(len(df), end_idxs, lookback, horizon=horizon, n_splits=n_splits)
        print(f'lookback={lookback:>3} | sequences={len(Xseq):>6} | folds={len(splits)}')
        for k, (tr, te) in enumerate(splits[:2]):
            print(f'  fold {k}: train={len(tr):>5}, test={len(te):>5}, '
                  f'train_end={end_idxs[tr].max()}, test_input_start={end_idxs[te].min()-lookback+1}')
    print('✓ Sequence splits use row-based embargo and pass boundary checks.')


# Run the audit before advanced training.
audit_feature_safety(datasets)
class_distribution_report(datasets, ADVANCED_TARGETS)
audit_sequence_splitting(datasets, lookbacks=(64, 256, 512), target='target_trade_signal_5', horizon=DEFAULT_HORIZON, n_splits=5)
# Out:
# Torch device: cuda
# === Feature safety audit ===
# Row counts: {'baseline': 2932, 'fft': 2932, 'fft_stft': 2932}
# baseline   features= 41  NaNs in features/targets=0
# fft        features= 70  NaNs in features/targets=0
# fft_stft   features= 80  NaNs in features/targets=0
# ✓ Feature sets are aligned and target columns are excluded from inputs.
# === Class distribution by feature set and target ===
#
# [baseline] rows=2,932
#   target_direction_5:
#     class 0:   1459  (49.76%)
#     class 1:   1473  (50.24%)
#   target_trade_signal_5:
#     class 0.0:   1108  (37.79%)
#     class 1.0:    688  (23.47%)
#     class 2.0:   1136  (38.74%)
#
# [fft] rows=2,932
#   target_direction_5:
#     class 0:   1459  (49.76%)
#     class 1:   1473  (50.24%)
#   target_trade_signal_5:
#     class 0.0:   1108  (37.79%)
#     class 1.0:    688  (23.47%)
#     class 2.0:   1136  (38.74%)
#
# [fft_stft] rows=2,932
#   target_direction_5:
#     class 0:   1459  (49.76%)
#     class 1:   1473  (50.24%)
#   target_trade_signal_5:
#     class 0.0:   1108  (37.79%)
#     class 1.0:    688  (23.47%)
#     class 2.0:   1136  (38.74%)
# === Sequence splitting audit ===
# lookback= 64 | sequences=  2869 | folds=5
#   fold 0: train=  360, test=  425, train_end=422, test_input_start=492
#   fold 1: train=  848, test=  425, train_end=910, test_input_start=980
# lookback=256 | sequences=  2677 | folds=4
#   fold 0: train=  464, test=  233, train_end=718, test_input_start=980
#   fold 1: train=  952, test=  233, train_end=1206, test_input_start=1468
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
# lookback=512 | sequences=  2421 | folds=3
#   fold 0: train=  146, test=   75, train_end=656, test_input_start=1174
#   fold 1: train=  732, test=   75, train_end=1242, test_input_start=1760
# ✓ Sequence splits use row-based embargo and pass boundary checks.

# %%
# ============================================================
# Phase 1C — Advanced sequence backbones
# ============================================================

if HAS_TORCH:
    class AdvancedSeqDataset(Dataset):
        def __init__(self, X, y):
            self.X = torch.tensor(X, dtype=torch.float32)
            self.y = torch.tensor(y, dtype=torch.long)
        def __len__(self): return len(self.y)
        def __getitem__(self, idx): return self.X[idx], self.y[idx]

    def train_val_predict_torch_advanced(model, Xtr, ytr, Xte, yte,
                                         epochs=10, batch_size=128, lr=1e-3,
                                         patience=3, class_weight=True):
        """Train with time-ordered validation and training-fold-only scaling handled outside."""
        n = len(Xtr)
        cut = max(int(n * 0.85), 1)
        X_train, y_train = Xtr[:cut], ytr[:cut]
        X_val, y_val = Xtr[cut:], ytr[cut:]
        if len(X_val) < 20:
            X_train, y_train, X_val, y_val = Xtr, ytr, Xtr, ytr

        train_loader = DataLoader(AdvancedSeqDataset(X_train, y_train), batch_size=batch_size, shuffle=False)
        val_loader = DataLoader(AdvancedSeqDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

        model = model.to(DEVICE)
        opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

        if class_weight:
            classes, counts = np.unique(y_train, return_counts=True)
            weights = np.ones(int(max(classes)) + 1, dtype=np.float32)
            total = counts.sum()
            for cls, cnt in zip(classes, counts):
                weights[int(cls)] = total / (len(classes) * max(cnt, 1))
            weight_tensor = torch.tensor(weights, dtype=torch.float32, device=DEVICE)
            loss_fn = nn.CrossEntropyLoss(weight=weight_tensor)
        else:
            loss_fn = nn.CrossEntropyLoss()

        best_state, best_val, bad = None, 1e9, 0
        for ep in range(epochs):
            model.train()
            for xb, yb in train_loader:
                xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                opt.zero_grad()
                loss = loss_fn(model(xb), yb)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                opt.step()

            model.eval(); vloss = 0.0
            with torch.no_grad():
                for xb, yb in val_loader:
                    xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                    vloss += loss_fn(model(xb), yb).item() * len(yb)
            vloss /= max(len(X_val), 1)
            if vloss < best_val:
                best_val = vloss
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
                bad = 0
            else:
                bad += 1
                if bad >= patience:
                    break

        if best_state is not None:
            model.load_state_dict(best_state)

        test_loader = DataLoader(AdvancedSeqDataset(Xte, yte), batch_size=batch_size, shuffle=False)
        preds = []
        model.eval()
        with torch.no_grad():
            for xb, _ in test_loader:
                logits = model(xb.to(DEVICE))
                preds.extend(torch.argmax(logits, dim=1).cpu().numpy().tolist())
        return np.asarray(preds)

    class RevINAdvanced(nn.Module):
        def __init__(self, n_features, eps=1e-5, affine=True):
            super().__init__()
            self.eps = eps
            self.affine = affine
            if affine:
                self.weight = nn.Parameter(torch.ones(1, 1, n_features))
                self.bias = nn.Parameter(torch.zeros(1, 1, n_features))
        def forward(self, x):
            mean = x.mean(dim=1, keepdim=True)
            std = x.std(dim=1, keepdim=True).clamp_min(self.eps)
            x = (x - mean) / std
            if self.affine:
                x = x * self.weight + self.bias
            return x

    class PatchTSTOriginalClassifier(nn.Module):
        """
        PatchTST classifier adaptation with faithful core design:
        - channel independence: each variable is treated as a univariate series
        - shared patch embedding across all variables
        - shared Transformer encoder across all variables
        - configurable patch length, stride, and end padding
        - learnable positional embedding over patch tokens
        - shared per-channel head, then channel pooling for classification

        Input:  [B, T, C]
        Output: [B, n_classes]
        """
        def __init__(self, n_features, n_classes, lookback=256, patch_len=16, stride=8,
                     d_model=128, nhead=8, layers=3, dropout=0.15, use_revin=True,
                     padding_patch='end', head_dim=128):
            super().__init__()
            assert lookback >= patch_len, 'lookback must be >= patch_len'
            self.n_features = n_features
            self.lookback = lookback
            self.patch_len = patch_len
            self.stride = stride
            self.padding_patch = padding_patch
            self.use_revin = use_revin
            self.revin = RevINAdvanced(n_features) if use_revin else nn.Identity()

            # Compute number of patches after optional end padding.
            if padding_patch == 'end':
                self.pad_len = (stride - ((lookback - patch_len) % stride)) % stride
            else:
                self.pad_len = 0
            self.n_patches = 1 + (lookback + self.pad_len - patch_len) // stride

            # Shared patch embedding and learnable positional encoding.
            self.patch_embed = nn.Linear(patch_len, d_model)
            self.pos_embed = nn.Parameter(torch.zeros(1, self.n_patches, d_model))
            self.dropout = nn.Dropout(dropout)

            enc_layer = nn.TransformerEncoderLayer(
                d_model=d_model,
                nhead=nhead,
                dim_feedforward=d_model * 4,
                dropout=dropout,
                activation='gelu',
                batch_first=True,
                norm_first=True,
            )
            self.encoder = nn.TransformerEncoder(enc_layer, num_layers=layers)

            # Original PatchTST forecasting head flattens patch embeddings per channel.
            # Here we use the same idea to create per-channel classification representations.
            self.channel_head = nn.Sequential(
                nn.Flatten(start_dim=1),
                nn.LayerNorm(self.n_patches * d_model),
                nn.Linear(self.n_patches * d_model, head_dim),
                nn.GELU(),
                nn.Dropout(dropout),
            )
            self.classifier = nn.Sequential(
                nn.LayerNorm(head_dim),
                nn.Linear(head_dim, n_classes),
            )
            nn.init.trunc_normal_(self.pos_embed, std=0.02)

        def forward(self, x):
            # x: [B, T, C]
            B, T, C = x.shape
            x = self.revin(x)
            x = x.transpose(1, 2)  # [B, C, T]

            if self.pad_len > 0:
                # Replicate the last time point, matching PatchTST-style end padding.
                pad = x[:, :, -1:].repeat(1, 1, self.pad_len)
                x = torch.cat([x, pad], dim=2)

            patches = x.unfold(dimension=2, size=self.patch_len, step=self.stride)  # [B,C,N,P]
            N = patches.size(2)
            z = self.patch_embed(patches)  # [B,C,N,D]
            z = z + self.pos_embed[:, :N, :].unsqueeze(1)
            z = self.dropout(z)

            # Shared encoder independently per channel.
            z = z.reshape(B * C, N, -1)
            z = self.encoder(z)

            # Shared head per channel, then pool across channels.
            z = self.channel_head(z)       # [B*C, head_dim]
            z = z.reshape(B, C, -1).mean(dim=1)
            return self.classifier(z)

    class iTransformerClassifier(nn.Module):
        """
        iTransformer classifier adaptation.
        Variables become tokens. Each token embeds the full lookback trajectory.
        Attention is applied across variables, not across time points.
        """
        def __init__(self, n_features, n_classes, lookback=256, d_model=128, nhead=8, layers=3, dropout=0.15, use_revin=True):
            super().__init__()
            self.revin = RevINAdvanced(n_features) if use_revin else nn.Identity()
            self.value_embedding = nn.Linear(lookback, d_model)
            self.var_embed = nn.Parameter(torch.zeros(1, n_features, d_model))
            enc_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=d_model*4,
                                                   dropout=dropout, batch_first=True, activation='gelu', norm_first=True)
            self.encoder = nn.TransformerEncoder(enc_layer, num_layers=layers)
            self.head = nn.Sequential(nn.LayerNorm(d_model), nn.Dropout(dropout), nn.Linear(d_model, n_classes))
            nn.init.trunc_normal_(self.var_embed, std=0.02)
        def forward(self, x):
            # [B,T,C] -> [B,C,T]
            x = self.revin(x).transpose(1, 2)
            z = self.value_embedding(x) + self.var_embed[:, :x.size(1), :]
            z = self.encoder(z)
            z = z.mean(dim=1)
            return self.head(z)

    class InceptionBlock2D(nn.Module):
        def __init__(self, in_ch, out_ch, kernels=(1,3,5), dropout=0.1):
            super().__init__()
            self.convs = nn.ModuleList([
                nn.Conv2d(in_ch, out_ch, kernel_size=(k,k), padding=(k//2,k//2)) for k in kernels
            ])
            self.proj = nn.Conv2d(out_ch * len(kernels), out_ch, kernel_size=1)
            self.act = nn.GELU()
            self.drop = nn.Dropout(dropout)
        def forward(self, x):
            z = torch.cat([conv(x) for conv in self.convs], dim=1)
            return self.drop(self.act(self.proj(z)))

    def timesnet_top_periods(x, k=3):
        # x: [B,T,C]
        xf = torch.fft.rfft(x, dim=1)
        amp = xf.abs().mean(dim=0).mean(dim=-1)  # [freq]
        amp[0] = 0
        k = min(k, len(amp)-1)
        vals, idx = torch.topk(amp, k)
        periods = torch.clamp(x.shape[1] // idx.clamp_min(1), min=2)
        weights = torch.softmax(vals, dim=0)
        return periods.detach().cpu().tolist(), weights

    class TimesBlockClassifier(nn.Module):
        """Compact TimesNet-style classifier block using FFT-discovered periods and 2D convolutions."""
        def __init__(self, n_features, n_classes, lookback=256, d_model=64, top_k=3, layers=2, dropout=0.15, use_revin=True):
            super().__init__()
            self.lookback = lookback
            self.top_k = top_k
            self.revin = RevINAdvanced(n_features) if use_revin else nn.Identity()
            self.input_proj = nn.Linear(n_features, d_model)
            self.blocks = nn.ModuleList([InceptionBlock2D(d_model, d_model, dropout=dropout) for _ in range(layers)])
            self.norm = nn.LayerNorm(d_model)
            self.head = nn.Sequential(nn.LayerNorm(d_model), nn.Dropout(dropout), nn.Linear(d_model, n_classes))
        def forward(self, x):
            # [B,T,C] -> [B,T,D]
            x = self.revin(x)
            z = self.input_proj(x)
            B, T, D = z.shape
            periods, weights = timesnet_top_periods(z, k=self.top_k)
            outs = []
            for p in periods:
                p = int(max(2, p))
                length = math.ceil(T / p) * p
                if length > T:
                    pad = z[:, -1:, :].repeat(1, length-T, 1)
                    zp = torch.cat([z, pad], dim=1)
                else:
                    zp = z
                # [B,length,D] -> [B,D,length//p,p]
                zp = zp.reshape(B, length // p, p, D).permute(0, 3, 1, 2)
                for block in self.blocks:
                    zp = zp + block(zp)
                zp = zp.permute(0, 2, 3, 1).reshape(B, length, D)[:, :T, :]
                outs.append(zp)
            stacked = torch.stack(outs, dim=-1)  # [B,T,D,K]
            w = weights.to(z.device).view(1,1,1,-1)
            z = (stacked * w).sum(dim=-1)
            z = self.norm(z).mean(dim=1)
            return self.head(z)

    class MovingAvg(nn.Module):
        def __init__(self, kernel_size=25):
            super().__init__()
            self.kernel_size = kernel_size
            self.avg = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=0)
        def forward(self, x):
            # x: [B,T,C]
            pad = (self.kernel_size - 1) // 2
            front = x[:, 0:1, :].repeat(1, pad, 1)
            end = x[:, -1:, :].repeat(1, pad, 1)
            xp = torch.cat([front, x, end], dim=1)
            return self.avg(xp.transpose(1,2)).transpose(1,2)

    class FourierFilter(nn.Module):
        """Keep low-frequency Fourier modes as a compact FEDformer-style frequency filter."""
        def __init__(self, modes=32):
            super().__init__()
            self.modes = modes
        def forward(self, x):
            # x: [B,T,D]
            xf = torch.fft.rfft(x, dim=1)
            out = torch.zeros_like(xf)
            m = min(self.modes, xf.shape[1])
            out[:, :m, :] = xf[:, :m, :]
            return torch.fft.irfft(out, n=x.shape[1], dim=1)

    class FEDformerLiteClassifier(nn.Module):
        """
        FEDformer-inspired classifier adaptation:
        moving-average decomposition + low-frequency Fourier filtering + Transformer encoder.
        """
        def __init__(self, n_features, n_classes, lookback=256, d_model=128, nhead=8, layers=2, modes=32, dropout=0.15, use_revin=True):
            super().__init__()
            self.revin = RevINAdvanced(n_features) if use_revin else nn.Identity()
            self.decomp = MovingAvg(kernel_size=25)
            self.proj = nn.Linear(n_features * 2, d_model)
            self.freq = FourierFilter(modes=modes)
            enc_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=d_model*4,
                                                   dropout=dropout, batch_first=True, activation='gelu', norm_first=True)
            self.encoder = nn.TransformerEncoder(enc_layer, num_layers=layers)
            self.head = nn.Sequential(nn.LayerNorm(d_model), nn.Dropout(dropout), nn.Linear(d_model, n_classes))
        def forward(self, x):
            x = self.revin(x)
            trend = self.decomp(x)
            seasonal = x - trend
            seasonal = self.freq(seasonal)
            z = torch.cat([seasonal, trend], dim=-1)
            z = self.proj(z)
            z = self.encoder(z).mean(dim=1)
            return self.head(z)
else:
    print('PyTorch is unavailable, so advanced models were not defined.')

# %%
# ============================================================
# Phase 1C — Advanced benchmark runner
# ============================================================

ADVANCED_CONFIG = {
    # Increase these for the final experiment. Keep small while debugging.
    'targets': ['target_direction_5', 'target_trade_signal_5'],
    'feature_sets': ['baseline', 'fft', 'fft_stft'],
    'n_splits': 5,
    'horizon': 5,
    'epochs': 8,
    'batch_size': 128,
    'lr': 1e-3,
    # Long context tests. PatchTST should benefit most from 256/512.
    'model_grid': [
        {'name': 'lstm_L256',       'family': 'lstm',       'lookback': 256},
        {'name': 'gru_L256',        'family': 'gru',        'lookback': 256},
        {'name': 'patchtst_L256',   'family': 'patchtst',   'lookback': 256, 'patch_len': 16, 'stride': 8},
        {'name': 'patchtst_L512',   'family': 'patchtst',   'lookback': 512, 'patch_len': 32, 'stride': 16},
        {'name': 'itransformer_L256','family': 'itransformer','lookback': 256},
        {'name': 'timesnet_L256',   'family': 'timesnet',   'lookback': 256},
        {'name': 'fedformer_L256',  'family': 'fedformer',  'lookback': 256},
    ]
}


def make_advanced_model(spec, n_features, n_classes):
    family = spec['family']
    L = spec.get('lookback', 256)
    if family == 'lstm':
        return LSTMClassifier(n_features, n_classes, hidden=128, layers=1)
    if family == 'gru':
        return GRUClassifier(n_features, n_classes, hidden=128, layers=1)
    if family == 'patchtst':
        return PatchTSTOriginalClassifier(
            n_features=n_features,
            n_classes=n_classes,
            lookback=L,
            patch_len=spec.get('patch_len', 16),
            stride=spec.get('stride', 8),
            d_model=128,
            nhead=8,
            layers=3,
            dropout=0.15,
            use_revin=True,
            padding_patch='end',
            head_dim=128,
        )
    if family == 'itransformer':
        return iTransformerClassifier(n_features, n_classes, lookback=L, d_model=128, nhead=8, layers=3, dropout=0.15)
    if family == 'timesnet':
        return TimesBlockClassifier(n_features, n_classes, lookback=L, d_model=64, top_k=3, layers=2, dropout=0.15)
    if family == 'fedformer':
        return FEDformerLiteClassifier(n_features, n_classes, lookback=L, d_model=128, nhead=8, layers=2, modes=32, dropout=0.15)
    raise ValueError(f'Unknown model family: {family}')


def eval_advanced_sequence_models(datasets, config=ADVANCED_CONFIG):
    if not HAS_TORCH:
        print('PyTorch unavailable; skipping advanced benchmark.')
        return pd.DataFrame()

    rows = []
    for fs in config['feature_sets']:
        df = datasets[fs]
        feat_cols = get_feature_cols(df)
        for target in config['targets']:
            for spec in config['model_grid']:
                model_name = spec['name']
                lookback = spec['lookback']
                Xseq, yseq, end_idxs = make_sequence_arrays_with_index(df, feat_cols, target, lookback=lookback)
                n_classes = len(np.unique(yseq))
                if len(Xseq) < 1000:
                    print(f'Skipping {fs}/{target}/{model_name}: too few sequences ({len(Xseq)})')
                    continue
                splits = make_audited_sequence_splits(
                    n_rows=len(df),
                    end_idxs=end_idxs,
                    lookback=lookback,
                    horizon=config['horizon'],
                    n_splits=config['n_splits'],
                )
                fold_metrics, ntr, nte = [], [], []
                print(f'\n{fs:9s} | {target:22s} | {model_name:18s} | L={lookback}')
                for fold, (tr, te) in enumerate(splits):
                    scaler = StandardScaler()
                    B, T, F = Xseq[tr].shape
                    Xtr = scaler.fit_transform(Xseq[tr].reshape(-1, F)).reshape(-1, T, F)
                    Xte = scaler.transform(Xseq[te].reshape(-1, F)).reshape(-1, T, F)
                    ytr, yte = yseq[tr], yseq[te]

                    torch.manual_seed(SEED + fold)
                    model = make_advanced_model(spec, len(feat_cols), n_classes)
                    pred = train_val_predict_torch_advanced(
                        model,
                        Xtr, ytr, Xte, yte,
                        epochs=config['epochs'],
                        batch_size=config['batch_size'],
                        lr=config['lr'],
                        patience=3,
                        class_weight=True,
                    )
                    m = summarize_clf(yte, pred)
                    fold_metrics.append(m)
                    ntr.append(len(tr)); nte.append(len(te))
                    print(f'  fold {fold}: acc={m["accuracy"]:.4f} macroF1={m["macro_f1"]:.4f} train={len(tr)} test={len(te)}')

                out = {
                    'feature_set': fs,
                    'target': target,
                    'model': model_name,
                    'family': spec['family'],
                    'lookback': lookback,
                    'patch_len': spec.get('patch_len', np.nan),
                    'stride': spec.get('stride', np.nan),
                    'accuracy': float(np.mean([m['accuracy'] for m in fold_metrics])),
                    'macro_f1': float(np.mean([m['macro_f1'] for m in fold_metrics])),
                    'weighted_f1': float(np.mean([m['weighted_f1'] for m in fold_metrics])),
                    'n_features': len(feat_cols),
                    'n_train_avg': int(np.mean(ntr)),
                    'n_test_avg': int(np.mean(nte)),
                }
                print(f'  AVG: acc={out["accuracy"]:.4f} macroF1={out["macro_f1"]:.4f}')
                rows.append(out)
    res = pd.DataFrame(rows).sort_values(['target', 'accuracy'], ascending=[True, False]).reset_index(drop=True)
    Path('benchmark_results').mkdir(exist_ok=True)
    res.to_csv('benchmark_results/advanced_transformer_benchmark_results.csv', index=False)
    print('\nSaved benchmark_results/advanced_transformer_benchmark_results.csv')
    return res


# Run the advanced benchmark. This can take time on CPU; Colab GPU is recommended.
advanced_results = eval_advanced_sequence_models(datasets, ADVANCED_CONFIG)
display(advanced_results)
# Out:
# baseline  | target_direction_5     | lstm_L256          | L=256
#   fold 0: acc=0.7039 macroF1=0.6797 train=464 test=233
#   fold 1: acc=0.8670 macroF1=0.8669 train=952 test=233
#   fold 2: acc=0.8412 macroF1=0.8377 train=1440 test=233
#   fold 3: acc=0.8541 macroF1=0.8489 train=1928 test=233
#   AVG: acc=0.8165 macroF1=0.8083
#
# baseline  | target_direction_5     | gru_L256           | L=256
#   fold 0: acc=0.8283 macroF1=0.8263 train=464 test=233
#   fold 1: acc=0.8841 macroF1=0.8840 train=952 test=233
#   fold 2: acc=0.6609 macroF1=0.6156 train=1440 test=233
#   fold 3: acc=0.8712 macroF1=0.8700 train=1928 test=233
#   AVG: acc=0.8112 macroF1=0.7990
#
# baseline  | target_direction_5     | patchtst_L256      | L=256
#   fold 0: acc=0.8412 macroF1=0.8412 train=464 test=233
#   fold 1: acc=0.8712 macroF1=0.8712 train=952 test=233
#   fold 2: acc=0.8584 macroF1=0.8580 train=1440 test=233
#   fold 3: acc=0.8498 macroF1=0.8497 train=1928 test=233
#   AVG: acc=0.8552 macroF1=0.8550
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# baseline  | target_direction_5     | patchtst_L512      | L=512
#   fold 0: acc=0.7733 macroF1=0.7625 train=146 test=75
#   fold 1: acc=0.8667 macroF1=0.8655 train=732 test=75
#   fold 2: acc=0.8267 macroF1=0.8256 train=1318 test=75
#   AVG: acc=0.8222 macroF1=0.8179
#
# baseline  | target_direction_5     | itransformer_L256  | L=256
#   fold 0: acc=0.8283 macroF1=0.8266 train=464 test=233
#   fold 1: acc=0.8498 macroF1=0.8489 train=952 test=233
#   fold 2: acc=0.8670 macroF1=0.8669 train=1440 test=233
#   fold 3: acc=0.8240 macroF1=0.8232 train=1928 test=233
#   AVG: acc=0.8423 macroF1=0.8414
#
# baseline  | target_direction_5     | timesnet_L256      | L=256
#   fold 0: acc=0.7811 macroF1=0.7788 train=464 test=233
#   fold 1: acc=0.9056 macroF1=0.9053 train=952 test=233
#   fold 2: acc=0.8712 macroF1=0.8708 train=1440 test=233
#   fold 3: acc=0.8240 macroF1=0.8238 train=1928 test=233
#   AVG: acc=0.8455 macroF1=0.8447
#
# baseline  | target_direction_5     | fedformer_L256     | L=256
#   fold 0: acc=0.6137 macroF1=0.5664 train=464 test=233
#   fold 1: acc=0.7811 macroF1=0.7784 train=952 test=233
#   fold 2: acc=0.7983 macroF1=0.7983 train=1440 test=233
#   fold 3: acc=0.8240 macroF1=0.8197 train=1928 test=233
#   AVG: acc=0.7543 macroF1=0.7407
#
# baseline  | target_trade_signal_5  | lstm_L256          | L=256
#   fold 0: acc=0.4163 macroF1=0.3785 train=464 test=233
#   fold 1: acc=0.5536 macroF1=0.4518 train=952 test=233
#   fold 2: acc=0.7167 macroF1=0.6626 train=1440 test=233
#   fold 3: acc=0.7167 macroF1=0.7066 train=1928 test=233
#   AVG: acc=0.6009 macroF1=0.5499
#
# baseline  | target_trade_signal_5  | gru_L256           | L=256
#   fold 0: acc=0.4764 macroF1=0.4711 train=464 test=233
#   fold 1: acc=0.6395 macroF1=0.6205 train=952 test=233
#   fold 2: acc=0.6652 macroF1=0.5752 train=1440 test=233
#   fold 3: acc=0.6996 macroF1=0.6305 train=1928 test=233
#   AVG: acc=0.6202 macroF1=0.5743
#
# baseline  | target_trade_signal_5  | patchtst_L256      | L=256
#   fold 0: acc=0.6996 macroF1=0.6974 train=464 test=233
#   fold 1: acc=0.7082 macroF1=0.6807 train=952 test=233
#   fold 2: acc=0.7210 macroF1=0.7046 train=1440 test=233
#   fold 3: acc=0.7425 macroF1=0.7422 train=1928 test=233
#   AVG: acc=0.7178 macroF1=0.7062
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# baseline  | target_trade_signal_5  | patchtst_L512      | L=512
#   fold 0: acc=0.7067 macroF1=0.5969 train=146 test=75
#   fold 1: acc=0.7067 macroF1=0.6933 train=732 test=75
#   fold 2: acc=0.7200 macroF1=0.7223 train=1318 test=75
#   AVG: acc=0.7111 macroF1=0.6708
#
# baseline  | target_trade_signal_5  | itransformer_L256  | L=256
#   fold 0: acc=0.6996 macroF1=0.6992 train=464 test=233
#   fold 1: acc=0.7296 macroF1=0.7062 train=952 test=233
#   fold 2: acc=0.7124 macroF1=0.6797 train=1440 test=233
#   fold 3: acc=0.7382 macroF1=0.7315 train=1928 test=233
#   AVG: acc=0.7200 macroF1=0.7041
#
# baseline  | target_trade_signal_5  | timesnet_L256      | L=256
#   fold 0: acc=0.5880 macroF1=0.5900 train=464 test=233
#   fold 1: acc=0.7554 macroF1=0.6543 train=952 test=233
#   fold 2: acc=0.7082 macroF1=0.6939 train=1440 test=233
#   fold 3: acc=0.7597 macroF1=0.7620 train=1928 test=233
#   AVG: acc=0.7028 macroF1=0.6750
#
# baseline  | target_trade_signal_5  | fedformer_L256     | L=256
#   fold 0: acc=0.3691 macroF1=0.1797 train=464 test=233
#   fold 1: acc=0.6567 macroF1=0.4902 train=952 test=233
#   fold 2: acc=0.6137 macroF1=0.5787 train=1440 test=233
#   fold 3: acc=0.7124 macroF1=0.6908 train=1928 test=233
#   AVG: acc=0.5880 macroF1=0.4848
#
# fft       | target_direction_5     | lstm_L256          | L=256
#   fold 0: acc=0.7854 macroF1=0.7799 train=464 test=233
#   fold 1: acc=0.7940 macroF1=0.7938 train=952 test=233
#   fold 2: acc=0.7597 macroF1=0.7444 train=1440 test=233
#   fold 3: acc=0.8670 macroF1=0.8637 train=1928 test=233
#   AVG: acc=0.8015 macroF1=0.7954
#
# fft       | target_direction_5     | gru_L256           | L=256
#   fold 0: acc=0.7811 macroF1=0.7730 train=464 test=233
#   fold 1: acc=0.8326 macroF1=0.8326 train=952 test=233
#   fold 2: acc=0.8584 macroF1=0.8556 train=1440 test=233
#   fold 3: acc=0.8541 macroF1=0.8536 train=1928 test=233
#   AVG: acc=0.8315 macroF1=0.8287
#
# fft       | target_direction_5     | patchtst_L256      | L=256
#   fold 0: acc=0.5064 macroF1=0.3362 train=464 test=233
#   fold 1: acc=0.8498 macroF1=0.8473 train=952 test=233
#   fold 2: acc=0.8369 macroF1=0.8350 train=1440 test=233
#   fold 3: acc=0.8584 macroF1=0.8582 train=1928 test=233
#   AVG: acc=0.7629 macroF1=0.7192
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# fft       | target_direction_5     | patchtst_L512      | L=512
#   fold 0: acc=0.4667 macroF1=0.3182 train=146 test=75
#   fold 1: acc=0.8133 macroF1=0.8092 train=732 test=75
#   fold 2: acc=0.8667 macroF1=0.8647 train=1318 test=75
#   AVG: acc=0.7156 macroF1=0.6640
#
# fft       | target_direction_5     | itransformer_L256  | L=256
#   fold 0: acc=0.8498 macroF1=0.8496 train=464 test=233
#   fold 1: acc=0.8670 macroF1=0.8647 train=952 test=233
#   fold 2: acc=0.8927 macroF1=0.8926 train=1440 test=233
#   fold 3: acc=0.8627 macroF1=0.8622 train=1928 test=233
#   AVG: acc=0.8680 macroF1=0.8673
#
# fft       | target_direction_5     | timesnet_L256      | L=256
#   fold 0: acc=0.8326 macroF1=0.8290 train=464 test=233
#   fold 1: acc=0.8541 macroF1=0.8518 train=952 test=233
#   fold 2: acc=0.8498 macroF1=0.8461 train=1440 test=233
#   fold 3: acc=0.8455 macroF1=0.8455 train=1928 test=233
#   AVG: acc=0.8455 macroF1=0.8431
#
# fft       | target_direction_5     | fedformer_L256     | L=256
#   fold 0: acc=0.5064 macroF1=0.3362 train=464 test=233
#   fold 1: acc=0.7554 macroF1=0.7527 train=952 test=233
#   fold 2: acc=0.6910 macroF1=0.6594 train=1440 test=233
#   fold 3: acc=0.7897 macroF1=0.7891 train=1928 test=233
#   AVG: acc=0.6856 macroF1=0.6344
#
# fft       | target_trade_signal_5  | lstm_L256          | L=256
#   fold 0: acc=0.5193 macroF1=0.4859 train=464 test=233
#   fold 1: acc=0.6695 macroF1=0.6230 train=952 test=233
#   fold 2: acc=0.4893 macroF1=0.3574 train=1440 test=233
#   fold 3: acc=0.7554 macroF1=0.7579 train=1928 test=233
#   AVG: acc=0.6084 macroF1=0.5561
#
# fft       | target_trade_signal_5  | gru_L256           | L=256
#   fold 0: acc=0.5150 macroF1=0.4720 train=464 test=233
#   fold 1: acc=0.6266 macroF1=0.6185 train=952 test=233
#   fold 2: acc=0.5021 macroF1=0.4329 train=1440 test=233
#   fold 3: acc=0.6481 macroF1=0.5998 train=1928 test=233
#   AVG: acc=0.5730 macroF1=0.5308
#
# fft       | target_trade_signal_5  | patchtst_L256      | L=256
#   fold 0: acc=0.6867 macroF1=0.6735 train=464 test=233
#   fold 1: acc=0.7082 macroF1=0.6855 train=952 test=233
#   fold 2: acc=0.6953 macroF1=0.6846 train=1440 test=233
#   fold 3: acc=0.7339 macroF1=0.7311 train=1928 test=233
#   AVG: acc=0.7060 macroF1=0.6937
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# fft       | target_trade_signal_5  | patchtst_L512      | L=512
#   fold 0: acc=0.5200 macroF1=0.4090 train=146 test=75
#   fold 1: acc=0.6933 macroF1=0.6664 train=732 test=75
#   fold 2: acc=0.7067 macroF1=0.7016 train=1318 test=75
#   AVG: acc=0.6400 macroF1=0.5923
#
# fft       | target_trade_signal_5  | itransformer_L256  | L=256
#   fold 0: acc=0.7425 macroF1=0.7271 train=464 test=233
#   fold 1: acc=0.7167 macroF1=0.6932 train=952 test=233
#   fold 2: acc=0.7124 macroF1=0.6585 train=1440 test=233
#   fold 3: acc=0.7597 macroF1=0.7547 train=1928 test=233
#   AVG: acc=0.7328 macroF1=0.7083
#
# fft       | target_trade_signal_5  | timesnet_L256      | L=256
#   fold 0: acc=0.7082 macroF1=0.5661 train=464 test=233
#   fold 1: acc=0.7039 macroF1=0.6668 train=952 test=233
#   fold 2: acc=0.4721 macroF1=0.4776 train=1440 test=233
#   fold 3: acc=0.7811 macroF1=0.7825 train=1928 test=233
#   AVG: acc=0.6663 macroF1=0.6233
#
# fft       | target_trade_signal_5  | fedformer_L256     | L=256
#   fold 0: acc=0.3691 macroF1=0.1797 train=464 test=233
#   fold 1: acc=0.5064 macroF1=0.4588 train=952 test=233
#   fold 2: acc=0.5837 macroF1=0.4981 train=1440 test=233
#   fold 3: acc=0.6867 macroF1=0.6683 train=1928 test=233
#   AVG: acc=0.5365 macroF1=0.4512
#
# fft_stft  | target_direction_5     | lstm_L256          | L=256
#   fold 0: acc=0.5579 macroF1=0.4581 train=464 test=233
#   fold 1: acc=0.7511 macroF1=0.7453 train=952 test=233
#   fold 2: acc=0.6652 macroF1=0.6218 train=1440 test=233
#   fold 3: acc=0.8541 macroF1=0.8511 train=1928 test=233
#   AVG: acc=0.7071 macroF1=0.6691
#
# fft_stft  | target_direction_5     | gru_L256           | L=256
#   fold 0: acc=0.6352 macroF1=0.5836 train=464 test=233
#   fold 1: acc=0.8584 macroF1=0.8582 train=952 test=233
#   fold 2: acc=0.7554 macroF1=0.7392 train=1440 test=233
#   fold 3: acc=0.8155 macroF1=0.8058 train=1928 test=233
#   AVG: acc=0.7661 macroF1=0.7467
#
# fft_stft  | target_direction_5     | patchtst_L256      | L=256
#   fold 0: acc=0.6867 macroF1=0.6536 train=464 test=233
#   fold 1: acc=0.8412 macroF1=0.8406 train=952 test=233
#   fold 2: acc=0.8670 macroF1=0.8669 train=1440 test=233
#   fold 3: acc=0.8541 macroF1=0.8539 train=1928 test=233
#   AVG: acc=0.8122 macroF1=0.8037
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# fft_stft  | target_direction_5     | patchtst_L512      | L=512
#   fold 0: acc=0.4933 macroF1=0.3717 train=146 test=75
#   fold 1: acc=0.8800 macroF1=0.8792 train=732 test=75
#   fold 2: acc=0.8933 macroF1=0.8900 train=1318 test=75
#   AVG: acc=0.7556 macroF1=0.7136
#
# fft_stft  | target_direction_5     | itransformer_L256  | L=256
#   fold 0: acc=0.8240 macroF1=0.8225 train=464 test=233
#   fold 1: acc=0.8412 macroF1=0.8385 train=952 test=233
#   fold 2: acc=0.8755 macroF1=0.8753 train=1440 test=233
#   fold 3: acc=0.8326 macroF1=0.8323 train=1928 test=233
#   AVG: acc=0.8433 macroF1=0.8421
#
# fft_stft  | target_direction_5     | timesnet_L256      | L=256
#   fold 0: acc=0.8412 macroF1=0.8412 train=464 test=233
#   fold 1: acc=0.8627 macroF1=0.8611 train=952 test=233
#   fold 2: acc=0.8884 macroF1=0.8882 train=1440 test=233
#   fold 3: acc=0.8755 macroF1=0.8749 train=1928 test=233
#   AVG: acc=0.8670 macroF1=0.8664
#
# fft_stft  | target_direction_5     | fedformer_L256     | L=256
#   fold 0: acc=0.5365 macroF1=0.4126 train=464 test=233
#   fold 1: acc=0.6223 macroF1=0.5860 train=952 test=233
#   fold 2: acc=0.7725 macroF1=0.7676 train=1440 test=233
#   fold 3: acc=0.8197 macroF1=0.8176 train=1928 test=233
#   AVG: acc=0.6878 macroF1=0.6460
#
# fft_stft  | target_trade_signal_5  | lstm_L256          | L=256
#   fold 0: acc=0.4335 macroF1=0.2944 train=464 test=233
#   fold 1: acc=0.5622 macroF1=0.4717 train=952 test=233
#   fold 2: acc=0.6352 macroF1=0.4937 train=1440 test=233
#   fold 3: acc=0.7382 macroF1=0.7139 train=1928 test=233
#   AVG: acc=0.5923 macroF1=0.4934
#
# fft_stft  | target_trade_signal_5  | gru_L256           | L=256
#   fold 0: acc=0.5107 macroF1=0.4545 train=464 test=233
#   fold 1: acc=0.5880 macroF1=0.5806 train=952 test=233
#   fold 2: acc=0.5966 macroF1=0.5109 train=1440 test=233
#   fold 3: acc=0.6910 macroF1=0.6824 train=1928 test=233
#   AVG: acc=0.5966 macroF1=0.5571
#
# fft_stft  | target_trade_signal_5  | patchtst_L256      | L=256
#   fold 0: acc=0.6223 macroF1=0.6075 train=464 test=233
#   fold 1: acc=0.6652 macroF1=0.6355 train=952 test=233
#   fold 2: acc=0.6996 macroF1=0.6719 train=1440 test=233
#   fold 3: acc=0.7511 macroF1=0.7431 train=1928 test=233
#   AVG: acc=0.6845 macroF1=0.6645
# Warning: Failed to create 5 splits with lookback=512, embargo=517. Error: 'Too many splits=5 for number of samples=2932 with test_size=488 and gap=517.'. Reducing splits...
#
# fft_stft  | target_trade_signal_5  | patchtst_L512      | L=512
#   fold 0: acc=0.5467 macroF1=0.3769 train=146 test=75
#   fold 1: acc=0.6267 macroF1=0.5729 train=732 test=75
#   fold 2: acc=0.6933 macroF1=0.6814 train=1318 test=75
#   AVG: acc=0.6222 macroF1=0.5437
#
# fft_stft  | target_trade_signal_5  | itransformer_L256  | L=256
#   fold 0: acc=0.7167 macroF1=0.6995 train=464 test=233
#   fold 1: acc=0.7425 macroF1=0.7233 train=952 test=233
#   fold 2: acc=0.7039 macroF1=0.6674 train=1440 test=233
#   fold 3: acc=0.7511 macroF1=0.7451 train=1928 test=233
#   AVG: acc=0.7285 macroF1=0.7088
#
# fft_stft  | target_trade_signal_5  | timesnet_L256      | L=256
#   fold 0: acc=0.6609 macroF1=0.6037 train=464 test=233
#   fold 1: acc=0.7382 macroF1=0.6676 train=952 test=233
#   fold 2: acc=0.6824 macroF1=0.6816 train=1440 test=233
#   fold 3: acc=0.7725 macroF1=0.7732 train=1928 test=233
#   AVG: acc=0.7135 macroF1=0.6815
#
# fft_stft  | target_trade_signal_5  | fedformer_L256     | L=256
#   fold 0: acc=0.2790 macroF1=0.1954 train=464 test=233
#   fold 1: acc=0.5021 macroF1=0.4904 train=952 test=233
#   fold 2: acc=0.6137 macroF1=0.6142 train=1440 test=233
#   fold 3: acc=0.6094 macroF1=0.5756 train=1928 test=233
#   AVG: acc=0.5011 macroF1=0.4689
#
# Saved benchmark_results/advanced_transformer_benchmark_results.csv
#    feature_set                 target              model        family  \
# 0          fft     target_direction_5  itransformer_L256  itransformer
# 1     fft_stft     target_direction_5      timesnet_L256      timesnet
# 2     baseline     target_direction_5      patchtst_L256      patchtst
# 3     baseline     target_direction_5      timesnet_L256      timesnet
# 4          fft     target_direction_5      timesnet_L256      timesnet
# 5     fft_stft     target_direction_5  itransformer_L256  itransformer
# 6     baseline     target_direction_5  itransformer_L256  itransformer
# 7          fft     target_direction_5           gru_L256           gru
# 8     baseline     target_direction_5      patchtst_L512      patchtst
# 9     baseline     target_direction_5          lstm_L256          lstm
# 10    fft_stft     target_direction_5      patchtst_L256      patchtst
# 11    baseline     target_direction_5           gru_L256           gru
# 12         fft     target_direction_5          lstm_L256          lstm
# 13    fft_stft     target_direction_5           gru_L256           gru
# 14         fft     target_direction_5      patchtst_L256      patchtst
# 15    fft_stft     target_direction_5      patchtst_L512      patchtst
# 16    baseline     target_direction_5     fedformer_L256     fedformer
# 17         fft     target_direction_5      patchtst_L512      patchtst
# 18    fft_stft     target_direction_5          lstm_L256          lstm
# 19    fft_stft     target_direction_5     fedformer_L256     fedformer
# 20         fft     target_direction_5     fedformer_L256     fedformer
# 21         fft  target_trade_signal_5  itransformer_L256  itransformer
# 22    fft_stft  target_trade_signal_5  itransformer_L256  itransformer
# 23    baseline  target_trade_signal_5  itransformer_L256  itransformer
# 24    baseline  target_trade_signal_5      patchtst_L256      patchtst
# 25    fft_stft  target_trade_signal_5      timesnet_L256      timesnet
# 26    baseline  target_trade_signal_5      patchtst_L512      patchtst
# 27         fft  target_trade_signal_5      patchtst_L256      patchtst
# 28    baseline  target_trade_signal_5      timesnet_L256      timesnet
# 29    fft_stft  target_trade_signal_5      patchtst_L256      patchtst
# 30         fft  target_trade_signal_5      timesnet_L256      timesnet
# 31         fft  target_trade_signal_5      patchtst_L512      patchtst
# 32    fft_stft  target_trade_signal_5      patchtst_L512      patchtst
# 33    baseline  target_trade_signal_5           gru_L256           gru
# 34         fft  target_trade_signal_5          lstm_L256          lstm
# 35    baseline  target_trade_signal_5          lstm_L256          lstm
# 36    fft_stft  target_trade_signal_5           gru_L256           gru
# 37    fft_stft  target_trade_signal_5          lstm_L256          lstm
# 38    baseline  target_trade_signal_5     fedformer_L256     fedformer
# 39         fft  target_trade_signal_5           gru_L256           gru
# 40         fft  target_trade_signal_5     fedformer_L256     fedformer
# 41    fft_stft  target_trade_signal_5     fedformer_L256     fedformer
#
#     lookback  patch_len  stride  accuracy  macro_f1  weighted_f1  n_features  \
# 0        256        NaN     NaN  0.868026  0.867282     0.867524          70
# 1        256        NaN     NaN  0.866953  0.866352     0.866598          80
# 2        256       16.0     8.0  0.855150  0.855030     0.855085          41
# 3        256        NaN     NaN  0.845494  0.844681     0.844689          41
# 4        256        NaN     NaN  0.845494  0.843090     0.843324          70
# 5        256        NaN     NaN  0.843348  0.842148     0.842372          80
# 6        256        NaN     NaN  0.842275  0.841409     0.841634          41
# 7        256        NaN     NaN  0.831545  0.828724     0.828728          70
# 8        512       32.0    16.0  0.822222  0.817857     0.819944          41
# 9        256        NaN     NaN  0.816524  0.808322     0.808496          41
# 10       256       16.0     8.0  0.812232  0.803742     0.804246          80
# 11       256        NaN     NaN  0.811159  0.798995     0.799306          41
# 12       256        NaN     NaN  0.801502  0.795430     0.795676          70
# 13       256        NaN     NaN  0.766094  0.746701     0.747034          80
# 14       256       16.0     8.0  0.762876  0.719162     0.720451          70
# 15       512       32.0    16.0  0.755556  0.713650     0.708653          80
# 16       256        NaN     NaN  0.754292  0.740683     0.741777          41
# 17       512       32.0    16.0  0.715556  0.664043     0.658388          70
# 18       256        NaN     NaN  0.707082  0.669074     0.668515          80
# 19       256        NaN     NaN  0.687768  0.645961     0.648101          80
# 20       256        NaN     NaN  0.685622  0.634355     0.635565          70
# 21       256        NaN     NaN  0.732833  0.708345     0.739577          70
# 22       256        NaN     NaN  0.728541  0.708808     0.738330          80
# 23       256        NaN     NaN  0.719957  0.704140     0.730944          41
# 24       256       16.0     8.0  0.717811  0.706227     0.731886          41
# 25       256        NaN     NaN  0.713519  0.681522     0.714908          80
# 26       512       32.0    16.0  0.711111  0.670833     0.703557          41
# 27       256       16.0     8.0  0.706009  0.693675     0.719585          70
# 28       256        NaN     NaN  0.702790  0.675047     0.707725          41
# 29       256       16.0     8.0  0.684549  0.664475     0.696233          80
# 30       256        NaN     NaN  0.666309  0.623255     0.654650          70
# 31       512       32.0    16.0  0.640000  0.592344     0.618977          70
# 32       512       32.0    16.0  0.622222  0.543696     0.583190          80
# 33       256        NaN     NaN  0.620172  0.574314     0.608097          41
# 34       256        NaN     NaN  0.608369  0.556052     0.587320          70
# 35       256        NaN     NaN  0.600858  0.549861     0.579347          41
# 36       256        NaN     NaN  0.596567  0.557113     0.587634          80
# 37       256        NaN     NaN  0.592275  0.493384     0.537096          80
# 38       256        NaN     NaN  0.587983  0.484848     0.526334          41
# 39       256        NaN     NaN  0.572961  0.530800     0.557399          70
# 40       256        NaN     NaN  0.536481  0.451230     0.480390          70
# 41       256        NaN     NaN  0.501073  0.468906     0.486427          80
#
#     n_train_avg  n_test_avg
# 0          1196         233
# 1          1196         233
# 2          1196         233
# 3          1196         233
# 4          1196         233
# 5          1196         233
# 6          1196         233
# 7          1196         233
# 8           732          75
# 9          1196         233
# 10         1196         233
# 11         1196         233
# 12         1196         233
# 13         1196         233
# 14         1196         233
# 15          732          75
# 16         1196         233
# 17          732          75
# 18         1196         233
# 19         1196         233
# 20         1196         233
# 21         1196         233
# 22         1196         233
# 23         1196         233
# 24         1196         233
# 25         1196         233
# 26          732          75
# 27         1196         233
# 28         1196         233
# 29         1196         233
# 30         1196         233
# 31          732          75
# 32          732          75
# 33         1196         233
# 34         1196         233
# 35         1196         233
# 36         1196         233
# 37         1196         233
# 38         1196         233
# 39         1196         233
# 40         1196         233
# 41         1196         233

# %%
# ============================================================
# Phase 1C — Advanced benchmark summary plots and ablation table
# ============================================================

if 'advanced_results' in globals() and len(advanced_results):
    for target in advanced_results['target'].unique():
        sub = advanced_results[advanced_results['target'] == target].copy()
        pivot = sub.pivot_table(index='model', columns='feature_set', values='accuracy', aggfunc='max')
        for col in ['baseline', 'fft', 'fft_stft']:
            if col not in pivot.columns:
                pivot[col] = np.nan
        pivot['best'] = pivot[['baseline','fft','fft_stft']].max(axis=1)
        pivot['uplift_vs_baseline'] = pivot['best'] - pivot['baseline']
        display(pivot.sort_values('best', ascending=False))

        plot_df = sub.sort_values('accuracy', ascending=False).head(30)
        plt.figure(figsize=(14,4))
        labels = plot_df['model'] + ' | ' + plot_df['feature_set']
        plt.bar(range(len(plot_df)), plot_df['accuracy'])
        plt.xticks(range(len(plot_df)), labels, rotation=75, ha='right')
        plt.ylabel('Accuracy')
        plt.title(f'Advanced accuracy benchmark — {target}')
        plt.tight_layout()
        plt.show()
else:
    print('No advanced_results found. Run the advanced benchmark cell first.')
# Out:
# feature_set        baseline       fft  fft_stft      best  uplift_vs_baseline
# model
# itransformer_L256  0.842275  0.868026  0.843348  0.868026            0.025751
# timesnet_L256      0.845494  0.845494  0.866953  0.866953            0.021459
# patchtst_L256      0.855150  0.762876  0.812232  0.855150            0.000000
# gru_L256           0.811159  0.831545  0.766094  0.831545            0.020386
# patchtst_L512      0.822222  0.715556  0.755556  0.822222            0.000000
# lstm_L256          0.816524  0.801502  0.707082  0.816524            0.000000
# fedformer_L256     0.754292  0.685622  0.687768  0.754292            0.000000
# feature_set        baseline       fft  fft_stft      best  uplift_vs_baseline
# model
# itransformer_L256  0.719957  0.732833  0.728541  0.732833            0.012876
# patchtst_L256      0.717811  0.706009  0.684549  0.717811            0.000000
# timesnet_L256      0.702790  0.666309  0.713519  0.713519            0.010730
# patchtst_L512      0.711111  0.640000  0.622222  0.711111            0.000000
# gru_L256           0.620172  0.572961  0.596567  0.620172            0.000000
# lstm_L256          0.600858  0.608369  0.592275  0.608369            0.007511
# fedformer_L256     0.587983  0.536481  0.501073  0.587983            0.000000

# %% [markdown]
# ## How to read Phase 1C
#
# The key comparison is no longer just `baseline vs FFT vs FFT+STFT`. It is now:
#
# 1. **Do long-context models improve when lookback increases to 256/512?**
# 2. **Does a faithful PatchTST core outperform GRU/LSTM when given longer context?**
# 3. **Do frequency-aware/period-aware models such as TimesNet and FEDformer reduce the need for handcrafted FFT/STFT features?**
# 4. **Do FFT/STFT features help tree models more than learned sequence models?**
#
# If PatchTST/FEDformer/TimesNet improve strongly with long lookbacks while FFT gives little additional gain, that suggests the model learns frequency-like structure internally.
# If tree models still benefit most from FFT/STFT, then frequency features are acting as handcrafted temporal memory for non-sequential models.

# %% [markdown]
# ---
# # Phase 1D — Official-style PatchTST Sweep + Long-Context Audit
#
# This section is designed to answer one specific question:
#
# > Is PatchTST underperforming because of the architecture, the context length, the patch size, or because FFT/STFT features are redundant for a sequence model?
#
# We now test PatchTST more carefully using:
#
# 1. **Channel independence with shared weights** — each feature channel is patched independently, but all channels share the same patch embedding and Transformer encoder.
# 2. **RevIN on/off** — RevIN helps with non-stationary series by normalizing each sample and channel across the lookback window.
# 3. **Learned positional embedding** — each patch token receives a learnable temporal position vector.
# 4. **GELU feed-forward blocks** — matching the Transformer FFN style used in PatchTST-like models.
# 5. **Configurable patch length and stride** — we test several patch/stride combinations.
# 6. **Long context lengths** — 96, 192, 384, and 768 candles.
# 7. **Audited sequence splits** — train/test windows are split by original row index, with an embargo of `lookback + horizon` to prevent overlap leakage.
#
# **Important:** this is still a classifier adaptation of PatchTST. The original PatchTST was built mainly for forecasting future numerical values. Here we use its core representation idea for classification targets: `target_direction_5` and `target_trade_signal_5`.

# %%
# ============================================================
# Phase 1D — Extra audit helpers for long-context experiments
# ============================================================

PATCH_SWEEP_TARGETS = ['target_direction_5', 'target_trade_signal_5']


def audit_one_split(df, feat_cols, target_col, lookback, horizon=5, n_splits=5):
    """Print a human-readable audit of sequence split safety."""
    Xseq, yseq, end_idxs = make_sequence_arrays_with_index(df, feat_cols, target_col, lookback=lookback)
    splits = make_audited_sequence_splits(
        n_rows=len(df),
        end_idxs=end_idxs,
        lookback=lookback,
        horizon=horizon,
        n_splits=n_splits,
    )
    print(f'Rows={len(df):,} | sequences={len(Xseq):,} | lookback={lookback} | horizon={horizon} | splits={len(splits)}')
    for fold, (tr, te) in enumerate(splits):
        train_end = end_idxs[tr].max()
        train_target_reach = train_end + horizon
        test_input_start = end_idxs[te].min() - lookback + 1
        test_end = end_idxs[te].max()
        print(
            f'fold={fold} train_seq={len(tr):5d} test_seq={len(te):5d} | '
            f'train_end={train_end:5d} train_target_reach={train_target_reach:5d} | '
            f'test_input_start={test_input_start:5d} test_end={test_end:5d} | '
            f'safe={train_target_reach < test_input_start}'
        )


# Quick audit example. Change feature set / target / lookback as needed.
print('=== Example leakage audit for baseline / target_trade_signal_5 / L=384 ===')
_example_df = datasets['baseline']
_example_feats = get_feature_cols(_example_df)
audit_one_split(_example_df, _example_feats, 'target_trade_signal_5', lookback=384, horizon=5, n_splits=5)
# Out:
# === Example leakage audit for baseline / target_trade_signal_5 / L=384 ===
# Rows=2,932 | sequences=2,549 | lookback=384 | horizon=5 | splits=4
# fold=0 train_seq=  208 test_seq=  105 | train_end=  590 train_target_reach=  595 | test_input_start=  980 test_end= 1467 | safe=True
# fold=1 train_seq=  696 test_seq=  105 | train_end= 1078 train_target_reach= 1083 | test_input_start= 1468 test_end= 1955 | safe=True
# fold=2 train_seq= 1184 test_seq=  105 | train_end= 1566 train_target_reach= 1571 | test_input_start= 1956 test_end= 2443 | safe=True
# fold=3 train_seq= 1672 test_seq=  105 | train_end= 2054 train_target_reach= 2059 | test_input_start= 2444 test_end= 2931 | safe=True

# %%
# ============================================================
# Phase 1D — Official-style PatchTST configurable classifier
# ============================================================

if HAS_TORCH:
    class PatchTSTOfficialStyleClassifier(nn.Module):
        """
        PatchTST classifier adaptation with the key PatchTST design choices.

        Core behavior:
        - Input shape: [B, T, C]
        - Optional RevIN over time for each channel
        - Channel-independent patching: each variable/channel is treated as a separate univariate sequence
        - Shared patch embedding across channels
        - Learned positional embedding over patch tokens
        - Shared Transformer encoder across channels
        - Flatten patch embeddings per channel, then aggregate channels
        - Classification head for direction/trade-signal labels

        This is not the original forecasting head unchanged; it is a classification head built on the faithful PatchTST representation core.
        """
        def __init__(
            self,
            n_features: int,
            n_classes: int,
            lookback: int,
            patch_len: int = 16,
            stride: int = 8,
            d_model: int = 128,
            n_heads: int = 8,
            n_layers: int = 3,
            d_ff: int = 512,
            dropout: float = 0.15,
            use_revin: bool = True,
            affine_revin: bool = True,
            padding_patch: str = 'end',
            head_dropout: float = 0.2,
            channel_pool: str = 'mean',
        ):
            super().__init__()
            assert lookback >= patch_len, 'lookback must be >= patch_len'
            assert channel_pool in ('mean', 'attention'), "channel_pool must be 'mean' or 'attention'"
            self.n_features = n_features
            self.n_classes = n_classes
            self.lookback = lookback
            self.patch_len = patch_len
            self.stride = stride
            self.padding_patch = padding_patch
            self.channel_pool = channel_pool
            self.revin = RevINAdvanced(n_features, affine=affine_revin) if use_revin else nn.Identity()

            if padding_patch == 'end':
                # Same idea as PatchTST: pad at the end so the final context is represented.
                self.pad_len = (stride - ((lookback - patch_len) % stride)) % stride
            else:
                self.pad_len = 0
            self.n_patches = 1 + (lookback + self.pad_len - patch_len) // stride

            self.patch_embedding = nn.Linear(patch_len, d_model)
            self.position_embedding = nn.Parameter(torch.zeros(1, self.n_patches, d_model))
            self.embedding_dropout = nn.Dropout(dropout)

            encoder_layer = nn.TransformerEncoderLayer(
                d_model=d_model,
                nhead=n_heads,
                dim_feedforward=d_ff,
                dropout=dropout,
                activation='gelu',
                batch_first=True,
                norm_first=True,
            )
            self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

            # PatchTST-style flattened head per channel.
            self.channel_projection = nn.Sequential(
                nn.Flatten(start_dim=1),
                nn.LayerNorm(self.n_patches * d_model),
                nn.Linear(self.n_patches * d_model, d_model),
                nn.GELU(),
                nn.Dropout(head_dropout),
            )

            if channel_pool == 'attention':
                self.channel_score = nn.Sequential(
                    nn.LayerNorm(d_model),
                    nn.Linear(d_model, 1),
                )
            else:
                self.channel_score = None

            self.classifier = nn.Sequential(
                nn.LayerNorm(d_model),
                nn.Dropout(head_dropout),
                nn.Linear(d_model, n_classes),
            )
            nn.init.trunc_normal_(self.position_embedding, std=0.02)

        def forward(self, x):
            # x: [B, T, C]
            B, T, C = x.shape
            x = self.revin(x)
            x = x.transpose(1, 2)  # [B, C, T]

            if self.pad_len > 0:
                pad = x[:, :, -1:].repeat(1, 1, self.pad_len)
                x = torch.cat([x, pad], dim=2)

            # [B, C, N, patch_len]
            patches = x.unfold(dimension=2, size=self.patch_len, step=self.stride)
            N = patches.size(2)

            # Shared patch embedding across all channels.
            z = self.patch_embedding(patches)  # [B, C, N, D]
            z = z + self.position_embedding[:, :N, :].unsqueeze(1)
            z = self.embedding_dropout(z)

            # Shared Transformer encoder per channel: [B*C, N, D]
            z = z.reshape(B * C, N, -1)
            z = self.encoder(z)

            # Shared head per channel: [B*C, D] -> [B, C, D]
            z = self.channel_projection(z).reshape(B, C, -1)

            if self.channel_pool == 'attention':
                scores = self.channel_score(z).squeeze(-1)      # [B, C]
                weights = torch.softmax(scores, dim=1).unsqueeze(-1)
                z = (z * weights).sum(dim=1)
            else:
                z = z.mean(dim=1)

            return self.classifier(z)


    def make_patchtst_sweep_model(spec, n_features, n_classes):
        return PatchTSTOfficialStyleClassifier(
            n_features=n_features,
            n_classes=n_classes,
            lookback=spec['lookback'],
            patch_len=spec['patch_len'],
            stride=spec['stride'],
            d_model=spec.get('d_model', 128),
            n_heads=spec.get('n_heads', 8),
            n_layers=spec.get('n_layers', 3),
            d_ff=spec.get('d_ff', 512),
            dropout=spec.get('dropout', 0.15),
            use_revin=spec.get('use_revin', True),
            affine_revin=spec.get('affine_revin', True),
            padding_patch=spec.get('padding_patch', 'end'),
            head_dropout=spec.get('head_dropout', 0.2),
            channel_pool=spec.get('channel_pool', 'mean'),
        )

# %%
# ============================================================
# Phase 1D — PatchTST hyperparameter grid
# ============================================================

# Start with a manageable sweep. You can expand this after a successful run.
# Rule of thumb:
#   - 96/192 are cheap and stable.
#   - 384 is medium.
#   - 768 can be data-hungry; use fewer folds or more history.

PATCHTST_SWEEP_CONFIG = {
    'targets': ['target_direction_5', 'target_trade_signal_5'],
    'feature_sets': ['baseline', 'fft', 'fft_stft'],
    'horizon': 5,
    'n_splits': 5,
    'epochs': 10,
    'batch_size': 96,
    'lr': 7e-4,
    'patience': 3,
    'min_train_sequences': 300,
    'class_weight': True,
    'channel_pools': ['mean'],  # try ['mean','attention'] later
    'revin_options': [True, False],
    'grid': [
        # shorter context
        {'lookback': 96,  'patch_len': 8,  'stride': 4,  'd_model': 128, 'n_layers': 3},
        {'lookback': 96,  'patch_len': 16, 'stride': 8,  'd_model': 128, 'n_layers': 3},

        # medium context
        {'lookback': 192, 'patch_len': 8,  'stride': 4,  'd_model': 128, 'n_layers': 3},
        {'lookback': 192, 'patch_len': 16, 'stride': 8,  'd_model': 128, 'n_layers': 3},
        {'lookback': 192, 'patch_len': 32, 'stride': 16, 'd_model': 128, 'n_layers': 3},

        # long context
        {'lookback': 384, 'patch_len': 16, 'stride': 8,  'd_model': 128, 'n_layers': 3},
        {'lookback': 384, 'patch_len': 32, 'stride': 8,  'd_model': 128, 'n_layers': 3},
        {'lookback': 384, 'patch_len': 32, 'stride': 16, 'd_model': 128, 'n_layers': 3},
        {'lookback': 384, 'patch_len': 64, 'stride': 32, 'd_model': 128, 'n_layers': 3},

        # very long context: data hungry. Keep a small set first.
        {'lookback': 768, 'patch_len': 32, 'stride': 16, 'd_model': 128, 'n_layers': 3},
        {'lookback': 768, 'patch_len': 64, 'stride': 32, 'd_model': 128, 'n_layers': 3},
    ]
}

# Optional quick mode while debugging. Set to False for the full sweep above.
PATCHTST_QUICK_MODE = True

if PATCHTST_QUICK_MODE:
    PATCHTST_SWEEP_CONFIG['feature_sets'] = ['baseline', 'fft_stft']
    PATCHTST_SWEEP_CONFIG['targets'] = ['target_trade_signal_5']
    PATCHTST_SWEEP_CONFIG['revin_options'] = [True]
    PATCHTST_SWEEP_CONFIG['grid'] = [
        {'lookback': 96,  'patch_len': 16, 'stride': 8,  'd_model': 128, 'n_layers': 3},
        {'lookback': 192, 'patch_len': 16, 'stride': 8,  'd_model': 128, 'n_layers': 3},
        {'lookback': 384, 'patch_len': 32, 'stride': 16, 'd_model': 128, 'n_layers': 3},
    ]

PATCHTST_SWEEP_CONFIG
# Out:
# {'targets': ['target_trade_signal_5'],
#  'feature_sets': ['baseline', 'fft_stft'],
#  'horizon': 5,
#  'n_splits': 5,
#  'epochs': 10,
#  'batch_size': 96,
#  'lr': 0.0007,
#  'patience': 3,
#  'min_train_sequences': 300,
#  'class_weight': True,
#  'channel_pools': ['mean'],
#  'revin_options': [True],
#  'grid': [{'lookback': 96,
#    'patch_len': 16,
#    'stride': 8,
#    'd_model': 128,
#    'n_layers': 3},
#   {'lookback': 192,
#    'patch_len': 16,
#    'stride': 8,
#    'd_model': 128,
#    'n_layers': 3},
#   {'lookback': 384,
#    'patch_len': 32,
#    'stride': 16,
#    'd_model': 128,
#    'n_layers': 3}]}

# %%
# ============================================================
# Phase 1D — Run official-style PatchTST sweep
# ============================================================

def eval_patchtst_sweep(datasets, config=PATCHTST_SWEEP_CONFIG):
    if not HAS_TORCH:
        print('PyTorch unavailable; skipping PatchTST sweep.')
        return pd.DataFrame()

    rows = []
    for fs in config['feature_sets']:
        df = datasets[fs]
        feat_cols = get_feature_cols(df)
        for target in config['targets']:
            for base_spec in config['grid']:
                for use_revin in config['revin_options']:
                    for channel_pool in config['channel_pools']:
                        spec = dict(base_spec)
                        spec['use_revin'] = use_revin
                        spec['channel_pool'] = channel_pool
                        lookback = spec['lookback']

                        Xseq, yseq, end_idxs = make_sequence_arrays_with_index(df, feat_cols, target, lookback=lookback)
                        n_classes = len(np.unique(yseq))
                        splits = make_audited_sequence_splits(
                            n_rows=len(df),
                            end_idxs=end_idxs,
                            lookback=lookback,
                            horizon=config['horizon'],
                            n_splits=config['n_splits'],
                        )
                        if not splits:
                            print(f'SKIP no safe splits: {fs} {target} L={lookback}')
                            continue

                        model_name = (
                            f"patchtst_L{lookback}_P{spec['patch_len']}_S{spec['stride']}"
                            f"_revin{int(use_revin)}_{channel_pool}"
                        )
                        fold_metrics, ntr, nte = [], [], []
                        print(f"\n{fs:9s} | {target:22s} | {model_name}")

                        for fold, (tr, te) in enumerate(splits):
                            if len(tr) < config['min_train_sequences']:
                                print(f'  fold {fold}: skip, train too small ({len(tr)})')
                                continue

                            scaler = StandardScaler()
                            B, T, F = Xseq[tr].shape
                            Xtr = scaler.fit_transform(Xseq[tr].reshape(-1, F)).reshape(-1, T, F)
                            Xte = scaler.transform(Xseq[te].reshape(-1, F)).reshape(-1, T, F)
                            ytr, yte = yseq[tr], yseq[te]

                            torch.manual_seed(SEED + fold)
                            model = make_patchtst_sweep_model(spec, len(feat_cols), n_classes)
                            pred = train_val_predict_torch_advanced(
                                model,
                                Xtr, ytr, Xte, yte,
                                epochs=config['epochs'],
                                batch_size=config['batch_size'],
                                lr=config['lr'],
                                patience=config['patience'],
                                class_weight=config['class_weight'],
                            )
                            m = summarize_clf(yte, pred)
                            fold_metrics.append(m)
                            ntr.append(len(tr)); nte.append(len(te))
                            print(f'  fold {fold}: acc={m["accuracy"]:.4f} macroF1={m["macro_f1"]:.4f} train={len(tr)} test={len(te)}')

                        if not fold_metrics:
                            continue

                        rows.append({
                            'feature_set': fs,
                            'target': target,
                            'model': model_name,
                            'family': 'patchtst_official_style',
                            'lookback': lookback,
                            'patch_len': spec['patch_len'],
                            'stride': spec['stride'],
                            'use_revin': use_revin,
                            'channel_pool': channel_pool,
                            'd_model': spec.get('d_model', 128),
                            'n_layers': spec.get('n_layers', 3),
                            'accuracy': float(np.mean([m['accuracy'] for m in fold_metrics])),
                            'macro_f1': float(np.mean([m['macro_f1'] for m in fold_metrics])),
                            'weighted_f1': float(np.mean([m['weighted_f1'] for m in fold_metrics])),
                            'accuracy_std': float(np.std([m['accuracy'] for m in fold_metrics])),
                            'macro_f1_std': float(np.std([m['macro_f1'] for m in fold_metrics])),
                            'n_features': len(feat_cols),
                            'n_train_avg': int(np.mean(ntr)),
                            'n_test_avg': int(np.mean(nte)),
                            'n_folds_used': len(fold_metrics),
                        })

    out = pd.DataFrame(rows)
    os.makedirs('benchmark_results', exist_ok=True)
    out_path = 'benchmark_results/patchtst_official_style_sweep_results.csv'
    out.to_csv(out_path, index=False)
    print(f'\nSaved {out_path}')
    return out

patchtst_sweep_results = eval_patchtst_sweep(datasets, PATCHTST_SWEEP_CONFIG)
patchtst_sweep_results.sort_values(['target','accuracy'], ascending=[True, False]).head(20)
# Out:
# baseline  | target_trade_signal_5  | patchtst_L96_P16_S8_revin1_mean
#   fold 0: skip, train too small (296)
#   fold 1: acc=0.7455 macroF1=0.7289 train=784 test=393
#   fold 2: acc=0.7277 macroF1=0.6974 train=1272 test=393
#   fold 3: acc=0.7379 macroF1=0.7239 train=1760 test=393
#   fold 4: acc=0.7532 macroF1=0.7423 train=2248 test=393
#
# baseline  | target_trade_signal_5  | patchtst_L192_P16_S8_revin1_mean
#   fold 0: skip, train too small (104)
#   fold 1: acc=0.6801 macroF1=0.6623 train=592 test=297
#   fold 2: acc=0.7037 macroF1=0.6645 train=1080 test=297
#   fold 3: acc=0.7037 macroF1=0.6896 train=1568 test=297
#   fold 4: acc=0.7441 macroF1=0.7390 train=2056 test=297
#
# baseline  | target_trade_signal_5  | patchtst_L384_P32_S16_revin1_mean
#   fold 0: skip, train too small (208)
#   fold 1: acc=0.7333 macroF1=0.7125 train=696 test=105
#   fold 2: acc=0.7143 macroF1=0.6810 train=1184 test=105
#   fold 3: acc=0.7048 macroF1=0.7065 train=1672 test=105
#
# fft_stft  | target_trade_signal_5  | patchtst_L96_P16_S8_revin1_mean
#   fold 0: skip, train too small (296)
#   fold 1: acc=0.7201 macroF1=0.6846 train=784 test=393
#   fold 2: acc=0.7176 macroF1=0.6871 train=1272 test=393
#   fold 3: acc=0.7506 macroF1=0.7356 train=1760 test=393
#   fold 4: acc=0.7888 macroF1=0.7829 train=2248 test=393
#
# fft_stft  | target_trade_signal_5  | patchtst_L192_P16_S8_revin1_mean
#   fold 0: skip, train too small (104)
#   fold 1: acc=0.6296 macroF1=0.6213 train=592 test=297
#   fold 2: acc=0.7407 macroF1=0.7119 train=1080 test=297
#   fold 3: acc=0.7172 macroF1=0.7023 train=1568 test=297
#   fold 4: acc=0.7508 macroF1=0.7453 train=2056 test=297
#
# fft_stft  | target_trade_signal_5  | patchtst_L384_P32_S16_revin1_mean
#   fold 0: skip, train too small (208)
#   fold 1: acc=0.7143 macroF1=0.7005 train=696 test=105
#   fold 2: acc=0.7429 macroF1=0.6976 train=1184 test=105
#   fold 3: acc=0.7238 macroF1=0.7244 train=1672 test=105
#
# Saved benchmark_results/patchtst_official_style_sweep_results.csv
#   feature_set                 target                              model  \
# 3    fft_stft  target_trade_signal_5    patchtst_L96_P16_S8_revin1_mean
# 0    baseline  target_trade_signal_5    patchtst_L96_P16_S8_revin1_mean
# 5    fft_stft  target_trade_signal_5  patchtst_L384_P32_S16_revin1_mean
# 2    baseline  target_trade_signal_5  patchtst_L384_P32_S16_revin1_mean
# 4    fft_stft  target_trade_signal_5   patchtst_L192_P16_S8_revin1_mean
# 1    baseline  target_trade_signal_5   patchtst_L192_P16_S8_revin1_mean
#
#                     family  lookback  patch_len  stride  use_revin  \
# 3  patchtst_official_style        96         16       8       True
# 0  patchtst_official_style        96         16       8       True
# 5  patchtst_official_style       384         32      16       True
# 2  patchtst_official_style       384         32      16       True
# 4  patchtst_official_style       192         16       8       True
# 1  patchtst_official_style       192         16       8       True
#
#   channel_pool  d_model  n_layers  accuracy  macro_f1  weighted_f1  \
# 3         mean      128         3  0.744275  0.722539     0.752606
# 0         mean      128         3  0.741094  0.723135     0.751271
# 5         mean      128         3  0.726984  0.707514     0.740730
# 2         mean      128         3  0.717460  0.700011     0.732744
# 4         mean      128         3  0.709596  0.695206     0.723247
# 1         mean      128         3  0.707912  0.688868     0.720784
#
#    accuracy_std  macro_f1_std  n_features  n_train_avg  n_test_avg  \
# 3      0.028816      0.040319          80         1516         393
# 0      0.009414      0.016302          41         1516         393
# 5      0.011878      0.012027          80         1184         105
# 2      0.011878      0.013661          41         1184         105
# 4      0.047758      0.045533          80         1324         297
# 1      0.023006      0.030879          41         1324         297
#
#    n_folds_used
# 3             4
# 0             4
# 5             3
# 2             3
# 4             4
# 1             4

# %%
# ============================================================
# Phase 1D — Analyze PatchTST sweep results
# ============================================================

if len(patchtst_sweep_results):
    display_cols = [
        'feature_set','target','lookback','patch_len','stride','use_revin','channel_pool',
        'accuracy','macro_f1','accuracy_std','n_folds_used','n_train_avg','n_test_avg'
    ]
    display(patchtst_sweep_results[display_cols].sort_values(['target','accuracy'], ascending=[True, False]).head(30))

    # Ablation by target and feature set.
    for target in patchtst_sweep_results['target'].unique():
        print('\n' + '='*80)
        print('TARGET:', target)
        sub = patchtst_sweep_results[patchtst_sweep_results['target'] == target]
        best = sub.sort_values('accuracy', ascending=False).head(10)
        display(best[display_cols])

    # Best by lookback.
    best_by_lookback = (
        patchtst_sweep_results
        .sort_values('accuracy', ascending=False)
        .groupby(['target','lookback'], as_index=False)
        .first()
        .sort_values(['target','accuracy'], ascending=[True, False])
    )
    print('\nBest configuration by lookback:')
    display(best_by_lookback[display_cols])

    # Simple plots.
    import matplotlib.pyplot as plt
    for target in patchtst_sweep_results['target'].unique():
        sub = patchtst_sweep_results[patchtst_sweep_results['target'] == target].copy()
        sub['config'] = (
            sub['feature_set'] + ' | L' + sub['lookback'].astype(str) +
            ' P' + sub['patch_len'].astype(str) + ' S' + sub['stride'].astype(str) +
            ' R' + sub['use_revin'].astype(int).astype(str)
        )
        sub = sub.sort_values('accuracy', ascending=False).head(25)
        plt.figure(figsize=(16, 4))
        plt.bar(range(len(sub)), sub['accuracy'])
        plt.xticks(range(len(sub)), sub['config'], rotation=75, ha='right')
        plt.title(f'PatchTST official-style sweep — {target}')
        plt.ylabel('Accuracy')
        plt.tight_layout()
        plt.show()
else:
    print('No PatchTST sweep results available.')
# Out:
#   feature_set                 target  lookback  patch_len  stride  use_revin  \
# 3    fft_stft  target_trade_signal_5        96         16       8       True
# 0    baseline  target_trade_signal_5        96         16       8       True
# 5    fft_stft  target_trade_signal_5       384         32      16       True
# 2    baseline  target_trade_signal_5       384         32      16       True
# 4    fft_stft  target_trade_signal_5       192         16       8       True
# 1    baseline  target_trade_signal_5       192         16       8       True
#
#   channel_pool  accuracy  macro_f1  accuracy_std  n_folds_used  n_train_avg  \
# 3         mean  0.744275  0.722539      0.028816             4         1516
# 0         mean  0.741094  0.723135      0.009414             4         1516
# 5         mean  0.726984  0.707514      0.011878             3         1184
# 2         mean  0.717460  0.700011      0.011878             3         1184
# 4         mean  0.709596  0.695206      0.047758             4         1324
# 1         mean  0.707912  0.688868      0.023006             4         1324
#
#    n_test_avg
# 3         393
# 0         393
# 5         105
# 2         105
# 4         297
# 1         297
# ================================================================================
# TARGET: target_trade_signal_5
#   feature_set                 target  lookback  patch_len  stride  use_revin  \
# 3    fft_stft  target_trade_signal_5        96         16       8       True
# 0    baseline  target_trade_signal_5        96         16       8       True
# 5    fft_stft  target_trade_signal_5       384         32      16       True
# 2    baseline  target_trade_signal_5       384         32      16       True
# 4    fft_stft  target_trade_signal_5       192         16       8       True
# 1    baseline  target_trade_signal_5       192         16       8       True
#
#   channel_pool  accuracy  macro_f1  accuracy_std  n_folds_used  n_train_avg  \
# 3         mean  0.744275  0.722539      0.028816             4         1516
# 0         mean  0.741094  0.723135      0.009414             4         1516
# 5         mean  0.726984  0.707514      0.011878             3         1184
# 2         mean  0.717460  0.700011      0.011878             3         1184
# 4         mean  0.709596  0.695206      0.047758             4         1324
# 1         mean  0.707912  0.688868      0.023006             4         1324
#
#    n_test_avg
# 3         393
# 0         393
# 5         105
# 2         105
# 4         297
# 1         297
# Best configuration by lookback:
#   feature_set                 target  lookback  patch_len  stride  use_revin  \
# 0    fft_stft  target_trade_signal_5        96         16       8       True
# 2    fft_stft  target_trade_signal_5       384         32      16       True
# 1    fft_stft  target_trade_signal_5       192         16       8       True
#
#   channel_pool  accuracy  macro_f1  accuracy_std  n_folds_used  n_train_avg  \
# 0         mean  0.744275  0.722539      0.028816             4         1516
# 2         mean  0.726984  0.707514      0.011878             3         1184
# 1         mean  0.709596  0.695206      0.047758             4         1324
#
#    n_test_avg
# 0         393
# 2         105
# 1         297

# %%
# ============================================================
# Phase 1D — Optional comparison with previous advanced benchmark
# ============================================================

# If advanced_results exists from Phase 1C, compare its PatchTST rows against the new sweep.
try:
    if len(advanced_results) and len(patchtst_sweep_results):
        old_patch = advanced_results[advanced_results['family'].astype(str).str.contains('patchtst', case=False, na=False)].copy()
        old_patch = old_patch.assign(source='phase1c_previous_patchtst')
        new_patch = patchtst_sweep_results.copy().assign(source='phase1d_official_style_sweep')

        common_cols = ['source','feature_set','target','model','lookback','patch_len','stride','accuracy','macro_f1','n_train_avg','n_test_avg']
        comp = pd.concat([
            old_patch[[c for c in common_cols if c in old_patch.columns]],
            new_patch[[c for c in common_cols if c in new_patch.columns]],
        ], ignore_index=True)
        display(comp.sort_values(['target','accuracy'], ascending=[True, False]).head(40))
except NameError:
    print('advanced_results not found; run Phase 1C first if you want this comparison.')
# Out:
#                           source feature_set                 target  \
# 0      phase1c_previous_patchtst    baseline     target_direction_5
# 1      phase1c_previous_patchtst    baseline     target_direction_5
# 2      phase1c_previous_patchtst    fft_stft     target_direction_5
# 3      phase1c_previous_patchtst         fft     target_direction_5
# 4      phase1c_previous_patchtst    fft_stft     target_direction_5
# 5      phase1c_previous_patchtst         fft     target_direction_5
# 15  phase1d_official_style_sweep    fft_stft  target_trade_signal_5
# 12  phase1d_official_style_sweep    baseline  target_trade_signal_5
# 17  phase1d_official_style_sweep    fft_stft  target_trade_signal_5
# 6      phase1c_previous_patchtst    baseline  target_trade_signal_5
# 14  phase1d_official_style_sweep    baseline  target_trade_signal_5
# 7      phase1c_previous_patchtst    baseline  target_trade_signal_5
# 16  phase1d_official_style_sweep    fft_stft  target_trade_signal_5
# 13  phase1d_official_style_sweep    baseline  target_trade_signal_5
# 8      phase1c_previous_patchtst         fft  target_trade_signal_5
# 9      phase1c_previous_patchtst    fft_stft  target_trade_signal_5
# 10     phase1c_previous_patchtst         fft  target_trade_signal_5
# 11     phase1c_previous_patchtst    fft_stft  target_trade_signal_5
#
#                                 model  lookback  patch_len  stride  accuracy  \
# 0                       patchtst_L256       256       16.0     8.0  0.855150
# 1                       patchtst_L512       512       32.0    16.0  0.822222
# 2                       patchtst_L256       256       16.0     8.0  0.812232
# 3                       patchtst_L256       256       16.0     8.0  0.762876
# 4                       patchtst_L512       512       32.0    16.0  0.755556
# 5                       patchtst_L512       512       32.0    16.0  0.715556
# 15    patchtst_L96_P16_S8_revin1_mean        96       16.0     8.0  0.744275
# 12    patchtst_L96_P16_S8_revin1_mean        96       16.0     8.0  0.741094
# 17  patchtst_L384_P32_S16_revin1_mean       384       32.0    16.0  0.726984
# 6                       patchtst_L256       256       16.0     8.0  0.717811
# 14  patchtst_L384_P32_S16_revin1_mean       384       32.0    16.0  0.717460
# 7                       patchtst_L512       512       32.0    16.0  0.711111
# 16   patchtst_L192_P16_S8_revin1_mean       192       16.0     8.0  0.709596
# 13   patchtst_L192_P16_S8_revin1_mean       192       16.0     8.0  0.707912
# 8                       patchtst_L256       256       16.0     8.0  0.706009
# 9                       patchtst_L256       256       16.0     8.0  0.684549
# 10                      patchtst_L512       512       32.0    16.0  0.640000
# 11                      patchtst_L512       512       32.0    16.0  0.622222
#
#     macro_f1  n_train_avg  n_test_avg
# 0   0.855030         1196         233
# 1   0.817857          732          75
# 2   0.803742         1196         233
# 3   0.719162         1196         233
# 4   0.713650          732          75
# 5   0.664043          732          75
# 15  0.722539         1516         393
# 12  0.723135         1516         393
# 17  0.707514         1184         105
# 6   0.706227         1196         233
# 14  0.700011         1184         105
# 7   0.670833          732          75
# 16  0.695206         1324         297
# 13  0.688868         1324         297
# 8   0.693675         1196         233
# 9   0.664475         1196         233
# 10  0.592344          732          75
# 11  0.543696          732          75

# %% [markdown]
# ## How to interpret Phase 1D
#
# Use this section to answer four questions:
#
# 1. **Does RevIN help?**
#    If `use_revin=True` consistently beats `False`, then non-stationarity is a major issue and RevIN should stay in the architecture.
#
# 2. **Which context length works best?**
#    If 96 or 192 beats 384/768, then the model may not need very long memory, or the dataset is too small for long-context Transformers.
#    If 384/768 wins, then the market structure likely requires longer context.
#
# 3. **Which patch/stride works best?**
#    Smaller patches capture local movements; larger patches capture broader cycles.
#    The best patch size gives a clue about the dominant useful temporal scale.
#
# 4. **Do FFT/STFT help PatchTST?**
#    If `baseline` beats `fft` and `fft_stft`, then PatchTST is already learning useful time structure directly.
#    If `fft` or `fft_stft` wins, then the explicit signal-processing features add information PatchTST was not learning on its own.
#
# This section is intentionally a sweep, not a single model. PatchTST is sensitive to lookback, patch length, stride, and RevIN; testing only one configuration can give misleading conclusions.

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ---
# # Phase 1E — Long-History Dukascopy + Focused iTransformer / TimesNet Benchmark
#
# Phase 1 is **not complete** until we test the model families that actually benefited from FFT/STFT: **iTransformer** and **TimesNet**.
#
# This section changes the experiment in three ways:
#
# 1. **Pull more Dukascopy history inside Colab** instead of assuming a pre-uploaded CSV.
# 2. **Cache the downloaded/resampled 4H data** so future runs are faster.
# 3. **Run a focused sweep** on iTransformer and TimesNet, while keeping GRU/LSTM/PatchTST as reference baselines.
#
# The key research question is now:
#
# > When we give the models enough history, do iTransformer and TimesNet continue to benefit from FFT/STFT representations more than GRU/LSTM/PatchTST?

# %%
import shutil
shutil.rmtree('dukascopy_cache', ignore_errors=True)

# %%
import os, time, math, warnings
from datetime import datetime, timedelta, timezone
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import dukascopy_python
    from dukascopy_python import INTERVAL_HOUR_1, INTERVAL_HOUR_4, INTERVAL_DAY_1, INTERVAL_MIN_1
    from dukascopy_python.instruments import INSTRUMENT_FX_METALS_XAU_USD, INSTRUMENT_FX_MAJORS_EUR_USD
    HAS_DUKA = True
except Exception as e:
    HAS_DUKA = False
    print('Dukascopy package import failed:', repr(e))

# -----------------------------
# User controls
# -----------------------------
INSTRUMENT = 'XAUUSD'                 # 'XAUUSD' or 'EURUSD'
START_DATE = datetime(2008, 1, 1)     # Safer first full long-history run. Try 2003-05-05 after this works.
END_DATE = datetime.utcnow()
SOURCE_INTERVAL = INTERVAL_HOUR_1     # FIX: was '1h' (invalid). Must be a real dukascopy_python constant, e.g. INTERVAL_HOUR_1 == "1HOUR".
TARGET_TIMEFRAME = '4H'
CHUNK_DAYS = 180                      # Smaller chunks reduce timeout/rate-limit risk.
SLEEP_SECONDS = 0.5
MAX_RETRIES = 3

VALID_INTERVALS = {INTERVAL_HOUR_1, INTERVAL_HOUR_4, INTERVAL_DAY_1, INTERVAL_MIN_1}
if HAS_DUKA and SOURCE_INTERVAL not in VALID_INTERVALS:
    raise ValueError(
        f"SOURCE_INTERVAL={SOURCE_INTERVAL!r} is not a valid dukascopy_python interval. "
        f"Valid options: {sorted(VALID_INTERVALS)}"
    )

CACHE_DIR = Path('dukascopy_cache')
CACHE_DIR.mkdir(parents=True, exist_ok=True)
RAW_CACHE = CACHE_DIR / f'{INSTRUMENT}_{SOURCE_INTERVAL}_{START_DATE:%Y%m%d}_{END_DATE:%Y%m%d}.parquet'
RESAMPLED_CACHE = CACHE_DIR / f'{INSTRUMENT}_{TARGET_TIMEFRAME}_{START_DATE:%Y%m%d}_{END_DATE:%Y%m%d}.parquet'

print('Raw cache     :', RAW_CACHE)
print('4H cache      :', RESAMPLED_CACHE)
print('Instrument    :', INSTRUMENT)
print('Date range    :', START_DATE, '→', END_DATE)
print('Source interval:', SOURCE_INTERVAL)


def _instrument_const(name: str):
    name = name.upper()
    if name == 'XAUUSD':
        return INSTRUMENT_FX_METALS_XAU_USD
    if name == 'EURUSD':
        return INSTRUMENT_FX_MAJORS_EUR_USD
    raise ValueError('Unsupported instrument. Add the dukascopy_python instrument constant here.')


def normalize_ohlcv(df: pd.DataFrame) -> pd.DataFrame:
    """Normalize Dukascopy output to timestamp/open/high/low/close/volume."""
    if df is None or len(df) == 0:
        return pd.DataFrame(columns=['timestamp','open','high','low','close','volume'])
    df = df.copy()
    if not isinstance(df.index, pd.RangeIndex):
        df = df.reset_index()
    df.columns = [str(c).lower().replace(' ', '_') for c in df.columns]

    # Timestamp candidates seen across Dukascopy wrappers
    for cand in ['timestamp', 'datetime', 'time', 'date', 'index', 'local_time']:
        if cand in df.columns:
            df = df.rename(columns={cand: 'timestamp'})
            break

    # Volume may appear as volume or tick_volume depending on source
    if 'volume' not in df.columns:
        for cand in ['tick_volume', 'vol']:
            if cand in df.columns:
                df = df.rename(columns={cand: 'volume'})
                break
    if 'volume' not in df.columns:
        df['volume'] = 0.0

    required = ['timestamp','open','high','low','close','volume']
    missing = [c for c in required if c not in df.columns]
    if missing:
        print('Columns returned:', df.columns.tolist())
        raise KeyError(f'Missing required columns: {missing}')

    df = df[required].dropna()
    df['timestamp'] = pd.to_datetime(df['timestamp'], utc=True)
    for c in ['open','high','low','close','volume']:
        df[c] = pd.to_numeric(df[c], errors='coerce')
    df = df.dropna().sort_values('timestamp').drop_duplicates('timestamp').reset_index(drop=True)
    return df


def fetch_dukascopy_chunked(instrument_name, start, end, interval=INTERVAL_HOUR_1, chunk_days=180,
                            sleep_seconds=0.5, max_retries=3):
    """Download Dukascopy data in chunks to avoid timeouts/rate limits."""
    if not HAS_DUKA:
        raise RuntimeError('dukascopy_python is not available.')
    if interval not in VALID_INTERVALS:
        raise ValueError(f"interval={interval!r} is not valid. Valid options: {sorted(VALID_INTERVALS)}")
    instrument = _instrument_const(instrument_name)
    chunks = []
    cur = start
    n_chunks = math.ceil((end - start).days / chunk_days)
    i = 0
    while cur < end:
        nxt = min(cur + timedelta(days=chunk_days), end)
        i += 1
        ok = False
        last_err = None
        for attempt in range(1, max_retries + 1):
            try:
                print(f'[{i}/{n_chunks}] {cur:%Y-%m-%d} → {nxt:%Y-%m-%d}  attempt={attempt}')

                part = dukascopy_python.fetch(
                    instrument,
                    interval=interval,
                    offer_side="BID",
                    start=cur,
                    end=nxt,
                )

                part = normalize_ohlcv(part)

                if len(part):
                    chunks.append(part)

                ok = True
                break

            except Exception as e:
                last_err = e
                wait = sleep_seconds * attempt * 3
                print(f'  failed: {repr(e)}; sleeping {wait:.1f}s')
                time.sleep(wait)
        if not ok:
            print(f'  WARNING: chunk skipped after retries: {cur} → {nxt}. Last error: {last_err!r}')
        cur = nxt
        time.sleep(sleep_seconds)
    if not chunks:
        raise RuntimeError('No Dukascopy chunks downloaded. Try smaller CHUNK_DAYS or different SOURCE_INTERVAL.')
    return pd.concat(chunks, ignore_index=True).sort_values('timestamp').drop_duplicates('timestamp').reset_index(drop=True)


def resample_ohlcv(df: pd.DataFrame, timeframe='4H') -> pd.DataFrame:
    df = normalize_ohlcv(df)
    out = (df.set_index('timestamp')
             .resample(timeframe)
             .agg({'open':'first', 'high':'max', 'low':'min', 'close':'last', 'volume':'sum'})
             .dropna()
             .reset_index())
    return out

# Download or load cached raw data
if RAW_CACHE.exists():
    print('Loading raw cache...')
    df_raw_long = pd.read_parquet(RAW_CACHE)
else:
    df_raw_long = fetch_dukascopy_chunked(
        INSTRUMENT, START_DATE, END_DATE,
        interval=SOURCE_INTERVAL,
        chunk_days=CHUNK_DAYS,
        sleep_seconds=SLEEP_SECONDS,
        max_retries=MAX_RETRIES,
    )
    df_raw_long.to_parquet(RAW_CACHE, index=False)
    print('Saved raw cache:', RAW_CACHE)

# Resample or load cached 4H data
if RESAMPLED_CACHE.exists():
    print('Loading 4H cache...')
    df_long_4h = pd.read_parquet(RESAMPLED_CACHE)
else:
    df_long_4h = resample_ohlcv(df_raw_long, TARGET_TIMEFRAME)
    df_long_4h.to_parquet(RESAMPLED_CACHE, index=False)
    print('Saved 4H cache:', RESAMPLED_CACHE)

print('\nLong 4H dataset:')
display(df_long_4h.head())
display(df_long_4h.tail())
print(df_long_4h.shape)
print('Date span:', df_long_4h.timestamp.min(), '→', df_long_4h.timestamp.max())
# Out:
# Raw cache     : dukascopy_cache/XAUUSD_1HOUR_20080101_20260704.parquet
# 4H cache      : dukascopy_cache/XAUUSD_4H_20080101_20260704.parquet
# Instrument    : XAUUSD
# Date range    : 2008-01-01 00:00:00 → 2026-07-04 08:53:48.235745
# Source interval: 1HOUR
# [1/38] 2008-01-01 → 2008-06-29  attempt=1
# [2/38] 2008-06-29 → 2008-12-26  attempt=1
# [3/38] 2008-12-26 → 2009-06-24  attempt=1
# [4/38] 2009-06-24 → 2009-12-21  attempt=1
# [5/38] 2009-12-21 → 2010-06-19  attempt=1
# [6/38] 2010-06-19 → 2010-12-16  attempt=1
# [7/38] 2010-12-16 → 2011-06-14  attempt=1
# [8/38] 2011-06-14 → 2011-12-11  attempt=1
# [9/38] 2011-12-11 → 2012-06-08  attempt=1
# [10/38] 2012-06-08 → 2012-12-05  attempt=1
# [11/38] 2012-12-05 → 2013-06-03  attempt=1
# [12/38] 2013-06-03 → 2013-11-30  attempt=1
# [13/38] 2013-11-30 → 2014-05-29  attempt=1
# [14/38] 2014-05-29 → 2014-11-25  attempt=1
# [15/38] 2014-11-25 → 2015-05-24  attempt=1
# [16/38] 2015-05-24 → 2015-11-20  attempt=1
# [17/38] 2015-11-20 → 2016-05-18  attempt=1
# [18/38] 2016-05-18 → 2016-11-14  attempt=1
# [19/38] 2016-11-14 → 2017-05-13  attempt=1
# [20/38] 2017-05-13 → 2017-11-09  attempt=1
# [21/38] 2017-11-09 → 2018-05-08  attempt=1
# [22/38] 2018-05-08 → 2018-11-04  attempt=1
# [23/38] 2018-11-04 → 2019-05-03  attempt=1
# [24/38] 2019-05-03 → 2019-10-30  attempt=1
# [25/38] 2019-10-30 → 2020-04-27  attempt=1
# [26/38] 2020-04-27 → 2020-10-24  attempt=1
# [27/38] 2020-10-24 → 2021-04-22  attempt=1
# [28/38] 2021-04-22 → 2021-10-19  attempt=1
# [29/38] 2021-10-19 → 2022-04-17  attempt=1
# [30/38] 2022-04-17 → 2022-10-14  attempt=1
# [31/38] 2022-10-14 → 2023-04-12  attempt=1
# [32/38] 2023-04-12 → 2023-10-09  attempt=1
# [33/38] 2023-10-09 → 2024-04-06  attempt=1
# [34/38] 2024-04-06 → 2024-10-03  attempt=1
# [35/38] 2024-10-03 → 2025-04-01  attempt=1
# [36/38] 2025-04-01 → 2025-09-28  attempt=1
# [37/38] 2025-09-28 → 2026-03-27  attempt=1
# [38/38] 2026-03-27 → 2026-07-04  attempt=1
# INFO:DUKASCRIPT:current timestamp :2026-07-03T16:00:00
# Saved raw cache: dukascopy_cache/XAUUSD_1HOUR_20080101_20260704.parquet
# Saved 4H cache: dukascopy_cache/XAUUSD_4H_20080101_20260704.parquet
#
# Long 4H dataset:
#                   timestamp     open     high      low    close  volume
# 0 2008-01-01 00:00:00+00:00  833.022  833.204  832.938  833.041    0.62
# 1 2008-01-01 04:00:00+00:00  833.099  833.266  832.927  833.137    0.71
# 2 2008-01-01 08:00:00+00:00  833.040  833.319  832.865  833.051    0.74
# 3 2008-01-01 12:00:00+00:00  833.023  833.218  832.939  833.144    0.65
# 4 2008-01-01 16:00:00+00:00  833.119  833.233  832.908  833.038    0.50
#                       timestamp      open      high       low     close  \
# 30132 2026-07-03 00:00:00+00:00  4125.775  4195.365  4122.625  4175.735
# 30133 2026-07-03 04:00:00+00:00  4175.735  4182.535  4160.225  4177.385
# 30134 2026-07-03 08:00:00+00:00  4177.185  4186.525  4168.265  4180.895
# 30135 2026-07-03 12:00:00+00:00  4181.015  4183.075  4155.085  4164.545
# 30136 2026-07-03 16:00:00+00:00  4164.565  4176.055  4162.535  4175.245
#
#         volume
# 30132  7.89316
# 30133  5.52081
# 30134  4.25787
# 30135  4.94535
# 30136  0.67476
# (30137, 6)
# Date span: 2008-01-01 00:00:00+00:00 → 2026-07-03 16:00:00+00:00

# %%
gaps = df_long_4h['timestamp'].diff().value_counts().head(10)
print(gaps)
# Out:
# timestamp
# 0 days 04:00:00    29155
# 2 days 00:00:00      668
# 1 days 16:00:00      177
# 1 days 20:00:00       59
# 3 days 00:00:00       25
# 2 days 04:00:00       19
# 1 days 12:00:00       13
# 1 days 00:00:00        7
# 1 days 04:00:00        5
# 0 days 08:00:00        3
# Name: count, dtype: int64

# %%
df_long_4h.set_index('timestamp')['close'].plot(figsize=(14,4))
# Out:
# <Axes: xlabel='timestamp'>

# %%
# ============================================================
# Phase 1F.2 — Download/cache base Dukascopy data and build 15M/30M/4H candles
# ============================================================

import time, math
from datetime import timedelta
import pandas as pd

def fetch_dukascopy_chunked_mtf(symbol, start, end, interval, chunk_days=30,
                                 sleep_seconds=0.5, max_retries=3):
    """Chunked Dukascopy downloader for high-frequency (15min/1min) data.
    Uses the same instrument-resolution and normalization helpers defined in Cell 50."""
    if not HAS_DUKA:
        raise RuntimeError('dukascopy_python is not available.')
    instrument = _instrument_const(symbol)
    chunks = []
    cur = start
    n_chunks = math.ceil((end - start).days / chunk_days)
    i = 0
    while cur < end:
        nxt = min(cur + timedelta(days=chunk_days), end)
        i += 1
        ok = False
        last_err = None
        for attempt in range(1, max_retries + 1):
            try:
                print(f'[{i}/{n_chunks}] {cur:%Y-%m-%d} → {nxt:%Y-%m-%d}  interval={interval}  attempt={attempt}')
                part = dukascopy_python.fetch(
                    instrument,
                    interval=interval,
                    offer_side="BID",
                    start=cur,
                    end=nxt,
                )
                part = normalize_ohlcv(part)
                if len(part):
                    chunks.append(part)
                ok = True
                break
            except Exception as e:
                last_err = e
                wait = sleep_seconds * attempt * 3
                print(f'  failed: {repr(e)}; sleeping {wait:.1f}s')
                time.sleep(wait)
        if not ok:
            print(f'  WARNING: chunk skipped after retries: {cur} → {nxt}. Last error: {last_err!r}')
        cur = nxt
        time.sleep(sleep_seconds)
    if not chunks:
        return pd.DataFrame(columns=['timestamp','open','high','low','close','volume'])
    return (pd.concat(chunks, ignore_index=True)
              .sort_values('timestamp')
              .drop_duplicates('timestamp')
              .reset_index(drop=True))


def download_or_load_base_mtf(symbol=MTF_SYMBOL, start=MTF_START_DATE, end=MTF_END_DATE,
                               interval=MTF_BASE_INTERVAL, fallback_interval=MTF_FALLBACK_INTERVAL,
                               chunk_days=MTF_CHUNK_DAYS, sleep_seconds=MTF_SLEEP_SECONDS,
                               max_retries=MTF_MAX_RETRIES):
    """Download or load cached high-resolution Dukascopy data (chunked)."""
    cache_path = MTF_CACHE_DIR / f"{symbol}_{interval}_{start.date()}_{end.date()}_raw.parquet"
    fallback_path = MTF_CACHE_DIR / f"{symbol}_{fallback_interval}_{start.date()}_{end.date()}_raw.parquet"

    if cache_path.exists():
        print(f"Loading cached base data: {cache_path}")
        return pd.read_parquet(cache_path)

    if fallback_path.exists():
        print(f"Loading cached fallback data: {fallback_path}")
        return pd.read_parquet(fallback_path)

    print(f"Downloading {symbol} from Dukascopy at interval={interval} ...")
    df_base = fetch_dukascopy_chunked_mtf(
        symbol, start, end, interval=interval,
        chunk_days=chunk_days, sleep_seconds=sleep_seconds, max_retries=max_retries,
    )

    if len(df_base) == 0:
        print(f"interval={interval} returned no data. Falling back to interval={fallback_interval}. This can take longer.")
        df_base = fetch_dukascopy_chunked_mtf(
            symbol, start, end, interval=fallback_interval,
            chunk_days=chunk_days, sleep_seconds=sleep_seconds, max_retries=max_retries,
        )
        if len(df_base) == 0:
            raise RuntimeError(f"No data downloaded for {symbol} at either {interval} or {fallback_interval}.")
        df_base.to_parquet(fallback_path, index=False)
        print(f"Saved fallback cache: {fallback_path} shape={df_base.shape}")
        return df_base

    df_base.to_parquet(cache_path, index=False)
    print(f"Saved cache: {cache_path} shape={df_base.shape}")
    return df_base


def build_timeframe_ohlcv_map(df_base, timeframe_configs=TIMEFRAME_CONFIGS):
    """Create OHLCV dataframes for each timeframe from the same base data."""
    tf_map = {}
    for tf, cfg in timeframe_configs.items():
        rule = cfg["resample_rule"]
        out_path = MTF_CACHE_DIR / f"{MTF_SYMBOL}_{tf}_ohlcv.parquet"
        if out_path.exists():
            print(f"Loading cached {tf}: {out_path}")
            tf_df = pd.read_parquet(out_path)
        else:
            print(f"Resampling to {tf} using rule={rule}")
            tf_df = resample_ohlcv(df_base, rule)
            tf_df.to_parquet(out_path, index=False)
            print(f"Saved {tf}: {out_path} shape={tf_df.shape}")
        tf_map[tf] = tf_df
        print(tf, tf_map[tf].shape, tf_map[tf]["timestamp"].min(), "→", tf_map[tf]["timestamp"].max())
    return tf_map

# Run this cell to prepare all three timeframes.
df_base_mtf = download_or_load_base_mtf()
timeframe_ohlcv = build_timeframe_ohlcv_map(df_base_mtf)
# Out:
# Downloading XAUUSD from Dukascopy at interval=15MIN ...
# [1/140] 2015-01-01 → 2015-01-31  interval=15MIN  attempt=1
# [2/140] 2015-01-31 → 2015-03-02  interval=15MIN  attempt=1
# [3/140] 2015-03-02 → 2015-04-01  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2015-03-31T17:30:00
# [4/140] 2015-04-01 → 2015-05-01  interval=15MIN  attempt=1
# [5/140] 2015-05-01 → 2015-05-31  interval=15MIN  attempt=1
# [6/140] 2015-05-31 → 2015-06-30  interval=15MIN  attempt=1
# [7/140] 2015-06-30 → 2015-07-30  interval=15MIN  attempt=1
# [8/140] 2015-07-30 → 2015-08-29  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2015-08-28T16:45:00
# [9/140] 2015-08-29 → 2015-09-28  interval=15MIN  attempt=1
# [10/140] 2015-09-28 → 2015-10-28  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2015-10-27T16:45:00
# [11/140] 2015-10-28 → 2015-11-27  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2015-11-26T18:00:00
# [12/140] 2015-11-27 → 2015-12-27  interval=15MIN  attempt=1
# [13/140] 2015-12-27 → 2016-01-26  interval=15MIN  attempt=1
# [14/140] 2016-01-26 → 2016-02-25  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2016-02-24T20:30:00
# [15/140] 2016-02-25 → 2016-03-26  interval=15MIN  attempt=1
# [16/140] 2016-03-26 → 2016-04-25  interval=15MIN  attempt=1
# [17/140] 2016-04-25 → 2016-05-25  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2016-05-24T16:45:00
# [18/140] 2016-05-25 → 2016-06-24  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2016-06-23T20:45:00
# [19/140] 2016-06-24 → 2016-07-24  interval=15MIN  attempt=1
# [20/140] 2016-07-24 → 2016-08-23  interval=15MIN  attempt=1
# [21/140] 2016-08-23 → 2016-09-22  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2016-09-21T22:00:00
# [22/140] 2016-09-22 → 2016-10-22  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2016-10-21T17:15:00
# [23/140] 2016-10-22 → 2016-11-21  interval=15MIN  attempt=1
# [24/140] 2016-11-21 → 2016-12-21  interval=15MIN  attempt=1
# [25/140] 2016-12-21 → 2017-01-20  interval=15MIN  attempt=1
# [26/140] 2017-01-20 → 2017-02-19  interval=15MIN  attempt=1
# [27/140] 2017-02-19 → 2017-03-21  interval=15MIN  attempt=1
# [28/140] 2017-03-21 → 2017-04-20  interval=15MIN  attempt=1
# [29/140] 2017-04-20 → 2017-05-20  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2017-05-19T16:45:00
# [30/140] 2017-05-20 → 2017-06-19  interval=15MIN  attempt=1
# [31/140] 2017-06-19 → 2017-07-19  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2017-07-18T20:45:00
# [32/140] 2017-07-19 → 2017-08-18  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2017-08-17T16:45:00
# [33/140] 2017-08-18 → 2017-09-17  interval=15MIN  attempt=1
# [34/140] 2017-09-17 → 2017-10-17  interval=15MIN  attempt=1
# [35/140] 2017-10-17 → 2017-11-16  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2017-11-15T18:45:00
# [36/140] 2017-11-16 → 2017-12-16  interval=15MIN  attempt=1
# [37/140] 2017-12-16 → 2018-01-15  interval=15MIN  attempt=1
# [38/140] 2018-01-15 → 2018-02-14  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2018-02-13T20:45:00
# [39/140] 2018-02-14 → 2018-03-16  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2018-03-15T19:30:00
# [40/140] 2018-03-16 → 2018-04-15  interval=15MIN  attempt=1
# [41/140] 2018-04-15 → 2018-05-15  interval=15MIN  attempt=1
# [42/140] 2018-05-15 → 2018-06-14  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2018-06-13T20:45:00
# [43/140] 2018-06-14 → 2018-07-14  interval=15MIN  attempt=1
# [44/140] 2018-07-14 → 2018-08-13  interval=15MIN  attempt=1
# [45/140] 2018-08-13 → 2018-09-12  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2018-09-11T20:45:00
# [46/140] 2018-09-12 → 2018-10-12  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2018-10-11T17:00:00
# [47/140] 2018-10-12 → 2018-11-11  interval=15MIN  attempt=1
# [48/140] 2018-11-11 → 2018-12-11  interval=15MIN  attempt=1
# [49/140] 2018-12-11 → 2019-01-10  interval=15MIN  attempt=1
# [50/140] 2019-01-10 → 2019-02-09  interval=15MIN  attempt=1
# [51/140] 2019-02-09 → 2019-03-11  interval=15MIN  attempt=1
# [52/140] 2019-03-11 → 2019-04-10  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2019-04-09T19:15:00
# [53/140] 2019-04-10 → 2019-05-10  interval=15MIN  attempt=1
# [54/140] 2019-05-10 → 2019-06-09  interval=15MIN  attempt=1
# [55/140] 2019-06-09 → 2019-07-09  interval=15MIN  attempt=1
# [56/140] 2019-07-09 → 2019-08-08  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2019-08-07T17:00:00
# [57/140] 2019-08-08 → 2019-09-07  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2019-09-06T20:45:00
# [58/140] 2019-09-07 → 2019-10-07  interval=15MIN  attempt=1
# [59/140] 2019-10-07 → 2019-11-06  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2019-11-05T18:30:00
# [60/140] 2019-11-06 → 2019-12-06  interval=15MIN  attempt=1
# [61/140] 2019-12-06 → 2020-01-05  interval=15MIN  attempt=1
# [62/140] 2020-01-05 → 2020-02-04  interval=15MIN  attempt=1
# [63/140] 2020-02-04 → 2020-03-05  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-03-04T20:45:00
# [64/140] 2020-03-05 → 2020-04-04  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-04-03T16:15:00
# [65/140] 2020-04-04 → 2020-05-04  interval=15MIN  attempt=1
# [66/140] 2020-05-04 → 2020-06-03  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-06-02T20:45:00
# [67/140] 2020-06-03 → 2020-07-03  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-07-02T16:45:00
# [68/140] 2020-07-03 → 2020-08-02  interval=15MIN  attempt=1
# [69/140] 2020-08-02 → 2020-09-01  interval=15MIN  attempt=1
# [70/140] 2020-09-01 → 2020-10-01  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-09-30T20:45:00
# [71/140] 2020-10-01 → 2020-10-31  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2020-10-30T16:45:00
# [72/140] 2020-10-31 → 2020-11-30  interval=15MIN  attempt=1
# [73/140] 2020-11-30 → 2020-12-30  interval=15MIN  attempt=1
# [74/140] 2020-12-30 → 2021-01-29  interval=15MIN  attempt=1
# [75/140] 2021-01-29 → 2021-02-28  interval=15MIN  attempt=1
# [76/140] 2021-02-28 → 2021-03-30  interval=15MIN  attempt=1
# [77/140] 2021-03-30 → 2021-04-29  interval=15MIN  attempt=1
# [78/140] 2021-04-29 → 2021-05-29  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2021-05-28T16:45:00
# [79/140] 2021-05-29 → 2021-06-28  interval=15MIN  attempt=1
# [80/140] 2021-06-28 → 2021-07-28  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2021-07-27T20:45:00
# [81/140] 2021-07-28 → 2021-08-27  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2021-08-26T16:45:00
# [82/140] 2021-08-27 → 2021-09-26  interval=15MIN  attempt=1
# [83/140] 2021-09-26 → 2021-10-26  interval=15MIN  attempt=1
# [84/140] 2021-10-26 → 2021-11-25  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2021-11-24T17:45:00
# [85/140] 2021-11-25 → 2021-12-25  interval=15MIN  attempt=1
# [86/140] 2021-12-25 → 2022-01-24  interval=15MIN  attempt=1
# [87/140] 2022-01-24 → 2022-02-23  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-02-22T19:15:00
# [88/140] 2022-02-23 → 2022-03-25  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-03-24T15:45:00
# [89/140] 2022-03-25 → 2022-04-24  interval=15MIN  attempt=1
# [90/140] 2022-04-24 → 2022-05-24  interval=15MIN  attempt=1
# [91/140] 2022-05-24 → 2022-06-23  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-06-22T22:45:00
# [92/140] 2022-06-23 → 2022-07-23  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-07-22T19:15:00
# [93/140] 2022-07-23 → 2022-08-22  interval=15MIN  attempt=1
# [94/140] 2022-08-22 → 2022-09-21  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-09-20T19:15:00
# [95/140] 2022-09-21 → 2022-10-21  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2022-10-20T16:45:00
# [96/140] 2022-10-21 → 2022-11-20  interval=15MIN  attempt=1
# [97/140] 2022-11-20 → 2022-12-20  interval=15MIN  attempt=1
# [98/140] 2022-12-20 → 2023-01-19  interval=15MIN  attempt=1
# [99/140] 2023-01-19 → 2023-02-18  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2023-02-17T16:45:00
# [100/140] 2023-02-18 → 2023-03-20  interval=15MIN  attempt=1
# [101/140] 2023-03-20 → 2023-04-19  interval=15MIN  attempt=1
# [102/140] 2023-04-19 → 2023-05-19  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2023-05-18T16:45:00
# [103/140] 2023-05-19 → 2023-06-18  interval=15MIN  attempt=1
# [104/140] 2023-06-18 → 2023-07-18  interval=15MIN  attempt=1
# [105/140] 2023-07-18 → 2023-08-17  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2023-08-16T17:00:00
# [106/140] 2023-08-17 → 2023-09-16  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2023-09-15T20:45:00
# [107/140] 2023-09-16 → 2023-10-16  interval=15MIN  attempt=1
# [108/140] 2023-10-16 → 2023-11-15  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2023-11-14T17:45:00
# [109/140] 2023-11-15 → 2023-12-15  interval=15MIN  attempt=1
# [110/140] 2023-12-15 → 2024-01-14  interval=15MIN  attempt=1
# [111/140] 2024-01-14 → 2024-02-13  interval=15MIN  attempt=1
# [112/140] 2024-02-13 → 2024-03-14  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2024-03-13T18:30:00
# [113/140] 2024-03-14 → 2024-04-13  interval=15MIN  attempt=1
# [114/140] 2024-04-13 → 2024-05-13  interval=15MIN  attempt=1
# [115/140] 2024-05-13 → 2024-06-12  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2024-06-11T19:15:00
# [116/140] 2024-06-12 → 2024-07-12  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2024-07-11T22:45:00
# [117/140] 2024-07-12 → 2024-08-11  interval=15MIN  attempt=1
# [118/140] 2024-08-11 → 2024-09-10  interval=15MIN  attempt=1
# [119/140] 2024-09-10 → 2024-10-10  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2024-10-09T16:45:00
# [120/140] 2024-10-10 → 2024-11-09  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2024-11-08T17:45:00
# [121/140] 2024-11-09 → 2024-12-09  interval=15MIN  attempt=1
# [122/140] 2024-12-09 → 2025-01-08  interval=15MIN  attempt=1
# [123/140] 2025-01-08 → 2025-02-07  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2025-02-06T19:30:00
# [124/140] 2025-02-07 → 2025-03-09  interval=15MIN  attempt=1
# [125/140] 2025-03-09 → 2025-04-08  interval=15MIN  attempt=1
# [126/140] 2025-04-08 → 2025-05-08  interval=15MIN  attempt=1
# [127/140] 2025-05-08 → 2025-06-07  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2025-06-06T19:15:00
# [128/140] 2025-06-07 → 2025-07-07  interval=15MIN  attempt=1
# [129/140] 2025-07-07 → 2025-08-06  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2025-08-05T16:45:00
# [130/140] 2025-08-06 → 2025-09-05  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2025-09-04T19:15:00
# [131/140] 2025-09-05 → 2025-10-05  interval=15MIN  attempt=1
# [132/140] 2025-10-05 → 2025-11-04  interval=15MIN  attempt=1
# [133/140] 2025-11-04 → 2025-12-04  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2025-12-03T21:45:00
# [134/140] 2025-12-04 → 2026-01-03  interval=15MIN  attempt=1
# [135/140] 2026-01-03 → 2026-02-02  interval=15MIN  attempt=1
# [136/140] 2026-02-02 → 2026-03-04  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2026-03-03T19:15:00
# [137/140] 2026-03-04 → 2026-04-03  interval=15MIN  attempt=1
# INFO:DUKASCRIPT:current timestamp :2026-04-02T15:45:00
# [138/140] 2026-04-03 → 2026-05-03  interval=15MIN  attempt=1
# [139/140] 2026-05-03 → 2026-06-02  interval=15MIN  attempt=1
# [140/140] 2026-06-02 → 2026-06-30  interval=15MIN  attempt=1
# Saved cache: mtf_cache/XAUUSD_15MIN_2015-01-01_2026-06-30_raw.parquet shape=(271572, 6)
# Resampling to 15M using rule=15min
# Saved 15M: mtf_cache/XAUUSD_15M_ohlcv.parquet shape=(271572, 6)
# 15M (271572, 6) 2015-01-01 23:00:00+00:00 → 2026-06-30 00:00:00+00:00
# Resampling to 30M using rule=30min
# Saved 30M: mtf_cache/XAUUSD_30M_ohlcv.parquet shape=(135873, 6)
# 30M (135873, 6) 2015-01-01 23:00:00+00:00 → 2026-06-30 00:00:00+00:00
# Resampling to 4H using rule=4H
# Saved 4H: mtf_cache/XAUUSD_4H_ohlcv.parquet shape=(18373, 6)
# 4H (18373, 6) 2015-01-01 20:00:00+00:00 → 2026-06-30 00:00:00+00:00

# %%
gaps = timeframe_ohlcv['15M']['timestamp'].diff().value_counts().head(10)
print(gaps)
# Out:
# timestamp
# 0 days 00:15:00    268596
# 0 days 01:15:00      2162
# 2 days 01:15:00       536
# 0 days 01:00:00       126
# 0 days 03:45:00        29
# 0 days 05:15:00        22
# 3 days 01:15:00        22
# 0 days 05:00:00        13
# 2 days 02:15:00        11
# 2 days 00:15:00        10
# Name: count, dtype: int64

# %%
gaps = timeframe_ohlcv['30M']['timestamp'].diff().value_counts().head(10)
print(gaps)
# Out:
# timestamp
# 0 days 00:30:00    132901
# 0 days 01:30:00      2163
# 2 days 01:30:00       536
# 0 days 01:00:00       128
# 0 days 04:00:00        28
# 0 days 05:30:00        25
# 3 days 01:30:00        22
# 0 days 05:00:00        15
# 2 days 02:30:00        11
# 2 days 00:30:00        10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# 1. Full 15M close series
fig, ax = plt.subplots(figsize=(14, 4))
timeframe_ohlcv['15M'].set_index('timestamp')['close'].plot(ax=ax, linewidth=0.5)
ax.set_title('XAUUSD 15M close, 2015–2026')
plt.tight_layout()
plt.show()

# 2. Overlay 15M vs the mtf-derived 4H to sanity check consistency
fig, ax = plt.subplots(figsize=(14, 4))
timeframe_ohlcv['15M'].set_index('timestamp')['close'].plot(ax=ax, linewidth=0.4, alpha=0.5, label='15M')
timeframe_ohlcv['4H'].set_index('timestamp')['close'].plot(ax=ax, linewidth=1, label='4H (from 15M base)')
ax.legend()
ax.set_title('15M vs 4H (mtf_cache) close overlay')
plt.tight_layout()
plt.show()

# 3. Gap check on 15M (highest-frequency, most gap-sensitive)
gaps_15m = timeframe_ohlcv['15M']['timestamp'].diff().value_counts().head(10)
print("15M gap distribution:\n", gaps_15m)

# 4. Compare the two 4H series (long-history 1H-derived vs mtf 15M-derived) over their overlap window
df_long_4h_overlap = df_long_4h[df_long_4h['timestamp'] >= '2015-01-01']
fig, ax = plt.subplots(figsize=(14, 4))
df_long_4h_overlap.set_index('timestamp')['close'].plot(ax=ax, linewidth=1, label='4H (from 1H base, dukascopy_cache)')
timeframe_ohlcv['4H'].set_index('timestamp')['close'].plot(ax=ax, linewidth=1, linestyle='--', label='4H (from 15M base, mtf_cache)')
ax.legend()
ax.set_title('4H consistency check: two source pipelines')
plt.tight_layout()
plt.show()
# Out:
# 15M gap distribution:
#  timestamp
# 0 days 00:15:00    268596
# 0 days 01:15:00      2162
# 2 days 01:15:00       536
# 0 days 01:00:00       126
# 0 days 03:45:00        29
# 0 days 05:15:00        22
# 3 days 01:15:00        22
# 0 days 05:00:00        13
# 2 days 02:15:00        11
# 2 days 00:15:00        10
# Name: count, dtype: int64

# %% [markdown]
# ## Phase 1E.2 — Rebuild features from the long-history dataset
#
# This reuses the same feature-engineering pipeline from earlier sections.
#
# Important: if this cell fails because `build_aligned_datasets` is not defined, run the earlier notebook cells first. This section is designed to be appended to the existing research notebook, not executed in isolation.

# %%
# ============================================================
# Phase 1E.2 — Build baseline / FFT / FFT+STFT from long history
# ============================================================
import os
LONG_DATASET_DIR = 'data_phase1E_long_history_4h'
os.makedirs(LONG_DATASET_DIR, exist_ok=True)

# Reuse the existing feature builder defined earlier in the notebook.
# Signature: build_aligned_datasets(source_df, fft_window=64, stft_nperseg=32, horizon=5, atr_mult=0.5)
# Returns: (datasets_dict, colgroups_dict) — NOT just a dict, and no price_col/out_dir args.
long_datasets, long_colgroups = build_aligned_datasets(
    df_long_4h,
    fft_window=64,
    stft_nperseg=32,
    horizon=5,
    atr_mult=0.5,
)

for name, d in long_datasets.items():
    print(name, d.shape, d.timestamp.min(), '→', d.timestamp.max())
    # Function itself doesn't persist to disk, so save explicitly here.
    d.to_parquet(os.path.join(LONG_DATASET_DIR, f'{name}.parquet'), index=False)

print('\nSaved to:', LONG_DATASET_DIR)

# Replace `datasets`/`colgroups` only if you explicitly want all later cells to use long history.
# datasets, colgroups = long_datasets, long_colgroups
# Out:
# Valid aligned rows: 30069 from source rows: 30137
# Baseline features: 41 FFT: 29 STFT: 10
# baseline (30069, 48)
# fft (30069, 77)
# fft_stft (30069, 87)
# baseline (30069, 48) 2008-01-14 12:00:00+00:00 → 2026-07-02 20:00:00+00:00
# fft (30069, 77) 2008-01-14 12:00:00+00:00 → 2026-07-02 20:00:00+00:00
# fft_stft (30069, 87) 2008-01-14 12:00:00+00:00 → 2026-07-02 20:00:00+00:00
#
# Saved to: data_phase1E_long_history_4h

# %% [markdown]
# ## Phase 1E.3 — Focused benchmark: iTransformer and TimesNet
#
# The earlier benchmark showed that **iTransformer** and **TimesNet** benefited most from FFT/STFT. This section keeps PatchTST, GRU, and LSTM as references, but the main sweep focuses on:
#
# - iTransformer with different lookbacks, layers, dimensions, and dropout.
# - TimesNet with different lookbacks, top-k periods, layers, and dimensions.
# - Baseline vs FFT vs FFT+STFT.
# - `target_direction_5` and `target_trade_signal_5`.
#
# We also switch to a safer **rolling-origin split** for long-context deep models, with a configurable minimum training size.

# %%
# ============================================================
# Phase 1E.3 — Focused iTransformer / TimesNet sweep utilities
# ============================================================

def make_rolling_origin_sequence_splits(end_idxs, n_rows, lookback, horizon=5,
                                        n_splits=4, test_size=600,
                                        min_train_sequences=2000):
    """
    Create leakage-safe rolling-origin splits directly over sequence end indexes.

    For each test block:
      - train sequences end before train_cut
      - test sequences start after train_cut + embargo
      - embargo = lookback + horizon

    This avoids the tiny first folds produced by generic TimeSeriesSplit for long lookbacks.
    """
    end_idxs = np.asarray(end_idxs)
    embargo = lookback + horizon
    max_end = int(end_idxs.max())

    # Test block endpoints are placed near the end of the dataset.
    total_test_span = n_splits * test_size
    first_test_start = max(lookback + min_train_sequences + embargo, max_end - total_test_span + 1)

    splits = []
    for k in range(n_splits):
        test_start_end = first_test_start + k * test_size
        test_end_end = min(test_start_end + test_size - 1, max_end - horizon)
        if test_end_end <= test_start_end:
            continue

        train_end_limit = test_start_end - embargo
        train_mask = end_idxs <= train_end_limit
        test_mask = (end_idxs >= test_start_end) & (end_idxs <= test_end_end)
        tr = np.where(train_mask)[0]
        te = np.where(test_mask)[0]

        if len(tr) >= min_train_sequences and len(te) > 50:
            # Safety audit: last training target must end before first test input begins.
            train_target_reach = end_idxs[tr].max() + horizon
            test_input_start = end_idxs[te].min() - lookback + 1
            assert train_target_reach < test_input_start, (
                train_target_reach, test_input_start, 'Leakage safety check failed'
            )
            splits.append((tr, te))
    return splits


FOCUS_CONFIG = {
    'targets': ['target_direction_5', 'target_trade_signal_5'],
    'feature_sets': ['baseline', 'fft', 'fft_stft'],
    'horizon': 5,
    'n_splits': 4,
    'test_size': 600,              # increase when using 20+ years of 4H data
    'min_train_sequences': 2500,   # require enough data for deep models
    'epochs': 10,
    'batch_size': 128,
    'lr': 7e-4,
    'patience': 3,
    'class_weight': True,
    'model_grid': [
        # Reference baselines
        {'name': 'gru_L256', 'family': 'gru', 'lookback': 256, 'hidden': 128},
        {'name': 'lstm_L256', 'family': 'lstm', 'lookback': 256, 'hidden': 128},
        {'name': 'patchtst_L256_P16_S8', 'family': 'patchtst', 'lookback': 256, 'patch_len': 16, 'stride': 8, 'd_model': 128, 'layers': 3},

        # Focus family 1: iTransformer
        {'name': 'itrans_L96_D128_L2',  'family': 'itransformer', 'lookback': 96,  'd_model': 128, 'layers': 2, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L192_D128_L2', 'family': 'itransformer', 'lookback': 192, 'd_model': 128, 'layers': 2, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L256_D128_L3', 'family': 'itransformer', 'lookback': 256, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L384_D128_L3', 'family': 'itransformer', 'lookback': 384, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L512_D128_L3', 'family': 'itransformer', 'lookback': 512, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L768_D128_L3', 'family': 'itransformer', 'lookback': 768, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},

        # Focus family 2: TimesNet-style periodic block
        {'name': 'times_L96_D64_K3',    'family': 'timesnet', 'lookback': 96,  'd_model': 64,  'top_k': 3, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L192_D64_K3',   'family': 'timesnet', 'lookback': 192, 'd_model': 64,  'top_k': 3, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L256_D64_K3',   'family': 'timesnet', 'lookback': 256, 'd_model': 64,  'top_k': 3, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L384_D64_K5',   'family': 'timesnet', 'lookback': 384, 'd_model': 64,  'top_k': 5, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L512_D64_K5',   'family': 'timesnet', 'lookback': 512, 'd_model': 64,  'top_k': 5, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L768_D64_K5',   'family': 'timesnet', 'lookback': 768, 'd_model': 64,  'top_k': 5, 'layers': 2, 'dropout': 0.15},
    ]
}

# Quick mode for first Colab run. Set False for the full sweep.
FOCUS_QUICK_MODE = True
if FOCUS_QUICK_MODE:
    FOCUS_CONFIG['feature_sets'] = ['baseline', 'fft_stft']
    FOCUS_CONFIG['targets'] = ['target_trade_signal_5']
    FOCUS_CONFIG['model_grid'] = [
        {'name': 'gru_L256', 'family': 'gru', 'lookback': 256, 'hidden': 128},
        {'name': 'patchtst_L256_P16_S8', 'family': 'patchtst', 'lookback': 256, 'patch_len': 16, 'stride': 8, 'd_model': 128, 'layers': 3},
        {'name': 'itrans_L256_D128_L3', 'family': 'itransformer', 'lookback': 256, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},
        {'name': 'itrans_L512_D128_L3', 'family': 'itransformer', 'lookback': 512, 'd_model': 128, 'layers': 3, 'nhead': 8, 'dropout': 0.15},
        {'name': 'times_L256_D64_K3', 'family': 'timesnet', 'lookback': 256, 'd_model': 64, 'top_k': 3, 'layers': 2, 'dropout': 0.15},
        {'name': 'times_L512_D64_K5', 'family': 'timesnet', 'lookback': 512, 'd_model': 64, 'top_k': 5, 'layers': 2, 'dropout': 0.15},
    ]

FOCUS_CONFIG
# Out:
# {'targets': ['target_trade_signal_5'],
#  'feature_sets': ['baseline', 'fft_stft'],
#  'horizon': 5,
#  'n_splits': 4,
#  'test_size': 600,
#  'min_train_sequences': 2500,
#  'epochs': 10,
#  'batch_size': 128,
#  'lr': 0.0007,
#  'patience': 3,
#  'class_weight': True,
#  'model_grid': [{'name': 'gru_L256',
#    'family': 'gru',
#    'lookback': 256,
#    'hidden': 128},
#   {'name': 'patchtst_L256_P16_S8',
#    'family': 'patchtst',
#    'lookback': 256,
#    'patch_len': 16,
#    'stride': 8,
#    'd_model': 128,
#    'layers': 3},
#   {'name': 'itrans_L256_D128_L3',
#    'family': 'itransformer',
#    'lookback': 256,
#    'd_model': 128,
#    'layers': 3,
#    'nhead': 8,
#    'dropout': 0.15},
#   {'name': 'itrans_L512_D128_L3',
#    'family': 'itransformer',
#    'lookback': 512,
#    'd_model': 128,
#    'layers': 3,
#    'nhead': 8,
#    'dropout': 0.15},
#   {'name': 'times_L256_D64_K3',
#    'family': 'timesnet',
#    'lookback': 256,
#    'd_model': 64,
#    'top_k': 3,
#    'layers': 2,
#    'dropout': 0.15},
#   {'name': 'times_L512_D64_K5',
#    'family': 'timesnet',
#    'lookback': 512,
#    'd_model': 64,
#    'top_k': 5,
#    'layers': 2,
#    'dropout': 0.15}]}

# %%
# ============================================================
# Phase 1E.4 — Run focused iTransformer / TimesNet benchmark
# ============================================================

def make_focus_model(spec, n_features, n_classes):
    family = spec['family']
    L = spec.get('lookback', 256)
    if family == 'gru':
        return GRUClassifier(n_features, n_classes, hidden=spec.get('hidden', 128), layers=1)
    if family == 'lstm':
        return LSTMClassifier(n_features, n_classes, hidden=spec.get('hidden', 128), layers=1)
    if family == 'patchtst':
        # Use the more official-style PatchTST core from Phase 1D if available.
        if 'PatchTSTOfficialStyleClassifier' in globals():
            return PatchTSTOfficialStyleClassifier(
                n_features=n_features,
                n_classes=n_classes,
                lookback=L,
                patch_len=spec.get('patch_len', 16),
                stride=spec.get('stride', 8),
                d_model=spec.get('d_model', 128),
                n_heads=spec.get('nhead', 8),
                n_layers=spec.get('layers', 3),
                d_ff=spec.get('d_ff', 512),
                dropout=spec.get('dropout', 0.15),
                use_revin=True,
                channel_pool='mean',
            )
        return PatchTSTOriginalClassifier(
            n_features=n_features,
            n_classes=n_classes,
            lookback=L,
            patch_len=spec.get('patch_len', 16),
            stride=spec.get('stride', 8),
            d_model=spec.get('d_model', 128),
            nhead=spec.get('nhead', 8),
            layers=spec.get('layers', 3),
            dropout=spec.get('dropout', 0.15),
            use_revin=True,
        )
    if family == 'itransformer':
        return iTransformerClassifier(
            n_features=n_features,
            n_classes=n_classes,
            lookback=L,
            d_model=spec.get('d_model', 128),
            nhead=spec.get('nhead', 8),
            layers=spec.get('layers', 3),
            dropout=spec.get('dropout', 0.15),
        )
    if family == 'timesnet':
        return TimesBlockClassifier(
            n_features=n_features,
            n_classes=n_classes,
            lookback=L,
            d_model=spec.get('d_model', 64),
            top_k=spec.get('top_k', 3),
            layers=spec.get('layers', 2),
            dropout=spec.get('dropout', 0.15),
        )
    raise ValueError(f'Unknown model family: {family}')


def eval_focus_transformers(datasets, config=FOCUS_CONFIG, results_dir='benchmark_results'):
    if not HAS_TORCH:
        print('PyTorch unavailable; skipping focus benchmark.')
        return pd.DataFrame()

    os.makedirs(results_dir, exist_ok=True)
    rows = []
    for fs in config['feature_sets']:
        df = datasets[fs]
        feat_cols = get_feature_cols(df)
        for target in config['targets']:
            for spec in config['model_grid']:
                model_name = spec['name']
                lookback = spec['lookback']
                Xseq, yseq, end_idxs = make_sequence_arrays_with_index(df, feat_cols, target, lookback=lookback)
                n_classes = len(np.unique(yseq))
                if len(Xseq) < config['min_train_sequences'] + config['test_size']:
                    print(f'SKIP {fs}/{target}/{model_name}: too few sequences={len(Xseq)}')
                    continue

                splits = make_rolling_origin_sequence_splits(
                    end_idxs=end_idxs,
                    n_rows=len(df),
                    lookback=lookback,
                    horizon=config['horizon'],
                    n_splits=config['n_splits'],
                    test_size=config['test_size'],
                    min_train_sequences=config['min_train_sequences'],
                )
                if not splits:
                    print(f'SKIP {fs}/{target}/{model_name}: no safe rolling-origin splits')
                    continue

                print(f'\n{fs:9s} | {target:22s} | {model_name:22s} | L={lookback} | splits={len(splits)}')
                fold_metrics, ntr, nte = [], [], []
                for fold, (tr, te) in enumerate(splits):
                    scaler = StandardScaler()
                    B, T, F = Xseq[tr].shape
                    Xtr = scaler.fit_transform(Xseq[tr].reshape(-1, F)).reshape(-1, T, F)
                    Xte = scaler.transform(Xseq[te].reshape(-1, F)).reshape(-1, T, F)
                    ytr, yte = yseq[tr], yseq[te]

                    torch.manual_seed(SEED + fold)
                    np.random.seed(SEED + fold)
                    model = make_focus_model(spec, len(feat_cols), n_classes)
                    pred = train_val_predict_torch_advanced(
                        model,
                        Xtr, ytr, Xte, yte,
                        epochs=config['epochs'],
                        batch_size=config['batch_size'],
                        lr=config['lr'],
                        patience=config['patience'],
                        class_weight=config['class_weight'],
                    )
                    m = summarize_clf(yte, pred)
                    fold_metrics.append(m)
                    ntr.append(len(tr)); nte.append(len(te))
                    print(f'  fold {fold}: acc={m["accuracy"]:.4f} macroF1={m["macro_f1"]:.4f} train={len(tr)} test={len(te)}')

                rows.append({
                    'feature_set': fs,
                    'target': target,
                    'model': model_name,
                    'family': spec['family'],
                    'lookback': lookback,
                    'accuracy': float(np.mean([m['accuracy'] for m in fold_metrics])),
                    'macro_f1': float(np.mean([m['macro_f1'] for m in fold_metrics])),
                    'weighted_f1': float(np.mean([m['weighted_f1'] for m in fold_metrics])),
                    'accuracy_std': float(np.std([m['accuracy'] for m in fold_metrics])),
                    'macro_f1_std': float(np.std([m['macro_f1'] for m in fold_metrics])),
                    'n_features': len(feat_cols),
                    'n_train_avg': int(np.mean(ntr)),
                    'n_test_avg': int(np.mean(nte)),
                    'n_folds_used': len(fold_metrics),
                    **{k: v for k, v in spec.items() if k not in ['name', 'family']},
                })

    out = pd.DataFrame(rows).sort_values(['target', 'accuracy'], ascending=[True, False]).reset_index(drop=True)
    path = os.path.join(results_dir, 'phase1E_focus_itransformer_timesnet_results.csv')
    out.to_csv(path, index=False)
    print('\nSaved:', path)
    return out

# Use the long-history datasets created above.
focus_results = eval_focus_transformers(long_datasets, FOCUS_CONFIG)
display(focus_results.head(30))
# Out:
# baseline  | target_trade_signal_5  | gru_L256               | L=256 | splits=4
#   fold 0: acc=0.2800 macroF1=0.2074 train=27154 test=600
#   fold 1: acc=0.2967 macroF1=0.1596 train=27754 test=600
#   fold 2: acc=0.2650 macroF1=0.1539 train=28354 test=600
#   fold 3: acc=0.3916 macroF1=0.1913 train=28954 test=595
#
# baseline  | target_trade_signal_5  | patchtst_L256_P16_S8   | L=256 | splits=4
#   fold 0: acc=0.2767 macroF1=0.1445 train=27154 test=600
#   fold 1: acc=0.4200 macroF1=0.1972 train=27754 test=600
#   fold 2: acc=0.2617 macroF1=0.1383 train=28354 test=600
#   fold 3: acc=0.3899 macroF1=0.1870 train=28954 test=595
#
# baseline  | target_trade_signal_5  | itrans_L256_D128_L3    | L=256 | splits=4
#   fold 0: acc=0.3033 macroF1=0.2563 train=27154 test=600
#   fold 1: acc=0.3783 macroF1=0.3443 train=27754 test=600
#   fold 2: acc=0.4217 macroF1=0.2581 train=28354 test=600
#   fold 3: acc=0.3899 macroF1=0.2429 train=28954 test=595
#
# baseline  | target_trade_signal_5  | itrans_L512_D128_L3    | L=512 | splits=4
#   fold 0: acc=0.2767 macroF1=0.2178 train=26642 test=600
#   fold 1: acc=0.3283 macroF1=0.2970 train=27242 test=600
#   fold 2: acc=0.3533 macroF1=0.2946 train=27842 test=600
#   fold 3: acc=0.3933 macroF1=0.2922 train=28442 test=595
#
# baseline  | target_trade_signal_5  | times_L256_D64_K3      | L=256 | splits=4
#   fold 0: acc=0.3050 macroF1=0.2330 train=27154 test=600
#   fold 1: acc=0.3350 macroF1=0.3050 train=27754 test=600
#   fold 2: acc=0.2617 macroF1=0.1383 train=28354 test=600
#   fold 3: acc=0.3899 macroF1=0.1870 train=28954 test=595
#
# baseline  | target_trade_signal_5  | times_L512_D64_K5      | L=512 | splits=4
#   fold 0: acc=0.2900 macroF1=0.2063 train=26642 test=600
#   fold 1: acc=0.4217 macroF1=0.2208 train=27242 test=600
#   fold 2: acc=0.4550 macroF1=0.3181 train=27842 test=600
#   fold 3: acc=0.3899 macroF1=0.1870 train=28442 test=595
#
# fft_stft  | target_trade_signal_5  | gru_L256               | L=256 | splits=4
#   fold 0: acc=0.2733 macroF1=0.1522 train=27154 test=600
#   fold 1: acc=0.2983 macroF1=0.1607 train=27754 test=600
#   fold 2: acc=0.2683 macroF1=0.1877 train=28354 test=600
#   fold 3: acc=0.3950 macroF1=0.2255 train=28954 test=595
#
# fft_stft  | target_trade_signal_5  | patchtst_L256_P16_S8   | L=256 | splits=4
#   fold 0: acc=0.4700 macroF1=0.2132 train=27154 test=600
#   fold 1: acc=0.4200 macroF1=0.1972 train=27754 test=600
#   fold 2: acc=0.4583 macroF1=0.2095 train=28354 test=600
#   fold 3: acc=0.3899 macroF1=0.1870 train=28954 test=595
#
# fft_stft  | target_trade_signal_5  | itrans_L256_D128_L3    | L=256 | splits=4
#   fold 0: acc=0.3000 macroF1=0.2229 train=27154 test=600
#   fold 1: acc=0.2950 macroF1=0.1542 train=27754 test=600
#   fold 2: acc=0.2600 macroF1=0.1416 train=28354 test=600
#   fold 3: acc=0.3950 macroF1=0.2773 train=28954 test=595
#
# fft_stft  | target_trade_signal_5  | itrans_L512_D128_L3    | L=512 | splits=4
#   fold 0: acc=0.3050 macroF1=0.2461 train=26642 test=600
#   fold 1: acc=0.4133 macroF1=0.2897 train=27242 test=600
#   fold 2: acc=0.2617 macroF1=0.1383 train=27842 test=600
#   fold 3: acc=0.3899 macroF1=0.1870 train=28442 test=595
#
# fft_stft  | target_trade_signal_5  | times_L256_D64_K3      | L=256 | splits=4
#   fold 0: acc=0.2767 macroF1=0.1445 train=27154 test=600
#   fold 1: acc=0.2950 macroF1=0.1519 train=27754 test=600
#   fold 2: acc=0.2617 macroF1=0.1383 train=28354 test=600
#   fold 3: acc=0.3697 macroF1=0.2121 train=28954 test=595
#
# fft_stft  | target_trade_signal_5  | times_L512_D64_K5      | L=512 | splits=4
#   fold 0: acc=0.2767 macroF1=0.1445 train=26642 test=600
#   fold 1: acc=0.4200 macroF1=0.1972 train=27242 test=600
#   fold 2: acc=0.2617 macroF1=0.1383 train=27842 test=600
#   fold 3: acc=0.4420 macroF1=0.3156 train=28442 test=595
#
# Saved: benchmark_results/phase1E_focus_itransformer_timesnet_results.csv
#    feature_set                 target                 model        family  \
# 0     fft_stft  target_trade_signal_5  patchtst_L256_P16_S8      patchtst
# 1     baseline  target_trade_signal_5     times_L512_D64_K5      timesnet
# 2     baseline  target_trade_signal_5   itrans_L256_D128_L3  itransformer
# 3     fft_stft  target_trade_signal_5     times_L512_D64_K5      timesnet
# 4     fft_stft  target_trade_signal_5   itrans_L512_D128_L3  itransformer
# 5     baseline  target_trade_signal_5   itrans_L512_D128_L3  itransformer
# 6     baseline  target_trade_signal_5  patchtst_L256_P16_S8      patchtst
# 7     baseline  target_trade_signal_5     times_L256_D64_K3      timesnet
# 8     fft_stft  target_trade_signal_5   itrans_L256_D128_L3  itransformer
# 9     fft_stft  target_trade_signal_5              gru_L256           gru
# 10    baseline  target_trade_signal_5              gru_L256           gru
# 11    fft_stft  target_trade_signal_5     times_L256_D64_K3      timesnet
#
#     lookback  accuracy  macro_f1  weighted_f1  accuracy_std  macro_f1_std  \
# 0        256  0.434562  0.201720     0.263965      0.031726      0.010347
# 1        512  0.389146  0.233056     0.268398      0.061695      0.050563
# 2        256  0.373312  0.275433     0.286299      0.043405      0.040199
# 3        512  0.350088  0.198892     0.204842      0.081467      0.071188
# 4        512  0.342479  0.215263     0.213056      0.061656      0.057481
# 5        512  0.337903  0.275377     0.275071      0.042267      0.033310
# 6        256  0.337062  0.166736     0.173917      0.068928      0.025713
# 7        256  0.322896  0.215814     0.215478      0.046657      0.061424
# 8        256  0.312489  0.199022     0.181284      0.050045      0.054798
# 9        256  0.308739  0.181542     0.167616      0.051059      0.028550
# 10       256  0.308316  0.178053     0.163179      0.049370      0.022144
# 11       256  0.300770  0.161671     0.150868      0.041537      0.029498
#
#     n_features  n_train_avg  n_test_avg  n_folds_used  hidden  patch_len  \
# 0           80        28054         598             4     NaN       16.0
# 1           41        27542         598             4     NaN        NaN
# 2           41        28054         598             4     NaN        NaN
# 3           80        27542         598             4     NaN        NaN
# 4           80        27542         598             4     NaN        NaN
# 5           41        27542         598             4     NaN        NaN
# 6           41        28054         598             4     NaN       16.0
# 7           41        28054         598             4     NaN        NaN
# 8           80        28054         598             4     NaN        NaN
# 9           80        28054         598             4   128.0        NaN
# 10          41        28054         598             4   128.0        NaN
# 11          80        28054         598             4     NaN        NaN
#
#     stride  d_model  layers  nhead  dropout  top_k
# 0      8.0    128.0     3.0    NaN      NaN    NaN
# 1      NaN     64.0     2.0    NaN     0.15    5.0
# 2      NaN    128.0     3.0    8.0     0.15    NaN
# 3      NaN     64.0     2.0    NaN     0.15    5.0
# 4      NaN    128.0     3.0    8.0     0.15    NaN
# 5      NaN    128.0     3.0    8.0     0.15    NaN
# 6      8.0    128.0     3.0    NaN      NaN    NaN
# 7      NaN     64.0     2.0    NaN     0.15    3.0
# 8      NaN    128.0     3.0    8.0     0.15    NaN
# 9      NaN      NaN     NaN    NaN      NaN    NaN
# 10     NaN      NaN     NaN    NaN      NaN    NaN
# 11     NaN     64.0     2.0    NaN     0.15    3.0

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# ============================================================
# Phase 1E.5 — Analyze focused benchmark results
# ============================================================
if 'focus_results' in globals() and len(focus_results):
    for target in focus_results['target'].unique():
        print('\n' + '='*80)
        print('TARGET:', target)
        sub = focus_results[focus_results['target'] == target].copy()
        display(sub.sort_values('accuracy', ascending=False).head(20))

        pivot = sub.pivot_table(index='model', columns='feature_set', values='accuracy', aggfunc='max')
        if 'baseline' in pivot.columns:
            pivot['best'] = pivot.max(axis=1)
            pivot['uplift_vs_baseline'] = pivot['best'] - pivot['baseline']
        display(pivot.sort_values('best', ascending=False).head(30))

    # Simple plot per target
    import matplotlib.pyplot as plt
    for target in focus_results['target'].unique():
        sub = focus_results[focus_results['target'] == target].sort_values('accuracy', ascending=False).head(25)
        plt.figure(figsize=(14, 4))
        labels = sub['model'] + ' | ' + sub['feature_set']
        plt.bar(range(len(sub)), sub['accuracy'])
        plt.xticks(range(len(sub)), labels, rotation=70, ha='right')
        plt.ylabel('Accuracy')
        plt.title(f'Phase 1E focused iTransformer / TimesNet benchmark — {target}')
        plt.tight_layout()
        plt.show()
else:
    print('No focus_results found yet. Run Phase 1E.4 first.')
# Out:
# ================================================================================
# TARGET: target_trade_signal_5
#    feature_set                 target                 model        family  \
# 0     fft_stft  target_trade_signal_5  patchtst_L256_P16_S8      patchtst
# 1     baseline  target_trade_signal_5     times_L512_D64_K5      timesnet
# 2     baseline  target_trade_signal_5   itrans_L256_D128_L3  itransformer
# 3     fft_stft  target_trade_signal_5     times_L512_D64_K5      timesnet
# 4     fft_stft  target_trade_signal_5   itrans_L512_D128_L3  itransformer
# 5     baseline  target_trade_signal_5   itrans_L512_D128_L3  itransformer
# 6     baseline  target_trade_signal_5  patchtst_L256_P16_S8      patchtst
# 7     baseline  target_trade_signal_5     times_L256_D64_K3      timesnet
# 8     fft_stft  target_trade_signal_5   itrans_L256_D128_L3  itransformer
# 9     fft_stft  target_trade_signal_5              gru_L256           gru
# 10    baseline  target_trade_signal_5              gru_L256           gru
# 11    fft_stft  target_trade_signal_5     times_L256_D64_K3      timesnet
#
#     lookback  accuracy  macro_f1  weighted_f1  accuracy_std  macro_f1_std  \
# 0        256  0.434562  0.201720     0.263965      0.031726      0.010347
# 1        512  0.389146  0.233056     0.268398      0.061695      0.050563
# 2        256  0.373312  0.275433     0.286299      0.043405      0.040199
# 3        512  0.350088  0.198892     0.204842      0.081467      0.071188
# 4        512  0.342479  0.215263     0.213056      0.061656      0.057481
# 5        512  0.337903  0.275377     0.275071      0.042267      0.033310
# 6        256  0.337062  0.166736     0.173917      0.068928      0.025713
# 7        256  0.322896  0.215814     0.215478      0.046657      0.061424
# 8        256  0.312489  0.199022     0.181284      0.050045      0.054798
# 9        256  0.308739  0.181542     0.167616      0.051059      0.028550
# 10       256  0.308316  0.178053     0.163179      0.049370      0.022144
# 11       256  0.300770  0.161671     0.150868      0.041537      0.029498
#
#     n_features  n_train_avg  n_test_avg  n_folds_used  hidden  patch_len  \
# 0           80        28054         598             4     NaN       16.0
# 1           41        27542         598             4     NaN        NaN
# 2           41        28054         598             4     NaN        NaN
# 3           80        27542         598             4     NaN        NaN
# 4           80        27542         598             4     NaN        NaN
# 5           41        27542         598             4     NaN        NaN
# 6           41        28054         598             4     NaN       16.0
# 7           41        28054         598             4     NaN        NaN
# 8           80        28054         598             4     NaN        NaN
# 9           80        28054         598             4   128.0        NaN
# 10          41        28054         598             4   128.0        NaN
# 11          80        28054         598             4     NaN        NaN
#
#     stride  d_model  layers  nhead  dropout  top_k
# 0      8.0    128.0     3.0    NaN      NaN    NaN
# 1      NaN     64.0     2.0    NaN     0.15    5.0
# 2      NaN    128.0     3.0    8.0     0.15    NaN
# 3      NaN     64.0     2.0    NaN     0.15    5.0
# 4      NaN    128.0     3.0    8.0     0.15    NaN
# 5      NaN    128.0     3.0    8.0     0.15    NaN
# 6      8.0    128.0     3.0    NaN      NaN    NaN
# 7      NaN     64.0     2.0    NaN     0.15    3.0
# 8      NaN    128.0     3.0    8.0     0.15    NaN
# 9      NaN      NaN     NaN    NaN      NaN    NaN
# 10     NaN      NaN     NaN    NaN      NaN    NaN
# 11     NaN     64.0     2.0    NaN     0.15    3.0
# feature_set           baseline  fft_stft      best  uplift_vs_baseline
# model
# patchtst_L256_P16_S8  0.337062  0.434562  0.434562            0.097500
# times_L512_D64_K5     0.389146  0.350088  0.389146            0.000000
# itrans_L256_D128_L3   0.373312  0.312489  0.373312            0.000000
# itrans_L512_D128_L3   0.337903  0.342479  0.342479            0.004576
# times_L256_D64_K3     0.322896  0.300770  0.322896            0.000000
# gru_L256              0.308316  0.308739  0.308739            0.000424

# %% [markdown]
# ## Phase 1E interpretation guide
#
# Use this section to decide whether Phase 1 should continue or move to Phase 2.
#
# A strong result would look like:
#
# - iTransformer or TimesNet improves with `fft` or `fft_stft` on long-history data.
# - The improvement appears on both `target_direction_5` and `target_trade_signal_5`, or at least consistently on trade signal.
# - The result uses enough training sequences per fold, not tiny early folds.
# - Longer lookbacks improve or stabilize results without collapsing the training sample size.
#
# If iTransformer/TimesNet remain the best models with FFT/STFT after long-history training, then Phase 1's conclusion becomes sharper:
#
# > Frequency-domain features are not universally beneficial, but they are useful for model families that reason across variables and periodic structure, especially iTransformer and TimesNet.

# %% [markdown]
# # Phase 1F — Multi-Timeframe Training for Live Forward Testing
#
# This section trains **separate models per timeframe** for XAUUSD:
#
# - **15M**: fast feedback / intraday entry behavior
# - **30M**: cleaner intraday structure
# - **4H**: higher-timeframe directional bias
#
# For each timeframe we build the same three feature sets:
#
# ```text
# baseline   = OHLCV + indicators
# fft        = baseline + FFT
# fft_stft   = baseline + FFT + causal STFT
# ```
#
# Then we benchmark and save models across multiple architectures:
#
# ```text
# XGBoost, LightGBM, RandomForest,
# GRU, LSTM, PatchTST, iTransformer, TimesNet
# ```
#
# The output is a folder like:
#
# ```text
# live_models/XAUUSD/15M/...
# live_models/XAUUSD/30M/...
# live_models/XAUUSD/4H/...
# ```
#
# These artifacts are what we will later load for **live/paper-market inference**.

# %%
# !pip install dukascopy-python
# Out:
# Requirement already satisfied: dukascopy-python in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from dukascopy-python) (2.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from dukascopy-python) (2.32.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->dukascopy-python) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->dukascopy-python) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->dukascopy-python) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->dukascopy-python) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->dukascopy-python) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->dukascopy-python) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->dukascopy-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->dukascopy-python) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->dukascopy-python) (1.17.0)

# %%
# ============================================================
# Phase 1F.1 — Multi-timeframe configuration, horizons, and W&B setup
# ============================================================
# !pip install dukascopy-python wandb

from pathlib import Path
from datetime import datetime
import joblib
import json
import gc

from dukascopy_python import INTERVAL_MIN_15, INTERVAL_MIN_30, INTERVAL_MIN_1

# ---------------------------------------------------------------------
# Market / data configuration
# ---------------------------------------------------------------------
MTF_SYMBOL = "XAUUSD"

# For 15M and 30M, the base download must be <= 15M.
# We try 15-minute first and fall back to 1-minute if required by the installed
# dukascopy-python version.
MTF_BASE_INTERVAL = INTERVAL_MIN_15
MTF_FALLBACK_INTERVAL = INTERVAL_MIN_1

# More data is better for iTransformer / TimesNet / PatchTST.
# Start with 2015 for Colab stability. Once stable, try 2010 or 2005.
MTF_START_DATE = datetime(2015, 1, 1)
MTF_END_DATE   = datetime(2026, 6, 30)

MTF_CHUNK_DAYS = 30
MTF_SLEEP_SECONDS = 0.5
MTF_MAX_RETRIES = 3

MTF_CACHE_DIR = Path("mtf_cache")
MTF_MODEL_DIR = Path("live_models") / MTF_SYMBOL
MTF_RESULTS_DIR = Path("live_results")
MTF_HISTORY_DIR = MTF_RESULTS_DIR / "training_history"
for p in [MTF_CACHE_DIR, MTF_MODEL_DIR, MTF_RESULTS_DIR, MTF_HISTORY_DIR]:
    p.mkdir(parents=True, exist_ok=True)

# ---------------------------------------------------------------------
# Horizon design
# ---------------------------------------------------------------------
# The previous experiment used roughly the same clock-time target:
#   15M -> 16 candles (~4h)
#   30M -> 8 candles  (~4h)
#   4H  -> 5 candles  (~20h)
# That made some targets noisy. We now expose two horizon modes:
#
# fixed_candles_4:
#   Every timeframe predicts 4 candles ahead. This keeps the learning task
#   structurally comparable across timeframes.
#
# fixed_time_4h:
#   15M and 30M predict roughly four hours ahead. 4H predicts one candle ahead.
#
# legacy:
#   The previous setup, kept for reproducibility.
MTF_HORIZON_MODE = "fixed_candles_4"   # options: "fixed_candles_4", "fixed_time_4h", "legacy"

HORIZON_PRESETS = {
    "fixed_candles_4": {"15M": 4,  "30M": 4, "4H": 4},
    "fixed_time_4h":   {"15M": 16, "30M": 8, "4H": 1},
    "legacy":          {"15M": 16, "30M": 8, "4H": 5},
}

_SELECTED_HORIZONS = HORIZON_PRESETS[MTF_HORIZON_MODE]

TIMEFRAME_CONFIGS = {
    "15M": {
        "resample_rule": "15min",
        "horizon": _SELECTED_HORIZONS["15M"],
        "lookbacks": [96, 192],
        "fft_window": 64,
        "stft_nperseg": 32,
    },
    "30M": {
        "resample_rule": "30min",
        "horizon": _SELECTED_HORIZONS["30M"],
        "lookbacks": [96, 192],
        "fft_window": 64,
        "stft_nperseg": 32,
    },
    "4H": {
        "resample_rule": "4H",
        "horizon": _SELECTED_HORIZONS["4H"],
        "lookbacks": [96, 256],
        "fft_window": 64,
        "stft_nperseg": 32,
    },
}

# ---------------------------------------------------------------------
# Model selection
# ---------------------------------------------------------------------
TREE_MODELS_MTF = ["xgboost", "lightgbm", "random_forest"]

# Keep PatchTST as a reference model, but the main research focus is now
# iTransformer and TimesNet because they benefited most from FFT/STFT.
DEEP_MODELS_MTF = ["gru", "lstm", "patchtst", "itransformer", "timesnet"]
FEATURE_SETS_MTF = ["baseline", "fft", "fft_stft"]

# ---------------------------------------------------------------------
# Training configuration
# ---------------------------------------------------------------------
# Earlier experiments used only 8 epochs and patience=3, which is too short for
# 100k+ sequence datasets. These settings are more appropriate for convergence.
MTF_EPOCHS = 80
MTF_FINAL_EPOCHS = 80
MTF_PATIENCE = 10
MTF_BATCH_SIZE = 256
MTF_LR = 3e-4
MTF_WEIGHT_DECAY = 1e-4
MTF_N_SPLITS = 4
MTF_ATR_MULT = 0.5

# Main target. Set to "direction" to train direction labels instead.
MTF_TARGET_KIND = "trade_signal"  # options: "trade_signal", "direction"

# ---------------------------------------------------------------------
# Weights & Biases configuration
# ---------------------------------------------------------------------
# Paste your W&B API key here or set it through Colab secrets/environment.
# Example:
#   WANDB_API_KEY = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
# Keep it empty if you do not want W&B logging.
WANDB_API_KEY = "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"


USE_WANDB = False if WANDB_API_KEY == "" else True
WANDB_PROJECT = "fusion-trade-phase1"
WANDB_ENTITY = None
WANDB_GROUP_PREFIX = f"{MTF_SYMBOL}_{MTF_HORIZON_MODE}_{MTF_TARGET_KIND}"

try:
    import wandb
    if USE_WANDB:
        wandb.login(key=WANDB_API_KEY)
        print("W&B enabled:", WANDB_PROJECT)
    else:
        print("W&B disabled. Add WANDB_API_KEY and set USE_WANDB=True to log runs.")
except Exception as e:
    USE_WANDB = False
    print("W&B import/login failed; continuing without W&B:", repr(e))

print("Multi-timeframe config ready.")
print("Symbol:", MTF_SYMBOL)
print("Horizon mode:", MTF_HORIZON_MODE)
print("Base interval:", MTF_BASE_INTERVAL)
print("Target kind:", MTF_TARGET_KIND)
print(TIMEFRAME_CONFIGS)
# Out:
# Multi-timeframe config ready.
# {'15M': {'resample_rule': '15min', 'horizon': 16, 'lookbacks': [96, 192], 'fft_window': 64, 'stft_nperseg': 32}, '30M': {'resample_rule': '30min', 'horizon': 8, 'lookbacks': [96, 192], 'fft_window': 64, 'stft_nperseg': 32}, '4H': {'resample_rule': '4H', 'horizon': 5, 'lookbacks': [96, 256], 'fft_window': 64, 'stft_nperseg': 32}}

# %%
# ============================================================
# Phase 1F.2 — Download/cache base Dukascopy data and build 15M/30M/4H candles
# ============================================================

def download_or_load_base_mtf(symbol=MTF_SYMBOL, start=MTF_START_DATE, end=MTF_END_DATE, interval=MTF_BASE_INTERVAL):
    """Download or load cached high-resolution Dukascopy data."""
    cache_path = MTF_CACHE_DIR / f"{symbol}_{interval}_{start.date()}_{end.date()}_raw.parquet"
    fallback_path = MTF_CACHE_DIR / f"{symbol}_1min_{start.date()}_{end.date()}_raw.parquet"

    if cache_path.exists():
        print(f"Loading cached base data: {cache_path}")
        return pd.read_parquet(cache_path)

    print(f"Downloading {symbol} from Dukascopy at interval={interval} ...")
    try:
        df_base = download_dukascopy(symbol, start, end, interval=interval)
        df_base.to_parquet(cache_path, index=False)
        print(f"Saved cache: {cache_path} shape={df_base.shape}")
        return df_base
    except Exception as e:
        print(f"Direct interval={interval} failed: {e}")
        print("Falling back to 1min download. This can take longer.")
        if fallback_path.exists():
            print(f"Loading cached fallback data: {fallback_path}")
            return pd.read_parquet(fallback_path)
        df_base = download_dukascopy(symbol, start, end, interval="1min")
        df_base.to_parquet(fallback_path, index=False)
        print(f"Saved fallback cache: {fallback_path} shape={df_base.shape}")
        return df_base


def build_timeframe_ohlcv_map(df_base, timeframe_configs=TIMEFRAME_CONFIGS):
    """Create OHLCV dataframes for each timeframe from the same base data."""
    tf_map = {}
    for tf, cfg in timeframe_configs.items():
        rule = cfg["resample_rule"]
        out_path = MTF_CACHE_DIR / f"{MTF_SYMBOL}_{tf}_ohlcv.parquet"
        if out_path.exists():
            print(f"Loading cached {tf}: {out_path}")
            tf_df = pd.read_parquet(out_path)
        else:
            print(f"Resampling to {tf} using rule={rule}")
            tf_df = resample_ohlcv(df_base, rule)
            tf_df.to_parquet(out_path, index=False)
            print(f"Saved {tf}: {out_path} shape={tf_df.shape}")
        tf_map[tf] = _standardize_ohlcv_columns(tf_df)
        print(tf, tf_map[tf].shape, tf_map[tf]["timestamp"].min(), "→", tf_map[tf]["timestamp"].max())
    return tf_map

# Run this cell to prepare all three timeframes.
df_base_mtf = download_or_load_base_mtf()
timeframe_ohlcv = build_timeframe_ohlcv_map(df_base_mtf)
# Out:
# Loading cached base data: mtf_cache/XAUUSD_15MIN_2015-01-01_2026-06-30_raw.parquet
# Loading cached 15M: mtf_cache/XAUUSD_15M_ohlcv.parquet
# 15M (271572, 6) 2015-01-01 23:00:00+00:00 → 2026-06-30 00:00:00+00:00
# Loading cached 30M: mtf_cache/XAUUSD_30M_ohlcv.parquet
# 30M (135873, 6) 2015-01-01 23:00:00+00:00 → 2026-06-30 00:00:00+00:00
# Loading cached 4H: mtf_cache/XAUUSD_4H_ohlcv.parquet
# 4H (18373, 6) 2015-01-01 20:00:00+00:00 → 2026-06-30 00:00:00+00:00

# %%
# ============================================================
# Phase 1F.3 — Horizon-aware targets and aligned datasets per timeframe
# ============================================================

def add_targets_horizon(df: pd.DataFrame, price_col='close', horizon=5, atr_mult=0.5) -> pd.DataFrame:
    """Create target columns whose names include the horizon."""
    df = df.copy()
    c = df[price_col]
    fwd = np.log(c.shift(-horizon) / c)
    df[f'target_return_{horizon}'] = fwd
    df[f'target_direction_{horizon}'] = (fwd > 0).astype(float)

    log_ret = np.log(c / c.shift(1))
    rv = pd.Series(index=df.index, dtype=float)
    for i in range(len(df) - horizon):
        rv.iloc[i] = log_ret.iloc[i+1:i+horizon+1].std()
    df[f'target_volatility_{horizon}'] = rv

    atr_return = df['atr_14'] / (c + 1e-9)
    threshold = atr_mult * atr_return
    trade = np.ones(len(df), dtype=float)  # 1 = NO_TRADE
    trade[fwd > threshold] = 2             # BUY
    trade[fwd < -threshold] = 0            # SELL
    trade[pd.isna(fwd) | pd.isna(threshold)] = np.nan
    df[f'target_trade_signal_{horizon}'] = trade
    return df


def build_aligned_datasets_horizon(source_df: pd.DataFrame, fft_window=64, stft_nperseg=32, horizon=5, atr_mult=0.5):
    """Build baseline/fft/fft_stft datasets for a given timeframe and target horizon."""
    df = add_baseline_features(source_df)
    df = add_targets_horizon(df, horizon=horizon, atr_mult=atr_mult)
    df = add_signal_features(df, fft_window=fft_window, stft_nperseg=stft_nperseg)

    target_cols = [
        f'target_return_{horizon}',
        f'target_direction_{horizon}',
        f'target_volatility_{horizon}',
        f'target_trade_signal_{horizon}',
    ]
    fft_cols = [c for c in df.columns if c.startswith('fft_') or c.startswith('sin_fft_') or c.startswith('cos_fft_')]
    stft_cols = [c for c in df.columns if c.startswith('stft_') or c.startswith('sin_stft_') or c.startswith('cos_stft_')]
    signal_cols = set(fft_cols + stft_cols)
    meta_cols = ['timestamp']
    baseline_cols = [c for c in df.columns if c not in set(target_cols) | set(TARGET_COLS) | set(meta_cols) | signal_cols]

    all_needed = baseline_cols + fft_cols + stft_cols + target_cols
    valid_mask = df[all_needed].notna().all(axis=1)
    dfv = df.loc[valid_mask].reset_index(drop=True)

    datasets_out = {
        'baseline': dfv[meta_cols + baseline_cols + target_cols].copy(),
        'fft': dfv[meta_cols + baseline_cols + fft_cols + target_cols].copy(),
        'fft_stft': dfv[meta_cols + baseline_cols + fft_cols + stft_cols + target_cols].copy(),
    }
    colgroups_out = {'baseline_cols': baseline_cols, 'fft_cols': fft_cols, 'stft_cols': stft_cols, 'target_cols': target_cols}
    print(f"horizon={horizon} valid_rows={len(dfv)} baseline={len(baseline_cols)} fft={len(fft_cols)} stft={len(stft_cols)}")
    for k,v in datasets_out.items(): print(' ', k, v.shape)
    return datasets_out, colgroups_out


def build_all_timeframe_datasets(timeframe_ohlcv, timeframe_configs=TIMEFRAME_CONFIGS):
    all_tf_datasets = {}
    all_tf_colgroups = {}
    for tf, df_tf in timeframe_ohlcv.items():
        cfg = timeframe_configs[tf]
        print("\n" + "="*80)
        print(f"Building datasets for {tf} | horizon={cfg['horizon']}")
        ds, cg = build_aligned_datasets_horizon(
            df_tf,
            fft_window=cfg['fft_window'],
            stft_nperseg=cfg['stft_nperseg'],
            horizon=cfg['horizon'],
            atr_mult=MTF_ATR_MULT,
        )
        all_tf_datasets[tf] = ds
        all_tf_colgroups[tf] = cg

        tf_dir = MTF_CACHE_DIR / tf
        tf_dir.mkdir(exist_ok=True, parents=True)
        for fs, d in ds.items():
            d.to_parquet(tf_dir / f"features_{fs}.parquet", index=False)
    return all_tf_datasets, all_tf_colgroups

mtf_datasets, mtf_colgroups = build_all_timeframe_datasets(timeframe_ohlcv)
# Out:
# ================================================================================
# Building datasets for 15M | horizon=16
# horizon=16 valid_rows=271493 baseline=41 fft=29 stft=10
#   baseline (271493, 46)
#   fft (271493, 75)
#   fft_stft (271493, 85)
#
# ================================================================================
# Building datasets for 30M | horizon=8
# horizon=8 valid_rows=135802 baseline=41 fft=29 stft=10
#   baseline (135802, 46)
#   fft (135802, 75)
#   fft_stft (135802, 85)
#
# ================================================================================
# Building datasets for 4H | horizon=5
# horizon=5 valid_rows=18305 baseline=41 fft=29 stft=10
#   baseline (18305, 46)
#   fft (18305, 75)
#   fft_stft (18305, 85)

# %%
# ============================================================
# Phase 1F.4 — Common training utilities for multi-timeframe models
# ============================================================

MTF_TARGET_KIND = globals().get("MTF_TARGET_KIND", "trade_signal")  # "trade_signal" or "direction"


def mtf_target_col(tf, kind=MTF_TARGET_KIND):
    h = TIMEFRAME_CONFIGS[tf]["horizon"]
    if kind == "direction":
        return f"target_direction_{h}"
    if kind == "trade_signal":
        return f"target_trade_signal_{h}"
    raise ValueError(f"Unknown target kind: {kind}")


def get_feature_cols_dynamic(df: pd.DataFrame):
    return [c for c in df.columns if c != 'timestamp' and not c.startswith('target_')]


def make_safe_time_series_splits(n_samples, n_splits=4, gap=5, test_size=None, min_train_size=200):
    if test_size is None:
        test_size = max(50, n_samples // (n_splits + 2))
    safe_splits = n_splits
    while safe_splits >= 2:
        try:
            splits = list(TimeSeriesSplit(n_splits=safe_splits, gap=gap, test_size=test_size).split(np.arange(n_samples)))
            # Keep only folds with enough training samples.
            splits = [(tr, te) for tr, te in splits if len(tr) >= min_train_size and len(te) > 0]
            if len(splits) >= 2:
                return splits
        except Exception:
            pass
        safe_splits -= 1
        test_size = max(50, test_size // 2)
    raise ValueError(f"Cannot create safe splits: n={n_samples}, gap={gap}, test_size={test_size}")


def save_json(path, obj):
    path = Path(path)
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, 'w') as f:
        json.dump(obj, f, indent=2, default=str)


def class_count(y):
    vals, cnts = np.unique(y, return_counts=True)
    return {int(v): int(c) for v,c in zip(vals, cnts)}

# %%
# ============================================================
# Phase 1F.5 — Tree models per timeframe
# ============================================================

def make_tree_model(model_name, n_classes):
    if model_name == "xgboost":
        if not HAS_XGB: return None
        if n_classes > 2:
            return xgb.XGBClassifier(
                n_estimators=300, max_depth=4, learning_rate=0.04,
                subsample=0.85, colsample_bytree=0.85,
                objective='multi:softprob', num_class=n_classes,
                eval_metric='mlogloss', random_state=SEED, verbosity=0
            )
        return xgb.XGBClassifier(
            n_estimators=300, max_depth=4, learning_rate=0.04,
            subsample=0.85, colsample_bytree=0.85,
            eval_metric='logloss', random_state=SEED, verbosity=0
        )
    if model_name == "lightgbm":
        if not HAS_LGB: return None
        return lgb.LGBMClassifier(
            n_estimators=300, max_depth=4, learning_rate=0.04,
            subsample=0.85, colsample_bytree=0.85,
            random_state=SEED, verbose=-1
        )
    if model_name == "random_forest":
        return RandomForestClassifier(
            n_estimators=300, max_depth=10, min_samples_leaf=5,
            random_state=SEED, n_jobs=-1
        )
    raise ValueError(model_name)


def benchmark_tree_models_mtf(mtf_datasets, target_kind=MTF_TARGET_KIND):
    results = []
    for tf, ds_by_fs in mtf_datasets.items():
        target_col = mtf_target_col(tf, target_kind)
        horizon = TIMEFRAME_CONFIGS[tf]['horizon']
        print("\n" + "="*90)
        print(f"TREE BENCHMARK | {tf} | target={target_col}")
        for fs, df in ds_by_fs.items():
            feat_cols = get_feature_cols_dynamic(df)
            X_all = df[feat_cols].values.astype(np.float32)
            y_all = df[target_col].values.astype(int)
            n_classes = len(np.unique(y_all))
            splits = make_safe_time_series_splits(len(df), n_splits=MTF_N_SPLITS, gap=horizon, min_train_size=300)
            for model_name in TREE_MODELS_MTF:
                model = make_tree_model(model_name, n_classes)
                if model is None: continue
                fold_metrics, ntr, nte = [], [], []
                for tr, te in splits:
                    scaler = StandardScaler()
                    Xtr = scaler.fit_transform(X_all[tr])
                    Xte = scaler.transform(X_all[te])
                    ytr, yte = y_all[tr], y_all[te]
                    model = make_tree_model(model_name, n_classes)
                    model.fit(Xtr, ytr)
                    pred = model.predict(Xte)
                    fold_metrics.append(summarize_clf(yte, pred))
                    ntr.append(len(tr)); nte.append(len(te))
                out = {
                    'timeframe': tf, 'feature_set': fs, 'target': target_col, 'model': model_name,
                    'family': model_name, 'lookback': np.nan, 'horizon': horizon,
                    'accuracy': float(np.mean([m['accuracy'] for m in fold_metrics])),
                    'macro_f1': float(np.mean([m['macro_f1'] for m in fold_metrics])),
                    'weighted_f1': float(np.mean([m['weighted_f1'] for m in fold_metrics])),
                    'n_features': len(feat_cols), 'n_folds': len(fold_metrics),
                    'n_train_avg': int(np.mean(ntr)), 'n_test_avg': int(np.mean(nte)),
                    'class_distribution': class_count(y_all),
                }
                print(f"{tf:3s} | {fs:8s} | {model_name:13s} acc={out['accuracy']:.4f} macroF1={out['macro_f1']:.4f}")
                results.append(out)
    return pd.DataFrame(results)

# Run tree benchmark
mtf_tree_results = benchmark_tree_models_mtf(mtf_datasets, target_kind=MTF_TARGET_KIND)
display(mtf_tree_results.sort_values(['timeframe','accuracy'], ascending=[True,False]))
# Out:
# ==========================================================================================
# TREE BENCHMARK | 15M | target=target_trade_signal_16
# 15M | baseline | xgboost       acc=0.4067 macroF1=0.3044
# 15M | baseline | lightgbm      acc=0.4076 macroF1=0.3160
# 15M | baseline | random_forest acc=0.4019 macroF1=0.2746
# 15M | fft      | xgboost       acc=0.4077 macroF1=0.3011
# 15M | fft      | lightgbm      acc=0.4070 macroF1=0.3138
# 15M | fft      | random_forest acc=0.4030 macroF1=0.2755
# 15M | fft_stft | xgboost       acc=0.4073 macroF1=0.3029
# 15M | fft_stft | lightgbm      acc=0.4073 macroF1=0.3116
# 15M | fft_stft | random_forest acc=0.4019 macroF1=0.2725
#
# ==========================================================================================
# TREE BENCHMARK | 30M | target=target_trade_signal_8
# 30M | baseline | xgboost       acc=0.3975 macroF1=0.3661
# 30M | baseline | lightgbm      acc=0.3981 macroF1=0.3684
# 30M | baseline | random_forest acc=0.3919 macroF1=0.3569
# 30M | fft      | xgboost       acc=0.3989 macroF1=0.3703
# 30M | fft      | lightgbm      acc=0.3965 macroF1=0.3712
# 30M | fft      | random_forest acc=0.3953 macroF1=0.3620
# 30M | fft_stft | xgboost       acc=0.3983 macroF1=0.3701
# 30M | fft_stft | lightgbm      acc=0.3976 macroF1=0.3722
# 30M | fft_stft | random_forest acc=0.3958 macroF1=0.3580
#
# ==========================================================================================
# TREE BENCHMARK | 4H | target=target_trade_signal_5
# 4H  | baseline | xgboost       acc=0.3301 macroF1=0.2672
# 4H  | baseline | lightgbm      acc=0.3276 macroF1=0.2617
# 4H  | baseline | random_forest acc=0.3272 macroF1=0.2526
# 4H  | fft      | xgboost       acc=0.3423 macroF1=0.2981
# 4H  | fft      | lightgbm      acc=0.3333 macroF1=0.2809
# 4H  | fft      | random_forest acc=0.3339 macroF1=0.2595
# 4H  | fft_stft | xgboost       acc=0.3337 macroF1=0.2891
# 4H  | fft_stft | lightgbm      acc=0.3307 macroF1=0.2814
# 4H  | fft_stft | random_forest acc=0.3370 macroF1=0.2611
#    timeframe feature_set                  target          model  \
# 3        15M         fft  target_trade_signal_16        xgboost
# 1        15M    baseline  target_trade_signal_16       lightgbm
# 6        15M    fft_stft  target_trade_signal_16        xgboost
# 7        15M    fft_stft  target_trade_signal_16       lightgbm
# 4        15M         fft  target_trade_signal_16       lightgbm
# 0        15M    baseline  target_trade_signal_16        xgboost
# 5        15M         fft  target_trade_signal_16  random_forest
# 8        15M    fft_stft  target_trade_signal_16  random_forest
# 2        15M    baseline  target_trade_signal_16  random_forest
# 12       30M         fft   target_trade_signal_8        xgboost
# 15       30M    fft_stft   target_trade_signal_8        xgboost
# 10       30M    baseline   target_trade_signal_8       lightgbm
# 16       30M    fft_stft   target_trade_signal_8       lightgbm
# 9        30M    baseline   target_trade_signal_8        xgboost
# 13       30M         fft   target_trade_signal_8       lightgbm
# 17       30M    fft_stft   target_trade_signal_8  random_forest
# 14       30M         fft   target_trade_signal_8  random_forest
# 11       30M    baseline   target_trade_signal_8  random_forest
# 21        4H         fft   target_trade_signal_5        xgboost
# 26        4H    fft_stft   target_trade_signal_5  random_forest
# 23        4H         fft   target_trade_signal_5  random_forest
# 24        4H    fft_stft   target_trade_signal_5        xgboost
# 22        4H         fft   target_trade_signal_5       lightgbm
# 25        4H    fft_stft   target_trade_signal_5       lightgbm
# 18        4H    baseline   target_trade_signal_5        xgboost
# 19        4H    baseline   target_trade_signal_5       lightgbm
# 20        4H    baseline   target_trade_signal_5  random_forest
#
#            family  lookback  horizon  accuracy  macro_f1  weighted_f1  \
# 3         xgboost       NaN       16  0.407747  0.301110     0.350002
# 1        lightgbm       NaN       16  0.407598  0.315961     0.362587
# 6         xgboost       NaN       16  0.407267  0.302914     0.350919
# 7        lightgbm       NaN       16  0.407256  0.311642     0.356577
# 4        lightgbm       NaN       16  0.407012  0.313824     0.359734
# 0         xgboost       NaN       16  0.406664  0.304369     0.351872
# 5   random_forest       NaN       16  0.403018  0.275461     0.331775
# 8   random_forest       NaN       16  0.401896  0.272451     0.328527
# 2   random_forest       NaN       16  0.401896  0.274589     0.328133
# 12        xgboost       NaN        8  0.398853  0.370294     0.369489
# 15        xgboost       NaN        8  0.398312  0.370094     0.368446
# 10       lightgbm       NaN        8  0.398124  0.368416     0.369889
# 16       lightgbm       NaN        8  0.397583  0.372174     0.372383
# 9         xgboost       NaN        8  0.397528  0.366100     0.365515
# 13       lightgbm       NaN        8  0.396545  0.371173     0.371773
# 17  random_forest       NaN        8  0.395761  0.358023     0.355894
# 14  random_forest       NaN        8  0.395308  0.361981     0.360321
# 11  random_forest       NaN        8  0.391861  0.356926     0.354414
# 21        xgboost       NaN        5  0.342295  0.298101     0.296123
# 26  random_forest       NaN        5  0.336967  0.261146     0.261759
# 23  random_forest       NaN        5  0.333934  0.259517     0.258256
# 24        xgboost       NaN        5  0.333689  0.289097     0.286584
# 22       lightgbm       NaN        5  0.333279  0.280859     0.277166
# 25       lightgbm       NaN        5  0.330738  0.281377     0.278230
# 18        xgboost       NaN        5  0.330082  0.267236     0.261865
# 19       lightgbm       NaN        5  0.327623  0.261689     0.256834
# 20  random_forest       NaN        5  0.327213  0.252555     0.249636
#
#     n_features  n_folds  n_train_avg  n_test_avg  \
# 3           70        4       158357       45248
# 1           41        4       158357       45248
# 6           80        4       158357       45248
# 7           80        4       158357       45248
# 4           70        4       158357       45248
# 0           41        4       158357       45248
# 5           70        4       158357       45248
# 8           80        4       158357       45248
# 2           41        4       158357       45248
# 12          70        4        79211       22633
# 15          80        4        79211       22633
# 10          41        4        79211       22633
# 16          80        4        79211       22633
# 9           41        4        79211       22633
# 13          70        4        79211       22633
# 17          80        4        79211       22633
# 14          70        4        79211       22633
# 11          41        4        79211       22633
# 21          70        4        10675        3050
# 26          80        4        10675        3050
# 23          70        4        10675        3050
# 24          80        4        10675        3050
# 22          70        4        10675        3050
# 25          80        4        10675        3050
# 18          41        4        10675        3050
# 19          41        4        10675        3050
# 20          41        4        10675        3050
#
#                   class_distribution
# 3   {0: 107299, 1: 49897, 2: 114297}
# 1   {0: 107299, 1: 49897, 2: 114297}
# 6   {0: 107299, 1: 49897, 2: 114297}
# 7   {0: 107299, 1: 49897, 2: 114297}
# 4   {0: 107299, 1: 49897, 2: 114297}
# 0   {0: 107299, 1: 49897, 2: 114297}
# 5   {0: 107299, 1: 49897, 2: 114297}
# 8   {0: 107299, 1: 49897, 2: 114297}
# 2   {0: 107299, 1: 49897, 2: 114297}
# 12    {0: 48175, 1: 36084, 2: 51543}
# 15    {0: 48175, 1: 36084, 2: 51543}
# 10    {0: 48175, 1: 36084, 2: 51543}
# 16    {0: 48175, 1: 36084, 2: 51543}
# 9     {0: 48175, 1: 36084, 2: 51543}
# 13    {0: 48175, 1: 36084, 2: 51543}
# 17    {0: 48175, 1: 36084, 2: 51543}
# 14    {0: 48175, 1: 36084, 2: 51543}
# 11    {0: 48175, 1: 36084, 2: 51543}
# 21       {0: 6118, 1: 5324, 2: 6863}
# 26       {0: 6118, 1: 5324, 2: 6863}
# 23       {0: 6118, 1: 5324, 2: 6863}
# 24       {0: 6118, 1: 5324, 2: 6863}
# 22       {0: 6118, 1: 5324, 2: 6863}
# 25       {0: 6118, 1: 5324, 2: 6863}
# 18       {0: 6118, 1: 5324, 2: 6863}
# 19       {0: 6118, 1: 5324, 2: 6863}
# 20       {0: 6118, 1: 5324, 2: 6863}

# %%
# ============================================================
# Phase 1F.6 — Deep model factories, W&B-aware training, and benchmark per timeframe
# ============================================================

# This section is intentionally more verbose than the earlier deep benchmark.
# Why?
#   1. The earlier models may have been under-trained.
#   2. We need learning curves, not just final scores.
#   3. We want W&B experiment tracking for model/timeframe/feature/horizon comparisons.
#   4. We still save local CSV histories so the notebook remains useful without W&B.


def make_deep_model_mtf(model_name, n_features, n_classes, lookback):
    """Factory for sequence models used in the multi-timeframe benchmark."""
    if model_name == "gru":
        return GRUClassifier(n_features, n_classes, hidden=96, layers=1)
    if model_name == "lstm":
        return LSTMClassifier(n_features, n_classes, hidden=96, layers=1)
    if model_name == "patchtst":
        patch_len = 16 if lookback <= 256 else 32
        stride = 8 if lookback <= 256 else 16
        if 'PatchTSTOriginalClassifier' in globals():
            return PatchTSTOriginalClassifier(
                n_features,
                n_classes,
                lookback=lookback,
                patch_len=patch_len,
                stride=stride,
                d_model=128,
                nhead=8,
                layers=3,
                dropout=0.15,
                use_revin=True,
            )
        return PatchTSTClassifier(
            n_features,
            n_classes,
            lookback=lookback,
            patch_len=patch_len,
            stride=stride,
            d_model=64,
            nhead=4,
            layers=3,
            dropout=0.15,
            use_revin=True,
        )
    if model_name == "itransformer":
        return iTransformerClassifier(
            n_features,
            n_classes,
            lookback=lookback,
            d_model=128,
            nhead=8,
            layers=3,
            dropout=0.15,
            use_revin=True,
        )
    if model_name == "timesnet":
        return TimesBlockClassifier(
            n_features,
            n_classes,
            lookback=lookback,
            d_model=64,
            top_k=3,
            layers=2,
            dropout=0.15,
            use_revin=True,
        )
    raise ValueError(model_name)


def make_sequence_arrays_dynamic(df, feat_cols, target_col, lookback=96):
    """Create causal lookback windows.

    For row i:
        X = rows [i-lookback+1, ..., i]
        y = target at row i

    The target itself is already forward-looking because it was created by
    add_targets_horizon(...). Therefore the input never contains future rows.
    """
    Xraw = df[feat_cols].values.astype(np.float32)
    yraw = df[target_col].values.astype(int)
    Xseq, yseq, end_idxs = [], [], []
    for i in range(lookback - 1, len(df)):
        Xseq.append(Xraw[i-lookback+1:i+1])
        yseq.append(yraw[i])
        end_idxs.append(i)
    return np.asarray(Xseq, dtype=np.float32), np.asarray(yseq, dtype=np.int64), np.asarray(end_idxs, dtype=np.int64)


def _class_names_for_target(n_classes):
    if n_classes == 3:
        return ["SELL", "NO_TRADE", "BUY"]
    if n_classes == 2:
        return ["DOWN", "UP"]
    return [str(i) for i in range(n_classes)]


def train_val_predict_torch_wandb(
    model,
    Xtr,
    ytr,
    Xte,
    yte,
    run_config,
    epochs=80,
    batch_size=256,
    lr=3e-4,
    patience=10,
    class_weight=True,
    weight_decay=1e-4,
    use_wandb=None,
):
    """Train a PyTorch sequence classifier and optionally log to W&B.

    Returns:
        preds: numpy array of test predictions
        history: list of epoch-level dictionaries
        final_metrics: dictionary with test metrics and confusion matrix
    """
    import copy
    from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

    if use_wandb is None:
        use_wandb = bool(globals().get("USE_WANDB", False))

    # Time-ordered validation split. We do not shuffle financial time series.
    n = len(Xtr)
    cut = max(int(n * 0.85), 1)
    X_train, y_train = Xtr[:cut], ytr[:cut]
    X_val, y_val = Xtr[cut:], ytr[cut:]
    if len(X_val) < 20:
        X_train, y_train, X_val, y_val = Xtr, ytr, Xtr, ytr

    train_loader = DataLoader(AdvancedSeqDataset(X_train, y_train), batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(AdvancedSeqDataset(X_val, y_val), batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(AdvancedSeqDataset(Xte, yte), batch_size=batch_size, shuffle=False)

    model = model.to(DEVICE)
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    if class_weight:
        classes, counts = np.unique(y_train, return_counts=True)
        weights = np.ones(int(max(classes)) + 1, dtype=np.float32)
        total = counts.sum()
        for cls, cnt in zip(classes, counts):
            weights[int(cls)] = total / (len(classes) * max(cnt, 1))
        weight_tensor = torch.tensor(weights, dtype=torch.float32, device=DEVICE)
        loss_fn = nn.CrossEntropyLoss(weight=weight_tensor)
    else:
        loss_fn = nn.CrossEntropyLoss()

    wandb_run = None
    if use_wandb:
        try:
            wandb_run = wandb.init(
                project=WANDB_PROJECT,
                entity=WANDB_ENTITY,
                group=run_config.get("wandb_group", WANDB_GROUP_PREFIX),
                name=run_config.get("run_name", None),
                config=run_config,
                reinit=True,
            )
        except Exception as e:
            print("W&B init failed; continuing without W&B:", repr(e))
            wandb_run = None

    best_state, best_val_loss, bad_epochs = None, float("inf"), 0
    history = []

    for epoch in range(1, epochs + 1):
        model.train()
        train_loss, n_train = 0.0, 0
        for xb, yb in train_loader:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            opt.zero_grad()
            logits = model(xb)
            loss = loss_fn(logits, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()
            train_loss += loss.item() * len(yb)
            n_train += len(yb)
        train_loss /= max(n_train, 1)

        model.eval()
        val_loss, val_true, val_pred = 0.0, [], []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(DEVICE), yb.to(DEVICE)
                logits = model(xb)
                loss = loss_fn(logits, yb)
                val_loss += loss.item() * len(yb)
                pred = torch.argmax(logits, dim=1)
                val_pred.extend(pred.cpu().numpy().tolist())
                val_true.extend(yb.cpu().numpy().tolist())
        val_loss /= max(len(X_val), 1)
        val_acc = accuracy_score(val_true, val_pred)
        val_macro_f1 = f1_score(val_true, val_pred, average="macro", zero_division=0)
        val_weighted_f1 = f1_score(val_true, val_pred, average="weighted", zero_division=0)

        row = {
            "epoch": epoch,
            "train_loss": float(train_loss),
            "val_loss": float(val_loss),
            "val_accuracy": float(val_acc),
            "val_macro_f1": float(val_macro_f1),
            "val_weighted_f1": float(val_weighted_f1),
            "lr": float(opt.param_groups[0]["lr"]),
        }
        history.append(row)
        if wandb_run is not None:
            wandb.log(row)

        # Early stopping watches validation loss, not accuracy. This prevents
        # selecting overconfident models that temporarily spike in accuracy.
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = copy.deepcopy(model.state_dict())
            bad_epochs = 0
        else:
            bad_epochs += 1
            if bad_epochs >= patience:
                break

    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    test_true, test_pred = [], []
    with torch.no_grad():
        for xb, yb in test_loader:
            logits = model(xb.to(DEVICE))
            pred = torch.argmax(logits, dim=1)
            test_pred.extend(pred.cpu().numpy().tolist())
            test_true.extend(yb.numpy().tolist())

    test_acc = accuracy_score(test_true, test_pred)
    test_macro_f1 = f1_score(test_true, test_pred, average="macro", zero_division=0)
    test_weighted_f1 = f1_score(test_true, test_pred, average="weighted", zero_division=0)
    cm = confusion_matrix(test_true, test_pred)

    final_metrics = {
        "test_accuracy": float(test_acc),
        "test_macro_f1": float(test_macro_f1),
        "test_weighted_f1": float(test_weighted_f1),
        "best_val_loss": float(best_val_loss),
        "epochs_ran": int(len(history)),
        "confusion_matrix": cm.tolist(),
    }

    if wandb_run is not None:
        wandb.log(final_metrics)
        try:
            wandb.log({
                "confusion_matrix_plot": wandb.plot.confusion_matrix(
                    preds=test_pred,
                    y_true=test_true,
                    class_names=_class_names_for_target(len(np.unique(np.concatenate([ytr, yte])))),
                )
            })
        except Exception as e:
            print("W&B confusion matrix logging failed:", repr(e))
        wandb.finish()

    return np.asarray(test_pred), history, final_metrics


# Global container for epoch-level learning curves across all folds.
MTF_DEEP_HISTORY = []


def benchmark_deep_models_mtf(mtf_datasets, target_kind=MTF_TARGET_KIND):
    if not HAS_TORCH:
        print("Torch unavailable; skipping deep models.")
        return pd.DataFrame()

    results = []
    for tf, ds_by_fs in mtf_datasets.items():
        cfg = TIMEFRAME_CONFIGS[tf]
        target_col = mtf_target_col(tf, target_kind)
        horizon = cfg['horizon']
        print("\n" + "="*90)
        print(f"DEEP BENCHMARK | {tf} | target={target_col} | horizon={horizon}")

        for fs, df in ds_by_fs.items():
            feat_cols = get_feature_cols_dynamic(df)
            for lookback in cfg['lookbacks']:
                Xseq, yseq, end_idxs = make_sequence_arrays_dynamic(df, feat_cols, target_col, lookback=lookback)
                if len(Xseq) < 500:
                    print(f"SKIP {tf} {fs} L={lookback}: only {len(Xseq)} sequences")
                    continue

                n_classes = len(np.unique(yseq))
                effective_gap = lookback + horizon
                try:
                    splits = make_safe_time_series_splits(
                        len(yseq),
                        n_splits=MTF_N_SPLITS,
                        gap=effective_gap,
                        min_train_size=max(500, lookback * 2),
                    )
                except Exception as e:
                    print(f"SKIP {tf} {fs} L={lookback}: {e}")
                    continue

                for model_name in DEEP_MODELS_MTF:
                    fold_metrics, ntr, nte = [], [], []
                    print(f"\n{tf} | {fs} | {target_col} | {model_name}_L{lookback}")

                    for fold, (tr, te) in enumerate(splits):
                        if len(tr) == 0 or len(te) == 0:
                            continue

                        # Fit the scaler on TRAIN ONLY. Then transform test.
                        scaler = StandardScaler()
                        B, T, F = Xseq[tr].shape
                        Xtr = scaler.fit_transform(Xseq[tr].reshape(-1, F)).reshape(-1, T, F)
                        Xte = scaler.transform(Xseq[te].reshape(-1, F)).reshape(-1, T, F)
                        ytr, yte = yseq[tr], yseq[te]

                        torch.manual_seed(SEED + fold)
                        model = make_deep_model_mtf(model_name, len(feat_cols), n_classes, lookback)

                        run_name = f"{tf}_{fs}_{target_col}_{model_name}_L{lookback}_fold{fold}"
                        run_config = {
                            "run_name": run_name,
                            "wandb_group": WANDB_GROUP_PREFIX,
                            "symbol": MTF_SYMBOL,
                            "timeframe": tf,
                            "feature_set": fs,
                            "target": target_col,
                            "target_kind": target_kind,
                            "horizon": horizon,
                            "horizon_mode": MTF_HORIZON_MODE,
                            "model": model_name,
                            "lookback": lookback,
                            "fold": fold,
                            "n_features": len(feat_cols),
                            "n_train": len(tr),
                            "n_test": len(te),
                            "epochs": MTF_EPOCHS,
                            "patience": MTF_PATIENCE,
                            "batch_size": MTF_BATCH_SIZE,
                            "lr": MTF_LR,
                            "weight_decay": MTF_WEIGHT_DECAY,
                            "effective_gap": effective_gap,
                            "class_distribution": class_count(yseq),
                        }

                        pred, history, final_metrics = train_val_predict_torch_wandb(
                            model,
                            Xtr,
                            ytr,
                            Xte,
                            yte,
                            run_config=run_config,
                            epochs=MTF_EPOCHS,
                            batch_size=MTF_BATCH_SIZE,
                            lr=MTF_LR,
                            patience=MTF_PATIENCE,
                            class_weight=True,
                            weight_decay=MTF_WEIGHT_DECAY,
                            use_wandb=USE_WANDB,
                        )

                        m = summarize_clf(yte, pred)
                        m.update({
                            "best_val_loss": final_metrics["best_val_loss"],
                            "epochs_ran": final_metrics["epochs_ran"],
                        })
                        fold_metrics.append(m)
                        ntr.append(len(tr)); nte.append(len(te))

                        for h in history:
                            MTF_DEEP_HISTORY.append({
                                "timeframe": tf,
                                "feature_set": fs,
                                "target": target_col,
                                "model": model_name,
                                "lookback": lookback,
                                "fold": fold,
                                **h,
                            })

                        print(
                            f"  fold {fold}: acc={m['accuracy']:.4f} "
                            f"macroF1={m['macro_f1']:.4f} "
                            f"valLoss={m['best_val_loss']:.4f} "
                            f"epochs={m['epochs_ran']} "
                            f"train={len(tr)} test={len(te)}"
                        )
                        gc.collect()
                        if torch.cuda.is_available():
                            torch.cuda.empty_cache()

                    if len(fold_metrics) == 0:
                        print("  SKIP result: no valid folds")
                        continue

                    out = {
                        'timeframe': tf,
                        'feature_set': fs,
                        'target': target_col,
                        'model': f"{model_name}_L{lookback}",
                        'family': model_name,
                        'lookback': lookback,
                        'horizon': horizon,
                        'accuracy': float(np.mean([m['accuracy'] for m in fold_metrics])),
                        'macro_f1': float(np.mean([m['macro_f1'] for m in fold_metrics])),
                        'weighted_f1': float(np.mean([m['weighted_f1'] for m in fold_metrics])),
                        'accuracy_std': float(np.std([m['accuracy'] for m in fold_metrics])),
                        'macro_f1_std': float(np.std([m['macro_f1'] for m in fold_metrics])),
                        'best_val_loss': float(np.mean([m['best_val_loss'] for m in fold_metrics])),
                        'epochs_ran_avg': float(np.mean([m['epochs_ran'] for m in fold_metrics])),
                        'n_features': len(feat_cols),
                        'n_folds': len(fold_metrics),
                        'n_train_avg': int(np.mean(ntr)),
                        'n_test_avg': int(np.mean(nte)),
                        'class_distribution': class_count(yseq),
                    }
                    print(
                        f"AVG {out['model']}: acc={out['accuracy']:.4f} "
                        f"macroF1={out['macro_f1']:.4f} "
                        f"epochs={out['epochs_ran_avg']:.1f}"
                    )
                    results.append(out)

    results_df = pd.DataFrame(results)
    if len(MTF_DEEP_HISTORY):
        hist_df = pd.DataFrame(MTF_DEEP_HISTORY)
        hist_path = MTF_HISTORY_DIR / f"{MTF_SYMBOL}_deep_training_history_{MTF_HORIZON_MODE}_{target_kind}.csv"
        hist_df.to_csv(hist_path, index=False)
        print("Saved deep training history:", hist_path)
    return results_df


# Run deep benchmark. This can take a while. Use GPU runtime when possible.
mtf_deep_results = benchmark_deep_models_mtf(mtf_datasets, target_kind=MTF_TARGET_KIND)
display(mtf_deep_results.sort_values(['timeframe','accuracy'], ascending=[True,False]) if len(mtf_deep_results) else mtf_deep_results)
# Out:
# ==========================================================================================
# DEEP BENCHMARK | 15M | target=target_trade_signal_16
#
# 15M | baseline | target_trade_signal_16 | gru_L96
#   fold 0: acc=0.2951 macroF1=0.2898 train=90354 test=45233
#   fold 1: acc=0.3054 macroF1=0.2560 train=135587 test=45233
#   fold 2: acc=0.3981 macroF1=0.3588 train=180820 test=45233
#   fold 3: acc=0.3719 macroF1=0.2718 train=226053 test=45233
# AVG gru_L96: acc=0.3426 macroF1=0.2941
#
# 15M | baseline | target_trade_signal_16 | lstm_L96
#   fold 0: acc=0.3638 macroF1=0.3139 train=90354 test=45233
#   fold 1: acc=0.1869 macroF1=0.1080 train=135587 test=45233
#   fold 2: acc=0.3981 macroF1=0.3700 train=180820 test=45233
#   fold 3: acc=0.3716 macroF1=0.2527 train=226053 test=45233
# AVG lstm_L96: acc=0.3301 macroF1=0.2612
#
# 15M | baseline | target_trade_signal_16 | patchtst_L96
#   fold 0: acc=0.3638 macroF1=0.3516 train=90354 test=45233
#   fold 1: acc=0.3633 macroF1=0.3286 train=135587 test=45233
#   fold 2: acc=0.3873 macroF1=0.3555 train=180820 test=45233
#   fold 3: acc=0.3734 macroF1=0.3640 train=226053 test=45233
# AVG patchtst_L96: acc=0.3720 macroF1=0.3499
#
# 15M | baseline | target_trade_signal_16 | itransformer_L96
#   fold 0: acc=0.3522 macroF1=0.3308 train=90354 test=45233
#   fold 1: acc=0.3622 macroF1=0.3043 train=135587 test=45233
#   fold 2: acc=0.3927 macroF1=0.3468 train=180820 test=45233
#   fold 3: acc=0.3866 macroF1=0.3199 train=226053 test=45233
# AVG itransformer_L96: acc=0.3734 macroF1=0.3254
#
# 15M | baseline | target_trade_signal_16 | timesnet_L96
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/3133526363.py in <cell line: 0>()
#     118
#     119 # Run deep benchmark
# --> 120 mtf_deep_results = benchmark_deep_models_mtf(mtf_datasets, target_kind=MTF_TARGET_KIND)
#     121 display(mtf_deep_results.sort_values(['timeframe','accuracy'], ascending=[True,False]) if len(mtf_deep_results) else mtf_deep_results)
#
# /tmp/ipykernel_58/3133526363.py in benchmark_deep_models_mtf(mtf_datasets, target_kind)
#      86
#      87                         torch.manual_seed(SEED + fold)
# ---> 88                         model = make_deep_model_mtf(model_name, len(feat_cols), n_classes, lookback)
#      89                         pred = train_val_predict_torch_advanced(
#      90                             model, Xtr, ytr, Xte, yte,
#
# /tmp/ipykernel_58/3133526363.py in make_deep_model_mtf(model_name, n_features, n_classes, lookback)
#      26         )
#      27     if model_name == "timesnet":
# ---> 28         return TimesNetClassifier(
#      29             n_features, n_classes, lookback=lookback, d_model=64, top_k=3, layers=2, dropout=0.15, use_revin=True
#      30         )
#
# NameError: name 'TimesNetClassifier' is not defined

# %%
# ============================================================
# Phase 1F.7 — Combine benchmark results and select best models per timeframe
# ============================================================

mtf_all_results = pd.concat([mtf_tree_results, mtf_deep_results], ignore_index=True) if len(mtf_deep_results) else mtf_tree_results.copy()
MTF_RESULTS_DIR.mkdir(exist_ok=True, parents=True)
mtf_results_path = MTF_RESULTS_DIR / f"{MTF_SYMBOL}_multi_timeframe_benchmark_{MTF_TARGET_KIND}.csv"
mtf_all_results.to_csv(mtf_results_path, index=False)
print("Saved:", mtf_results_path)

display(mtf_all_results.sort_values(['timeframe','accuracy'], ascending=[True,False]))

print("\nBest models per timeframe:")
best_by_tf = (
    mtf_all_results
    .sort_values('accuracy', ascending=False)
    .groupby('timeframe')
    .head(10)
    .reset_index(drop=True)
)
display(best_by_tf[['timeframe','feature_set','model','family','lookback','horizon','accuracy','macro_f1','n_folds','n_train_avg','n_test_avg']])

# Pivot for quick comparison
for tf in sorted(mtf_all_results['timeframe'].unique()):
    print("\n" + "="*80)
    print("TIMEFRAME:", tf)
    sub = mtf_all_results[mtf_all_results['timeframe'] == tf]
    piv = sub.pivot_table(index='model', columns='feature_set', values='accuracy', aggfunc='max')
    if {'baseline','fft','fft_stft'}.issubset(set(piv.columns)):
        piv['best'] = piv[['baseline','fft','fft_stft']].max(axis=1)
        piv['uplift_vs_baseline'] = piv['best'] - piv['baseline']
    display(piv.sort_values('best' if 'best' in piv.columns else piv.columns[0], ascending=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/2129029895.py in <cell line: 0>()
#       3 # ============================================================
#       4
# ----> 5 mtf_all_results = pd.concat([mtf_tree_results, mtf_deep_results], ignore_index=True) if len(mtf_deep_results) else mtf_tree_results.copy()
#       6 MTF_RESULTS_DIR.mkdir(exist_ok=True, parents=True)
#       7 mtf_results_path = MTF_RESULTS_DIR / f"{MTF_SYMBOL}_multi_timeframe_benchmark_{MTF_TARGET_KIND}.csv"
#
# NameError: name 'mtf_deep_results' is not defined

# %% [markdown]
# ## Phase 1F.7b — Metric visualization and convergence diagnostics
#
# This section turns the benchmark into a proper experiment-tracking workflow.
#
# It uses two sources of evidence:
#
# 1. **Final benchmark table** — which model won on each timeframe and feature set.
# 2. **Training history** — whether the deep model actually converged or stopped too early.
#
# If W&B is enabled, the same information is also logged online: loss curves, validation accuracy, validation macro F1, final test metrics, and confusion matrices.

# %%
# ============================================================
# Phase 1F.7b — Local visualization of benchmark + learning curves
# ============================================================

import matplotlib.pyplot as plt

# 1) Visualize model ranking per timeframe.
if 'mtf_all_results' in globals() and len(mtf_all_results):
    for tf in sorted(mtf_all_results['timeframe'].unique()):
        sub = mtf_all_results[mtf_all_results['timeframe'] == tf].copy()
        sub = sub.sort_values('accuracy', ascending=False).head(15)
        labels = sub['model'].astype(str) + ' | ' + sub['feature_set'].astype(str)
        plt.figure(figsize=(12, 5))
        plt.bar(range(len(sub)), sub['accuracy'].values)
        plt.xticks(range(len(sub)), labels, rotation=75, ha='right')
        plt.ylabel('Accuracy')
        plt.title(f'Top models by accuracy — {tf} | {MTF_TARGET_KIND} | {MTF_HORIZON_MODE}')
        plt.tight_layout()
        plt.show()

# 2) Visualize learning curves if the deep benchmark has produced histories.
hist_path = MTF_HISTORY_DIR / f"{MTF_SYMBOL}_deep_training_history_{MTF_HORIZON_MODE}_{MTF_TARGET_KIND}.csv"
if hist_path.exists():
    hist_df = pd.read_csv(hist_path)
    display(hist_df.head())

    # Show the best few runs by final validation macro F1.
    last_epoch = (
        hist_df.sort_values('epoch')
        .groupby(['timeframe','feature_set','target','model','lookback','fold'])
        .tail(1)
        .sort_values('val_macro_f1', ascending=False)
    )
    print('Best fold-level validation results:')
    display(last_epoch.head(20))

    # Plot a small sample of curves to inspect convergence.
    # You can change these filters to inspect a specific run.
    sample_runs = last_epoch.head(6)[['timeframe','feature_set','target','model','lookback','fold']]
    for _, r in sample_runs.iterrows():
        mask = (
            (hist_df['timeframe'] == r['timeframe']) &
            (hist_df['feature_set'] == r['feature_set']) &
            (hist_df['target'] == r['target']) &
            (hist_df['model'] == r['model']) &
            (hist_df['lookback'] == r['lookback']) &
            (hist_df['fold'] == r['fold'])
        )
        run_hist = hist_df[mask].sort_values('epoch')
        title = f"{r['timeframe']} | {r['feature_set']} | {r['model']} L{r['lookback']} fold{r['fold']}"

        plt.figure(figsize=(8, 4))
        plt.plot(run_hist['epoch'], run_hist['train_loss'], label='train_loss')
        plt.plot(run_hist['epoch'], run_hist['val_loss'], label='val_loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(title + ' — loss')
        plt.legend()
        plt.tight_layout()
        plt.show()

        plt.figure(figsize=(8, 4))
        plt.plot(run_hist['epoch'], run_hist['val_accuracy'], label='val_accuracy')
        plt.plot(run_hist['epoch'], run_hist['val_macro_f1'], label='val_macro_f1')
        plt.xlabel('Epoch')
        plt.ylabel('Metric')
        plt.title(title + ' — validation metrics')
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print('No deep training history found yet. Run Phase 1F.6 first.')

# %%
# ============================================================
# Phase 1F.8 — Train final selected models and save artifacts for live inference
# ============================================================

# Select models automatically from benchmark results.
# You can also manually specify selected_models below.

def select_top_models_for_live(results_df, top_k_per_tf=5):
    selected = []
    for tf in sorted(results_df['timeframe'].unique()):
        sub = results_df[results_df['timeframe'] == tf].sort_values('accuracy', ascending=False)
        selected.append(sub.head(top_k_per_tf))
    return pd.concat(selected, ignore_index=True)

selected_models = select_top_models_for_live(mtf_all_results, top_k_per_tf=5)
display(selected_models[['timeframe','feature_set','model','family','lookback','horizon','accuracy','macro_f1']])


def train_save_tree_final(tf, fs, model_name, df, target_col, artifact_dir):
    feat_cols = get_feature_cols_dynamic(df)
    X = df[feat_cols].values.astype(np.float32)
    y = df[target_col].values.astype(int)
    n_classes = len(np.unique(y))
    scaler = StandardScaler()
    Xs = scaler.fit_transform(X)
    model = make_tree_model(model_name, n_classes)
    model.fit(Xs, y)
    joblib.dump(model, artifact_dir / 'model.pkl')
    joblib.dump(scaler, artifact_dir / 'scaler.pkl')
    save_json(artifact_dir / 'metadata.json', {
        'symbol': MTF_SYMBOL, 'timeframe': tf, 'feature_set': fs,
        'model': model_name, 'family': model_name, 'target_col': target_col,
        'feature_cols': feat_cols, 'horizon': TIMEFRAME_CONFIGS[tf]['horizon'],
        'n_classes': int(n_classes), 'rows_trained': int(len(df)),
    })


def train_save_deep_final(tf, fs, family, lookback, df, target_col, artifact_dir):
    feat_cols = get_feature_cols_dynamic(df)
    Xseq, yseq, _ = make_sequence_arrays_dynamic(df, feat_cols, target_col, lookback=int(lookback))
    n_classes = len(np.unique(yseq))
    scaler = StandardScaler()
    B,T,F = Xseq.shape
    Xs = scaler.fit_transform(Xseq.reshape(-1,F)).reshape(-1,T,F)

    model = make_deep_model_mtf(family, len(feat_cols), n_classes, int(lookback))
    # Train final model using a time-ordered validation tail.
    # W&B is disabled here by default because final artifact training is not a CV fold.
    # If you want to track final training too, set use_wandb=True below.
    _pred_dummy, _history, _metrics = train_val_predict_torch_wandb(
        model,
        Xs,
        yseq,
        Xs[-min(512, len(Xs)):],
        yseq[-min(512, len(yseq)):],
        run_config={
            'run_name': f'FINAL_{tf}_{fs}_{family}_L{int(lookback)}',
            'wandb_group': f'{WANDB_GROUP_PREFIX}_final',
            'symbol': MTF_SYMBOL,
            'timeframe': tf,
            'feature_set': fs,
            'target': target_col,
            'model': family,
            'lookback': int(lookback),
            'horizon': TIMEFRAME_CONFIGS[tf]['horizon'],
            'n_features': len(feat_cols),
        },
        epochs=MTF_FINAL_EPOCHS,
        batch_size=MTF_BATCH_SIZE,
        lr=MTF_LR,
        patience=MTF_PATIENCE,
        class_weight=True,
        weight_decay=MTF_WEIGHT_DECAY,
        use_wandb=False,
    )
    torch.save(model.state_dict(), artifact_dir / 'model.pt')
    joblib.dump(scaler, artifact_dir / 'scaler.pkl')
    save_json(artifact_dir / 'metadata.json', {
        'symbol': MTF_SYMBOL, 'timeframe': tf, 'feature_set': fs,
        'model': f'{family}_L{int(lookback)}', 'family': family,
        'target_col': target_col, 'feature_cols': feat_cols,
        'horizon': TIMEFRAME_CONFIGS[tf]['horizon'], 'lookback': int(lookback),
        'n_classes': int(n_classes), 'rows_trained': int(len(df)),
    })


def train_and_save_selected_live_models(selected_df, mtf_datasets):
    for _, row in selected_df.iterrows():
        tf = row['timeframe']
        fs = row['feature_set']
        family = row['family']
        model_name = row['model']
        lookback = row['lookback']
        target_col = mtf_target_col(tf, MTF_TARGET_KIND)
        df = mtf_datasets[tf][fs]

        artifact_dir = MTF_MODEL_DIR / tf / fs / str(model_name)
        artifact_dir.mkdir(parents=True, exist_ok=True)
        print("\nTraining final:", artifact_dir)

        if family in TREE_MODELS_MTF:
            train_save_tree_final(tf, fs, family, df, target_col, artifact_dir)
        else:
            train_save_deep_final(tf, fs, family, int(lookback), df, target_col, artifact_dir)
        print("Saved artifact:", artifact_dir)

# Run this after reviewing selected_models.
# It may take time for deep models.
train_and_save_selected_live_models(selected_models, mtf_datasets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/2790795276.py in <cell line: 0>()
#      13     return pd.concat(selected, ignore_index=True)
#      14
# ---> 15 selected_models = select_top_models_for_live(mtf_all_results, top_k_per_tf=5)
#      16 display(selected_models[['timeframe','feature_set','model','family','lookback','horizon','accuracy','macro_f1']])
#      17
#
# NameError: name 'mtf_all_results' is not defined

# %%
# ============================================================
# Phase 1F.9 — Create live model registry/manifest
# ============================================================

registry = []
for meta_path in MTF_MODEL_DIR.glob("**/metadata.json"):
    with open(meta_path) as f:
        meta = json.load(f)
    meta['artifact_dir'] = str(meta_path.parent)
    registry.append(meta)

registry_df = pd.DataFrame(registry)
registry_path = MTF_MODEL_DIR / 'model_registry.csv'
registry_df.to_csv(registry_path, index=False)
print("Saved registry:", registry_path)
display(registry_df[['timeframe','feature_set','model','family','target_col','horizon','rows_trained','artifact_dir']])
# Out:
# Saved registry: live_models/XAUUSD/model_registry.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_58/3325970454.py in <cell line: 0>()
#      14 registry_df.to_csv(registry_path, index=False)
#      15 print("Saved registry:", registry_path)
# ---> 16 display(registry_df[['timeframe','feature_set','model','family','target_col','horizon','rows_trained','artifact_dir']])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4117             if is_iterator(key):
#    4118                 key = list(key)
# -> 4119             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4120
#    4121         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6210             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6211
# -> 6212         self._raise_if_missing(keyarr, indexer, axis_name)
#    6213
#    6214         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6259         if nmissing:
#    6260             if nmissing == len(indexer):
# -> 6261                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6262
#    6263             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['timeframe', 'feature_set', 'model', 'family', 'target_col', 'horizon',\n       'rows_trained', 'artifact_dir'],\n      dtype='object')] are in the [columns]"
